# %% [markdown]
# # Import Modules

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
import typing as tp
import time
import random
import math
from collections import deque
from dataclasses import dataclass

import torch
from torch import nn, Tensor

SEED = 42
random.seed(SEED)
np.random.seed(SEED+1)
torch.manual_seed(SEED+2)
torch.use_deterministic_algorithms(mode=True, warn_only=False)

# %% [markdown]
# # Ops

# %%
def plot_environment(env:gym.Env, figsize:tuple[int, int]=(5, 4)):
    plt.figure(figsize=figsize)
    img = env.render()
    plt.imshow(img)
    plt.axis("off")
    return img

def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames:list, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    animation = anim.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    return animation

def show_one_episode(action_sampler:tp.Callable, n_max_steps=500, repeat=False):
    frames = []
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    obs, info = env.reset()
    with torch.no_grad():
        for step in range(n_max_steps):
            frames.append(env.render())
            action = action_sampler(obs).cpu().item()
            obs, reward, done, truncated, info = env.step(action)
            if done or truncated:
                print("done at step", step+1)
                break
    env.close()
    return plot_animation(frames, repeat=repeat)

# %%
class CosineDecayWithWarmup:
    def __init__(
        self,
        warmup_steps:int,
        max_learning_rate:float,
        decay_steps:int,
        min_learning_rate:float
    ):
        self.warmup_steps = warmup_steps
        self.max_learning_rate = max_learning_rate
        self.decay_steps = decay_steps
        self.min_learning_rate = min_learning_rate

    def __call__(self, step):
        # linear warmup for warmup_steps steps
        if step < self.warmup_steps:
            return self.max_learning_rate * step / self.warmup_steps
        # if it > decay_steps, return min learning rate
        if step > self.decay_steps:
            return self.min_learning_rate
        # in between, use cosine decay down to min learning rate
        decay_ratio = (step - self.warmup_steps) / (self.decay_steps - self.warmup_steps)
        coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
        return self.min_learning_rate + coeff * (self.max_learning_rate - self.min_learning_rate)

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, info = env.reset(seed=1)
obs, obs.shape, info
# Out:
# (array([ 0.00118216,  0.04504637, -0.03558404,  0.04486495], dtype=float32),
#  (4,),
#  {})

# %% [markdown]
# # Cartpole Environment
# * GOAL: Keep the pole upright for as long as possible
# ```python
# Actions:
#     left: 0
#     right: 1
#
# Observation Space: (4,)
# ```
# ![image.png](images/carpole_info.png)
# * The cart x-position (index 0) can be take values between (-4.8, 4.8), but the episode terminates if the cart leaves the (-2.4, 2.4) range.
# * The pole angle can be observed between (-.418, .418) radians (or ±24°), but the episode terminates if the pole angle is not in the range (-.2095, .2095) (or ±12°)
#
# ## Rewards
# * Since the goal is to keep the pole upright for as long as possible, a reward of +1 for every step taken, including the termination step, is allotted
#
# ## Episode End
# * The episode ends if any one of the following occurs:
#     * Termination: Pole Angle is greater than ±12°
#     * Termination: Cart Position is greater than ±2.4 (center of the cart reaches the edge of the display)
#     * Truncation: Episode length is greater than 500

# %% [markdown]
# # Q-learning

# %%
@dataclass
class config:
    num_iters:int = 600
    num_episodes_per_iter:int = 10
    max_steps_per_episode:int = 1000 # will not go beyond 500, simply...
    
    gamma:float = 0.99 # changed from 0.95, improved performance...
    
    lr:float = 0.01
    weight_decay:float = 0.0
    batch_size:int = 64
    constlr_steps:int = int(num_iters*0.4375)

    device:torch.device = torch.device("cuda" if False else "cpu") # cpu good for very very small models
    dtype:torch.dtype = torch.float32 if "cpu" in device.type else torch.float16

    autocast:torch.autocast = torch.autocast(
        device_type=device.type, dtype=dtype, enabled="cuda" in device.type
    )
    logging_interval:int = 1

    generator:torch.Generator = torch.Generator(device=device).manual_seed(SEED+343434)

print(config())
# Out:
# config(num_iters=600, num_episodes_per_iter=10, max_steps_per_episode=1000, gamma=0.99, lr=0.01, weight_decay=0.0, batch_size=64, constlr_steps=262, device=device(type='cpu'), dtype=torch.float32, autocast=<torch.amp.autocast_mode.autocast object at 0x7aab74720790>, logging_interval=1, generator=<torch._C.Generator object at 0x7aab74807590>)

# %%
class DQN(nn.Module):
    def __init__(self, num_inputs:int, num_hidden:int, num_outputs:int):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(num_inputs, num_hidden), nn.ELU(),
            nn.Linear(num_hidden, num_hidden), nn.ELU(),
            nn.Linear(num_hidden, num_outputs)
        )
        self.num_actions = num_outputs

    def forward(self, x:Tensor):      # (B, num_inputs=4)
        return self.model(x)          # (B, num_outputs=2)

# %%
dqn = DQN(
    num_inputs=env.observation_space.shape[0],
    num_hidden=32,
    num_outputs=env.action_space.n
)
dqn.to(config.device)
# dqn.compile()

optimizer = torch.optim.NAdam(
    dqn.parameters(),
    lr=config.lr, 
    weight_decay=config.weight_decay,
)
cosine_decay = CosineDecayWithWarmup(
    warmup_steps=1,
    max_learning_rate=config.lr,
    decay_steps=config.num_iters,
    min_learning_rate=config.lr*0.0
)
def get_lr(step:int):
    if step < config.constlr_steps:
        return config.lr
    return cosine_decay(step)
    
print(len(list(dqn.parameters())), sum(p.numel() for p in dqn.parameters()), sep="\nNumber of parameters: ")
# Out:
# 6
# Number of parameters: 1282

# %%
@torch.no_grad()
def action_policy(dqn:DQN, obs:np.ndarray, epsilon:float) -> Tensor:
    if random.random() <= epsilon: return torch.randint(low=0, high=dqn.num_actions, size=(1,), device=config.device, generator=config.generator)
    else: return dqn(torch.as_tensor(obs, device=config.device).unsqueeze(0)).squeeze(0).argmax()

# %%
def play_step(dqn:DQN, obs:np.ndarray, eps:float, replay_buffer:deque):
    action = action_policy(dqn, obs, eps).item()
    next_obs, reward, done, truncated, info = env.step(action)
    # done = done or truncated # terminate only if done, not truncated
    replay_buffer.append([next_obs, action, reward, obs, done])
    return next_obs, reward, done, truncated, info

def sample_instances_from_buffer(replay_buffer:deque, batch_size:int):
    batch_sample = random.sample(replay_buffer, batch_size) # [[s', a, r, s], [s', a, r, s], ...] with len `batch_size`
    return batch_sample

# %% [markdown]
# ![image.png](images/semi_grad_sarsa.png)

# %%
@torch.compile
def train_step(dqn:DQN, replay_buffer:deque):
    # sample instances
    batched_samples = sample_instances_from_buffer(replay_buffer, batch_size=config.batch_size)
    instances = list(zip(*batched_samples))
    next_obs, actions, rewards, current_states, dones = [torch.as_tensor(np.array(inst), device=config.device, dtype=torch.float32) for inst in instances]
    # input model
    with torch.no_grad():
        with config.autocast:
            next_Q_val:Tensor = dqn(next_obs) # (B, num_actions)
            next_Q_val = next_Q_val.max(dim=1).values # (B,)
            #for the condition from the algorithm above
            zero_if_terminal_else_one = (~(dones.bool())).float() # 0 if done else 1
    
        Qtarget:Tensor = (rewards + config.gamma * next_Q_val * zero_if_terminal_else_one) # (B,)
    
    with config.autocast:
        Qpred:Tensor = dqn(current_states)
        Qpred = Qpred.gather(1, actions.unsqueeze(1).long()).squeeze(-1) # (B,)
        loss = nn.functional.mse_loss(Qpred, Qtarget)
    loss.backward()
    grads = [param.grad for param in dqn.parameters()]; dqn.zero_grad()
    return grads # len = 6

# %%
def apply_grads(grads:list[list[Tensor]]): # (num_episodes_per_iter=10, 6)
    param_list_len = len(grads[0]) # 6
    to_be_applied_grads:list[list[Tensor]] = [[] for _ in range(param_list_len)] # initialize list

    for n_ep_per_iter, grads_in_ep in enumerate(grads):
        for i, grad in enumerate(grads_in_ep): # (6,)
            to_be_applied_grads[i].append(grad)

    grads:list[Tensor] = [torch.stack(grad_list).mean(dim=0) for grad_list in to_be_applied_grads]
    
    for p, grad in zip(dqn.parameters(), grads):
        p.grad = grad

    optimizer.step()
    optimizer.zero_grad()

def play():
    replay_buffer = deque(maxlen=config.num_iters*config.num_episodes_per_iter*config.max_steps_per_episode)
    episode_lens = []
    # Iter Episodes
    for iter_num in range(1, config.num_iters+1):
        # else 0.01 works better than 0.0
        epsilon = 0.1 if iter_num<180 else 0.01; t0 = time.time()
        all_grads = []   # (num_episodes_per_iter, 6)
        all_rewards = [] # (num_episodes_per_iter, max_steps_per_episode)

        lr = get_lr(iter_num)
        for param_group in optimizer.param_groups:
            param_group["lr"] = lr

        for episode in range(config.num_episodes_per_iter): # 10
            obs, info = env.reset(); current_rewards = []
            for step in range(config.max_steps_per_episode):
                obs, reward, done, truncated, _ = play_step(dqn, obs, epsilon, replay_buffer)
                current_rewards.append(reward)
                if done or truncated: break
        
            # train step to get loss
            if len(replay_buffer) > config.batch_size:
                grads = train_step(dqn, replay_buffer)
                all_grads.append(grads) # (num_episodes_per_iter, 6)

            all_rewards.append(current_rewards) # ()

        # some logging
        episode_len_avg = sum(map(len, all_rewards))/config.num_episodes_per_iter; t1 = time.time(); dt = t1-t0
        episode_lens.append(episode_len_avg)
        if iter_num % config.logging_interval == 0:
            print(f"| Step: {iter_num:<4}/ {config.num_iters:<4} || Average Episode Length {episode_len_avg:<6.2f} || lr: {lr:<12e} || dt: {dt:<5.2f}s |")     

        # average gradients and apply them to increase the stability of the model (idk if this is usually done but it seems like a good idea)
        apply_grads(all_grads)
    return episode_lens

episode_lens = play()
# Out:
# [W928 13:21:06.614164227 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:06.614181707 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:06.614184507 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:06.614187217 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:06.614189477 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:06.614191727 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.909777956 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.909792056 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.909796596 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.909801036 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.909844335 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.909846815 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.911652883 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.911660873 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.911665023 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.911683282 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.911686462 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:07.911688832 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:08.786451026 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:08.786472046 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:08.786536545 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:08.786543915 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.452280250 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.452293900 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.452297130 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.452345290 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.452348840 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.452351410 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.469458139 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.469467059 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.469471829 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.469475539 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.469478709 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:09.469482449 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# | Step: 1   / 600  || Average Episode Length 10.10  || lr: 1.000000e-02 || dt: 8.07 s |
# [W928 13:21:10.838525246 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.838537606 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.838541356 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.838577446 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.838581056 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.838590145 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.857906390 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.857917670 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.857945839 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.857968609 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.857971819 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:10.857974599 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184352599 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184366239 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184369399 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184417009 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184419629 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184424309 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184452988 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184567098 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184570098 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184609267 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184626677 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:12.184630457 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.787761363 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.787774753 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.787777823 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.787831963 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.787834943 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.787843442 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.788003631 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.788007711 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.788010901 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.788014221 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.788030691 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:13.788034051 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.196431269 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.196452449 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.196502329 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.196506429 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.196510799 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.196641068 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.216558238 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.216566728 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.216587108 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.216604998 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.216608078 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:15.216619598 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# W0928 13:21:16.894000 134878426992640 torch/_dynamo/convert_frame.py:762] [0/8] torch._dynamo hit config.cache_size_limit (8)
# W0928 13:21:16.894000 134878426992640 torch/_dynamo/convert_frame.py:762] [0/8]    function: 'train_step' (/tmp/ipykernel_20185/1436842229.py:1)
# W0928 13:21:16.894000 134878426992640 torch/_dynamo/convert_frame.py:762] [0/8]    last reason: len(L['replay_buffer']) == 69
# W0928 13:21:16.894000 134878426992640 torch/_dynamo/convert_frame.py:762] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0928 13:21:16.894000 134878426992640 torch/_dynamo/convert_frame.py:762] [0/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html.
# [W928 13:21:16.848196790 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848210369 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848213449 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848243069 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848246269 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848255389 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848288939 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848312069 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848316199 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848322809 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848418558 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 13:21:16.848421708 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# | Step: 2   / 600  || Average Episode Length 9.30   || lr: 1.000000e-02 || dt: 6.26 s |
# | Step: 3   / 600  || Average Episode Length 9.60   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 4   / 600  || Average Episode Length 9.90   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 5   / 600  || Average Episode Length 9.60   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 6   / 600  || Average Episode Length 9.70   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 7   / 600  || Average Episode Length 10.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 8   / 600  || Average Episode Length 9.40   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 9   / 600  || Average Episode Length 10.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 10  / 600  || Average Episode Length 10.60  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 11  / 600  || Average Episode Length 9.70   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 12  / 600  || Average Episode Length 9.60   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 13  / 600  || Average Episode Length 10.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 14  / 600  || Average Episode Length 10.20  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 15  / 600  || Average Episode Length 9.50   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 16  / 600  || Average Episode Length 10.90  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 17  / 600  || Average Episode Length 9.90   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 18  / 600  || Average Episode Length 10.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 19  / 600  || Average Episode Length 9.60   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 20  / 600  || Average Episode Length 9.70   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 21  / 600  || Average Episode Length 10.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 22  / 600  || Average Episode Length 11.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 23  / 600  || Average Episode Length 10.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 24  / 600  || Average Episode Length 14.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 25  / 600  || Average Episode Length 19.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 26  / 600  || Average Episode Length 14.60  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 27  / 600  || Average Episode Length 10.60  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 28  / 600  || Average Episode Length 40.80  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 29  / 600  || Average Episode Length 15.50  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 30  / 600  || Average Episode Length 21.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 31  / 600  || Average Episode Length 9.50   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 32  / 600  || Average Episode Length 10.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 33  / 600  || Average Episode Length 40.40  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 34  / 600  || Average Episode Length 9.90   || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 35  / 600  || Average Episode Length 11.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 36  / 600  || Average Episode Length 13.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 37  / 600  || Average Episode Length 10.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 38  / 600  || Average Episode Length 18.10  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 39  / 600  || Average Episode Length 29.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 40  / 600  || Average Episode Length 16.90  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 41  / 600  || Average Episode Length 30.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 42  / 600  || Average Episode Length 43.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 43  / 600  || Average Episode Length 34.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 44  / 600  || Average Episode Length 22.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 45  / 600  || Average Episode Length 23.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 46  / 600  || Average Episode Length 32.90  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 47  / 600  || Average Episode Length 22.90  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 48  / 600  || Average Episode Length 15.50  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 49  / 600  || Average Episode Length 16.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 50  / 600  || Average Episode Length 23.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 51  / 600  || Average Episode Length 41.60  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 52  / 600  || Average Episode Length 28.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 53  / 600  || Average Episode Length 19.50  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 54  / 600  || Average Episode Length 15.20  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 55  / 600  || Average Episode Length 22.60  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 56  / 600  || Average Episode Length 109.90 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 57  / 600  || Average Episode Length 29.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 58  / 600  || Average Episode Length 27.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 59  / 600  || Average Episode Length 95.90  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 60  / 600  || Average Episode Length 23.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 61  / 600  || Average Episode Length 21.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 62  / 600  || Average Episode Length 152.80 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 63  / 600  || Average Episode Length 39.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 64  / 600  || Average Episode Length 28.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 65  / 600  || Average Episode Length 25.10  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 66  / 600  || Average Episode Length 20.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 67  / 600  || Average Episode Length 68.80  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 68  / 600  || Average Episode Length 58.40  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 69  / 600  || Average Episode Length 75.00  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 70  / 600  || Average Episode Length 22.40  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 71  / 600  || Average Episode Length 26.50  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 72  / 600  || Average Episode Length 24.50  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 73  / 600  || Average Episode Length 53.70  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 74  / 600  || Average Episode Length 20.80  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 75  / 600  || Average Episode Length 33.50  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 76  / 600  || Average Episode Length 48.70  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 77  / 600  || Average Episode Length 88.90  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 78  / 600  || Average Episode Length 67.50  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 79  / 600  || Average Episode Length 41.10  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 80  / 600  || Average Episode Length 61.40  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 81  / 600  || Average Episode Length 41.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 82  / 600  || Average Episode Length 30.20  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 83  / 600  || Average Episode Length 22.30  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 84  / 600  || Average Episode Length 55.40  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 85  / 600  || Average Episode Length 85.60  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 86  / 600  || Average Episode Length 40.20  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 87  / 600  || Average Episode Length 29.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 88  / 600  || Average Episode Length 65.10  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 89  / 600  || Average Episode Length 95.00  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 90  / 600  || Average Episode Length 18.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 91  / 600  || Average Episode Length 76.90  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 92  / 600  || Average Episode Length 122.10 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 93  / 600  || Average Episode Length 48.30  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 94  / 600  || Average Episode Length 43.00  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 95  / 600  || Average Episode Length 123.90 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 96  / 600  || Average Episode Length 124.90 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 97  / 600  || Average Episode Length 115.70 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 98  / 600  || Average Episode Length 42.10  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 99  / 600  || Average Episode Length 111.80 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 100 / 600  || Average Episode Length 68.40  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 101 / 600  || Average Episode Length 70.70  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 102 / 600  || Average Episode Length 81.80  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 103 / 600  || Average Episode Length 25.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 104 / 600  || Average Episode Length 31.70  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 105 / 600  || Average Episode Length 177.60 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 106 / 600  || Average Episode Length 36.20  || lr: 1.000000e-02 || dt: 0.01 s |
# | Step: 107 / 600  || Average Episode Length 93.00  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 108 / 600  || Average Episode Length 95.80  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 109 / 600  || Average Episode Length 166.00 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 110 / 600  || Average Episode Length 197.20 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 111 / 600  || Average Episode Length 180.70 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 112 / 600  || Average Episode Length 128.70 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 113 / 600  || Average Episode Length 225.10 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 114 / 600  || Average Episode Length 136.50 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 115 / 600  || Average Episode Length 151.90 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 116 / 600  || Average Episode Length 272.20 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 117 / 600  || Average Episode Length 159.10 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 118 / 600  || Average Episode Length 104.80 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 119 / 600  || Average Episode Length 124.00 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 120 / 600  || Average Episode Length 120.50 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 121 / 600  || Average Episode Length 164.60 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 122 / 600  || Average Episode Length 167.70 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 123 / 600  || Average Episode Length 220.40 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 124 / 600  || Average Episode Length 261.70 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 125 / 600  || Average Episode Length 233.40 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 126 / 600  || Average Episode Length 282.30 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 127 / 600  || Average Episode Length 206.50 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 128 / 600  || Average Episode Length 266.10 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 129 / 600  || Average Episode Length 243.00 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 130 / 600  || Average Episode Length 147.50 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 131 / 600  || Average Episode Length 48.10  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 132 / 600  || Average Episode Length 140.20 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 133 / 600  || Average Episode Length 91.10  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 134 / 600  || Average Episode Length 130.90 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 135 / 600  || Average Episode Length 93.10  || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 136 / 600  || Average Episode Length 142.70 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 137 / 600  || Average Episode Length 120.70 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 138 / 600  || Average Episode Length 172.70 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 139 / 600  || Average Episode Length 192.00 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 140 / 600  || Average Episode Length 138.70 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 141 / 600  || Average Episode Length 117.40 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 142 / 600  || Average Episode Length 140.40 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 143 / 600  || Average Episode Length 143.70 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 144 / 600  || Average Episode Length 260.50 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 145 / 600  || Average Episode Length 245.50 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 146 / 600  || Average Episode Length 166.80 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 147 / 600  || Average Episode Length 231.60 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 148 / 600  || Average Episode Length 353.40 || lr: 1.000000e-02 || dt: 0.09 s |
# | Step: 149 / 600  || Average Episode Length 213.70 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 150 / 600  || Average Episode Length 205.90 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 151 / 600  || Average Episode Length 203.70 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 152 / 600  || Average Episode Length 208.10 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 153 / 600  || Average Episode Length 171.40 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 154 / 600  || Average Episode Length 151.80 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 155 / 600  || Average Episode Length 172.20 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 156 / 600  || Average Episode Length 129.40 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 157 / 600  || Average Episode Length 166.80 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 158 / 600  || Average Episode Length 178.50 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 159 / 600  || Average Episode Length 166.40 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 160 / 600  || Average Episode Length 369.70 || lr: 1.000000e-02 || dt: 0.10 s |
# | Step: 161 / 600  || Average Episode Length 124.20 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 162 / 600  || Average Episode Length 118.10 || lr: 1.000000e-02 || dt: 0.03 s |
# | Step: 163 / 600  || Average Episode Length 113.60 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 164 / 600  || Average Episode Length 244.60 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 165 / 600  || Average Episode Length 134.70 || lr: 1.000000e-02 || dt: 0.04 s |
# | Step: 166 / 600  || Average Episode Length 220.40 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 167 / 600  || Average Episode Length 163.60 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 168 / 600  || Average Episode Length 286.80 || lr: 1.000000e-02 || dt: 0.08 s |
# | Step: 169 / 600  || Average Episode Length 203.20 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 170 / 600  || Average Episode Length 335.50 || lr: 1.000000e-02 || dt: 0.09 s |
# | Step: 171 / 600  || Average Episode Length 197.00 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 172 / 600  || Average Episode Length 366.30 || lr: 1.000000e-02 || dt: 0.09 s |
# | Step: 173 / 600  || Average Episode Length 173.40 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 174 / 600  || Average Episode Length 232.70 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 175 / 600  || Average Episode Length 247.00 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 176 / 600  || Average Episode Length 234.80 || lr: 1.000000e-02 || dt: 0.36 s |
# | Step: 177 / 600  || Average Episode Length 203.30 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 178 / 600  || Average Episode Length 249.40 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 179 / 600  || Average Episode Length 204.40 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 180 / 600  || Average Episode Length 216.90 || lr: 1.000000e-02 || dt: 0.07 s |
# | Step: 181 / 600  || Average Episode Length 203.90 || lr: 1.000000e-02 || dt: 0.06 s |
# | Step: 182 / 600  || Average Episode Length 183.40 || lr: 1.000000e-02 || dt: 0.05 s |
# | Step: 183 / 600  || Average Episode Length 433.70 || lr: 1.000000e-02 || dt: 0.12 s |
# ...
# | Step: 420 / 600  || Average Episode Length 437.70 || lr: 2.067442e-03 || dt: 0.15 s |
# | Step: 421 / 600  || Average Episode Length 500.00 || lr: 2.046243e-03 || dt: 0.17 s |
# | Step: 422 / 600  || Average Episode Length 331.30 || lr: 2.025125e-03 || dt: 0.12 s |
# | Step: 423 / 600  || Average Episode Length 468.60 || lr: 2.004089e-03 || dt: 0.16 s |
# | Step: 424 / 600  || Average Episode Length 415.00 || lr: 1.983135e-03 || dt: 0.14 s |
# | Step: 425 / 600  || Average Episode Length 475.60 || lr: 1.962264e-03 || dt: 0.16 s |
# | Step: 426 / 600  || Average Episode Length 470.50 || lr: 1.941477e-03 || dt: 0.16 s |
# | Step: 427 / 600  || Average Episode Length 449.40 || lr: 1.920774e-03 || dt: 0.16 s |
# | Step: 428 / 600  || Average Episode Length 384.80 || lr: 1.900156e-03 || dt: 0.14 s |
# | Step: 429 / 600  || Average Episode Length 433.90 || lr: 1.879623e-03 || dt: 0.15 s |
# | Step: 430 / 600  || Average Episode Length 397.70 || lr: 1.859176e-03 || dt: 0.14 s |
# | Step: 431 / 600  || Average Episode Length 448.00 || lr: 1.838815e-03 || dt: 0.16 s |
# | Step: 432 / 600  || Average Episode Length 484.60 || lr: 1.818541e-03 || dt: 0.16 s |
# | Step: 433 / 600  || Average Episode Length 456.10 || lr: 1.798355e-03 || dt: 0.16 s |
# | Step: 434 / 600  || Average Episode Length 421.90 || lr: 1.778256e-03 || dt: 0.15 s |
# | Step: 435 / 600  || Average Episode Length 479.00 || lr: 1.758247e-03 || dt: 0.55 s |
# | Step: 436 / 600  || Average Episode Length 446.60 || lr: 1.738326e-03 || dt: 0.15 s |
# | Step: 437 / 600  || Average Episode Length 406.80 || lr: 1.718496e-03 || dt: 0.15 s |
# | Step: 438 / 600  || Average Episode Length 369.50 || lr: 1.698755e-03 || dt: 0.13 s |
# | Step: 439 / 600  || Average Episode Length 407.60 || lr: 1.679105e-03 || dt: 0.15 s |
# | Step: 440 / 600  || Average Episode Length 387.00 || lr: 1.659547e-03 || dt: 0.14 s |
# | Step: 441 / 600  || Average Episode Length 411.50 || lr: 1.640081e-03 || dt: 0.15 s |
# | Step: 442 / 600  || Average Episode Length 414.20 || lr: 1.620707e-03 || dt: 0.15 s |
# | Step: 443 / 600  || Average Episode Length 367.30 || lr: 1.601425e-03 || dt: 0.14 s |
# | Step: 444 / 600  || Average Episode Length 426.90 || lr: 1.582238e-03 || dt: 0.15 s |
# | Step: 445 / 600  || Average Episode Length 412.50 || lr: 1.563144e-03 || dt: 0.17 s |
# | Step: 446 / 600  || Average Episode Length 436.80 || lr: 1.544145e-03 || dt: 0.16 s |
# | Step: 447 / 600  || Average Episode Length 386.30 || lr: 1.525241e-03 || dt: 0.14 s |
# | Step: 448 / 600  || Average Episode Length 431.10 || lr: 1.506433e-03 || dt: 0.15 s |
# | Step: 449 / 600  || Average Episode Length 420.70 || lr: 1.487721e-03 || dt: 0.15 s |
# | Step: 450 / 600  || Average Episode Length 422.80 || lr: 1.469105e-03 || dt: 0.16 s |
# | Step: 451 / 600  || Average Episode Length 424.60 || lr: 1.450586e-03 || dt: 0.16 s |
# | Step: 452 / 600  || Average Episode Length 492.80 || lr: 1.432165e-03 || dt: 0.17 s |
# | Step: 453 / 600  || Average Episode Length 430.90 || lr: 1.413843e-03 || dt: 0.16 s |
# | Step: 454 / 600  || Average Episode Length 403.20 || lr: 1.395618e-03 || dt: 0.15 s |
# | Step: 455 / 600  || Average Episode Length 442.60 || lr: 1.377493e-03 || dt: 0.16 s |
# | Step: 456 / 600  || Average Episode Length 354.80 || lr: 1.359468e-03 || dt: 0.13 s |
# | Step: 457 / 600  || Average Episode Length 362.60 || lr: 1.341543e-03 || dt: 0.14 s |
# | Step: 458 / 600  || Average Episode Length 319.70 || lr: 1.323718e-03 || dt: 0.12 s |
# | Step: 459 / 600  || Average Episode Length 456.00 || lr: 1.305995e-03 || dt: 0.17 s |
# | Step: 460 / 600  || Average Episode Length 388.60 || lr: 1.288373e-03 || dt: 0.14 s |
# | Step: 461 / 600  || Average Episode Length 426.90 || lr: 1.270853e-03 || dt: 0.16 s |
# | Step: 462 / 600  || Average Episode Length 436.20 || lr: 1.253436e-03 || dt: 0.16 s |
# | Step: 463 / 600  || Average Episode Length 395.50 || lr: 1.236122e-03 || dt: 0.15 s |
# | Step: 464 / 600  || Average Episode Length 410.10 || lr: 1.218911e-03 || dt: 0.15 s |
# | Step: 465 / 600  || Average Episode Length 395.20 || lr: 1.201805e-03 || dt: 0.14 s |
# | Step: 466 / 600  || Average Episode Length 399.80 || lr: 1.184803e-03 || dt: 0.14 s |
# | Step: 467 / 600  || Average Episode Length 409.70 || lr: 1.167906e-03 || dt: 0.15 s |
# | Step: 468 / 600  || Average Episode Length 360.50 || lr: 1.151114e-03 || dt: 0.14 s |
# | Step: 469 / 600  || Average Episode Length 462.00 || lr: 1.134428e-03 || dt: 0.16 s |
# | Step: 470 / 600  || Average Episode Length 423.50 || lr: 1.117848e-03 || dt: 0.16 s |
# | Step: 471 / 600  || Average Episode Length 376.00 || lr: 1.101376e-03 || dt: 0.15 s |
# | Step: 472 / 600  || Average Episode Length 395.80 || lr: 1.085010e-03 || dt: 0.15 s |
# | Step: 473 / 600  || Average Episode Length 392.00 || lr: 1.068752e-03 || dt: 0.15 s |
# | Step: 474 / 600  || Average Episode Length 345.60 || lr: 1.052603e-03 || dt: 0.13 s |
# | Step: 475 / 600  || Average Episode Length 481.60 || lr: 1.036561e-03 || dt: 0.17 s |
# | Step: 476 / 600  || Average Episode Length 438.70 || lr: 1.020629e-03 || dt: 0.16 s |
# | Step: 477 / 600  || Average Episode Length 384.20 || lr: 1.004807e-03 || dt: 0.15 s |
# | Step: 478 / 600  || Average Episode Length 395.80 || lr: 9.890941e-04 || dt: 0.15 s |
# | Step: 479 / 600  || Average Episode Length 352.20 || lr: 9.734917e-04 || dt: 0.14 s |
# | Step: 480 / 600  || Average Episode Length 471.90 || lr: 9.580000e-04 || dt: 0.17 s |
# | Step: 481 / 600  || Average Episode Length 443.40 || lr: 9.426196e-04 || dt: 0.17 s |
# | Step: 482 / 600  || Average Episode Length 432.30 || lr: 9.273507e-04 || dt: 0.16 s |
# | Step: 483 / 600  || Average Episode Length 356.40 || lr: 9.121939e-04 || dt: 0.15 s |
# | Step: 484 / 600  || Average Episode Length 383.00 || lr: 8.971495e-04 || dt: 0.15 s |
# | Step: 485 / 600  || Average Episode Length 416.60 || lr: 8.822180e-04 || dt: 0.16 s |
# | Step: 486 / 600  || Average Episode Length 369.10 || lr: 8.673998e-04 || dt: 0.14 s |
# | Step: 487 / 600  || Average Episode Length 433.50 || lr: 8.526952e-04 || dt: 0.16 s |
# | Step: 488 / 600  || Average Episode Length 412.60 || lr: 8.381047e-04 || dt: 0.15 s |
# | Step: 489 / 600  || Average Episode Length 305.60 || lr: 8.236287e-04 || dt: 0.13 s |
# | Step: 490 / 600  || Average Episode Length 440.10 || lr: 8.092675e-04 || dt: 0.16 s |
# | Step: 491 / 600  || Average Episode Length 437.40 || lr: 7.950217e-04 || dt: 0.16 s |
# | Step: 492 / 600  || Average Episode Length 404.70 || lr: 7.808915e-04 || dt: 0.15 s |
# | Step: 493 / 600  || Average Episode Length 405.70 || lr: 7.668774e-04 || dt: 0.16 s |
# | Step: 494 / 600  || Average Episode Length 357.80 || lr: 7.529797e-04 || dt: 0.14 s |
# | Step: 495 / 600  || Average Episode Length 374.70 || lr: 7.391988e-04 || dt: 0.14 s |
# | Step: 496 / 600  || Average Episode Length 335.70 || lr: 7.255351e-04 || dt: 0.14 s |
# | Step: 497 / 600  || Average Episode Length 424.40 || lr: 7.119890e-04 || dt: 0.16 s |
# | Step: 498 / 600  || Average Episode Length 434.10 || lr: 6.985609e-04 || dt: 0.16 s |
# | Step: 499 / 600  || Average Episode Length 424.20 || lr: 6.852511e-04 || dt: 0.16 s |
# | Step: 500 / 600  || Average Episode Length 409.80 || lr: 6.720599e-04 || dt: 0.16 s |
# | Step: 501 / 600  || Average Episode Length 395.20 || lr: 6.589879e-04 || dt: 0.16 s |
# | Step: 502 / 600  || Average Episode Length 324.00 || lr: 6.460352e-04 || dt: 0.13 s |
# | Step: 503 / 600  || Average Episode Length 428.10 || lr: 6.332023e-04 || dt: 0.17 s |
# | Step: 504 / 600  || Average Episode Length 424.30 || lr: 6.204895e-04 || dt: 0.31 s |
# | Step: 505 / 600  || Average Episode Length 384.10 || lr: 6.078972e-04 || dt: 0.15 s |
# | Step: 506 / 600  || Average Episode Length 444.10 || lr: 5.954256e-04 || dt: 0.17 s |
# | Step: 507 / 600  || Average Episode Length 373.70 || lr: 5.830753e-04 || dt: 0.14 s |
# | Step: 508 / 600  || Average Episode Length 405.00 || lr: 5.708464e-04 || dt: 0.15 s |
# | Step: 509 / 600  || Average Episode Length 416.00 || lr: 5.587394e-04 || dt: 0.16 s |
# | Step: 510 / 600  || Average Episode Length 446.00 || lr: 5.467546e-04 || dt: 0.17 s |
# | Step: 511 / 600  || Average Episode Length 348.70 || lr: 5.348922e-04 || dt: 0.14 s |
# | Step: 512 / 600  || Average Episode Length 420.60 || lr: 5.231527e-04 || dt: 0.16 s |
# | Step: 513 / 600  || Average Episode Length 430.40 || lr: 5.115363e-04 || dt: 0.16 s |
# | Step: 514 / 600  || Average Episode Length 448.20 || lr: 5.000433e-04 || dt: 0.17 s |
# | Step: 515 / 600  || Average Episode Length 421.30 || lr: 4.886742e-04 || dt: 0.16 s |
# | Step: 516 / 600  || Average Episode Length 397.60 || lr: 4.774291e-04 || dt: 0.16 s |
# | Step: 517 / 600  || Average Episode Length 432.30 || lr: 4.663085e-04 || dt: 0.16 s |
# | Step: 518 / 600  || Average Episode Length 472.00 || lr: 4.553125e-04 || dt: 0.18 s |
# | Step: 519 / 600  || Average Episode Length 444.10 || lr: 4.444416e-04 || dt: 0.16 s |
# | Step: 520 / 600  || Average Episode Length 439.80 || lr: 4.336960e-04 || dt: 0.17 s |
# | Step: 521 / 600  || Average Episode Length 375.00 || lr: 4.230760e-04 || dt: 0.15 s |
# | Step: 522 / 600  || Average Episode Length 355.70 || lr: 4.125818e-04 || dt: 0.15 s |
# | Step: 523 / 600  || Average Episode Length 426.30 || lr: 4.022139e-04 || dt: 0.16 s |
# | Step: 524 / 600  || Average Episode Length 414.60 || lr: 3.919725e-04 || dt: 0.16 s |
# | Step: 525 / 600  || Average Episode Length 469.60 || lr: 3.818577e-04 || dt: 0.17 s |
# | Step: 526 / 600  || Average Episode Length 432.50 || lr: 3.718701e-04 || dt: 0.17 s |
# | Step: 527 / 600  || Average Episode Length 345.20 || lr: 3.620097e-04 || dt: 0.14 s |
# | Step: 528 / 600  || Average Episode Length 407.90 || lr: 3.522769e-04 || dt: 0.16 s |
# | Step: 529 / 600  || Average Episode Length 466.30 || lr: 3.426720e-04 || dt: 0.17 s |
# | Step: 530 / 600  || Average Episode Length 441.70 || lr: 3.331951e-04 || dt: 0.17 s |
# | Step: 531 / 600  || Average Episode Length 440.50 || lr: 3.238467e-04 || dt: 0.17 s |
# | Step: 532 / 600  || Average Episode Length 425.50 || lr: 3.146268e-04 || dt: 0.17 s |
# | Step: 533 / 600  || Average Episode Length 424.60 || lr: 3.055359e-04 || dt: 0.16 s |
# | Step: 534 / 600  || Average Episode Length 378.80 || lr: 2.965741e-04 || dt: 0.16 s |
# | Step: 535 / 600  || Average Episode Length 438.90 || lr: 2.877416e-04 || dt: 0.17 s |
# | Step: 536 / 600  || Average Episode Length 405.10 || lr: 2.790388e-04 || dt: 0.16 s |
# | Step: 537 / 600  || Average Episode Length 417.40 || lr: 2.704658e-04 || dt: 0.16 s |
# | Step: 538 / 600  || Average Episode Length 395.30 || lr: 2.620230e-04 || dt: 0.17 s |
# | Step: 539 / 600  || Average Episode Length 446.90 || lr: 2.537104e-04 || dt: 0.17 s |
# | Step: 540 / 600  || Average Episode Length 409.00 || lr: 2.455284e-04 || dt: 0.16 s |
# | Step: 541 / 600  || Average Episode Length 377.90 || lr: 2.374772e-04 || dt: 0.15 s |
# | Step: 542 / 600  || Average Episode Length 461.00 || lr: 2.295570e-04 || dt: 0.18 s |
# | Step: 543 / 600  || Average Episode Length 432.00 || lr: 2.217680e-04 || dt: 0.17 s |
# | Step: 544 / 600  || Average Episode Length 369.30 || lr: 2.141105e-04 || dt: 0.16 s |
# | Step: 545 / 600  || Average Episode Length 427.20 || lr: 2.065846e-04 || dt: 0.17 s |
# | Step: 546 / 600  || Average Episode Length 395.00 || lr: 1.991906e-04 || dt: 0.16 s |
# | Step: 547 / 600  || Average Episode Length 353.90 || lr: 1.919286e-04 || dt: 0.15 s |
# | Step: 548 / 600  || Average Episode Length 434.10 || lr: 1.847988e-04 || dt: 0.18 s |
# | Step: 549 / 600  || Average Episode Length 409.10 || lr: 1.778016e-04 || dt: 0.16 s |
# | Step: 550 / 600  || Average Episode Length 386.70 || lr: 1.709369e-04 || dt: 0.16 s |
# | Step: 551 / 600  || Average Episode Length 355.80 || lr: 1.642051e-04 || dt: 0.15 s |
# | Step: 552 / 600  || Average Episode Length 425.80 || lr: 1.576063e-04 || dt: 0.17 s |
# | Step: 553 / 600  || Average Episode Length 391.70 || lr: 1.511408e-04 || dt: 0.16 s |
# | Step: 554 / 600  || Average Episode Length 408.00 || lr: 1.448086e-04 || dt: 0.23 s |
# | Step: 555 / 600  || Average Episode Length 416.30 || lr: 1.386099e-04 || dt: 0.16 s |
# | Step: 556 / 600  || Average Episode Length 406.00 || lr: 1.325450e-04 || dt: 0.16 s |
# | Step: 557 / 600  || Average Episode Length 391.30 || lr: 1.266139e-04 || dt: 0.62 s |
# | Step: 558 / 600  || Average Episode Length 345.70 || lr: 1.208170e-04 || dt: 0.15 s |
# | Step: 559 / 600  || Average Episode Length 442.90 || lr: 1.151542e-04 || dt: 0.19 s |
# | Step: 560 / 600  || Average Episode Length 388.00 || lr: 1.096258e-04 || dt: 0.16 s |
# | Step: 561 / 600  || Average Episode Length 452.30 || lr: 1.042319e-04 || dt: 0.18 s |
# | Step: 562 / 600  || Average Episode Length 419.20 || lr: 9.897267e-05 || dt: 0.17 s |
# | Step: 563 / 600  || Average Episode Length 441.60 || lr: 9.384827e-05 || dt: 0.18 s |
# | Step: 564 / 600  || Average Episode Length 447.30 || lr: 8.885882e-05 || dt: 0.17 s |
# | Step: 565 / 600  || Average Episode Length 438.00 || lr: 8.400446e-05 || dt: 0.18 s |
# | Step: 566 / 600  || Average Episode Length 457.80 || lr: 7.928533e-05 || dt: 0.18 s |
# | Step: 567 / 600  || Average Episode Length 403.80 || lr: 7.470155e-05 || dt: 0.17 s |
# | Step: 568 / 600  || Average Episode Length 387.90 || lr: 7.025325e-05 || dt: 0.16 s |
# | Step: 569 / 600  || Average Episode Length 425.20 || lr: 6.594055e-05 || dt: 0.17 s |
# | Step: 570 / 600  || Average Episode Length 401.20 || lr: 6.176358e-05 || dt: 0.16 s |
# | Step: 571 / 600  || Average Episode Length 471.50 || lr: 5.772244e-05 || dt: 0.19 s |
# | Step: 572 / 600  || Average Episode Length 384.20 || lr: 5.381726e-05 || dt: 0.16 s |
# | Step: 573 / 600  || Average Episode Length 428.10 || lr: 5.004812e-05 || dt: 0.17 s |
# | Step: 574 / 600  || Average Episode Length 391.90 || lr: 4.641515e-05 || dt: 0.16 s |
# | Step: 575 / 600  || Average Episode Length 384.80 || lr: 4.291843e-05 || dt: 0.16 s |
# | Step: 576 / 600  || Average Episode Length 435.20 || lr: 3.955807e-05 || dt: 0.18 s |
# | Step: 577 / 600  || Average Episode Length 393.40 || lr: 3.633416e-05 || dt: 0.17 s |
# | Step: 578 / 600  || Average Episode Length 345.60 || lr: 3.324678e-05 || dt: 0.15 s |
# | Step: 579 / 600  || Average Episode Length 389.20 || lr: 3.029602e-05 || dt: 0.17 s |
# | Step: 580 / 600  || Average Episode Length 435.00 || lr: 2.748197e-05 || dt: 0.17 s |
# | Step: 581 / 600  || Average Episode Length 401.60 || lr: 2.480470e-05 || dt: 0.17 s |
# | Step: 582 / 600  || Average Episode Length 469.40 || lr: 2.226427e-05 || dt: 0.19 s |
# | Step: 583 / 600  || Average Episode Length 392.10 || lr: 1.986078e-05 || dt: 0.17 s |
# | Step: 584 / 600  || Average Episode Length 462.30 || lr: 1.759427e-05 || dt: 0.18 s |
# | Step: 585 / 600  || Average Episode Length 460.30 || lr: 1.546481e-05 || dt: 0.18 s |
# | Step: 586 / 600  || Average Episode Length 398.20 || lr: 1.347246e-05 || dt: 0.17 s |
# | Step: 587 / 600  || Average Episode Length 350.60 || lr: 1.161728e-05 || dt: 0.16 s |
# | Step: 588 / 600  || Average Episode Length 396.70 || lr: 9.899317e-06 || dt: 0.17 s |
# | Step: 589 / 600  || Average Episode Length 376.10 || lr: 8.318615e-06 || dt: 0.16 s |
# | Step: 590 / 600  || Average Episode Length 424.90 || lr: 6.875219e-06 || dt: 0.17 s |
# | Step: 591 / 600  || Average Episode Length 383.40 || lr: 5.569170e-06 || dt: 0.17 s |
# | Step: 592 / 600  || Average Episode Length 410.10 || lr: 4.400503e-06 || dt: 0.17 s |
# | Step: 593 / 600  || Average Episode Length 361.70 || lr: 3.369251e-06 || dt: 0.16 s |
# | Step: 594 / 600  || Average Episode Length 406.50 || lr: 2.475442e-06 || dt: 0.17 s |
# | Step: 595 / 600  || Average Episode Length 390.20 || lr: 1.719100e-06 || dt: 0.17 s |
# | Step: 596 / 600  || Average Episode Length 344.00 || lr: 1.100247e-06 || dt: 0.16 s |
# | Step: 597 / 600  || Average Episode Length 369.40 || lr: 6.188988e-07 || dt: 0.16 s |
# | Step: 598 / 600  || Average Episode Length 434.00 || lr: 2.750693e-07 || dt: 0.18 s |
# | Step: 599 / 600  || Average Episode Length 423.70 || lr: 6.876780e-08 || dt: 0.18 s |
# | Step: 600 / 600  || Average Episode Length 396.60 || lr: 0.000000e+00 || dt: 0.17 s |

# %%
plt.plot(episode_lens)
plt.xlabel("Iterations")
plt.ylabel("Average Episode Length")
plt.yticks(range(0, 501, 50))
plt.grid(True)
plt.show()

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0), repeat=False)
# Out:
# done at step 500
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0), repeat=False)
# Out:
# done at step 500
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0), repeat=False)
# Out:
# done at step 500
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
