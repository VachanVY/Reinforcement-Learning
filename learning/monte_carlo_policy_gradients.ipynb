# %% [markdown]
# # Import Modules

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
import typing as tp
import time
import random
import math

import torch
from torch import nn, Tensor

SEED = 42
random.seed(SEED)
np.random.seed(SEED+1)
torch.manual_seed(SEED+2)
torch.use_deterministic_algorithms(mode=True, warn_only=False)

# %% [markdown]
# # Ops

# %%
def plot_environment(env:gym.Env, figsize:tuple[int, int]=(5, 4)):
    plt.figure(figsize=figsize)
    img = env.render()
    plt.imshow(img)
    plt.axis("off")
    return img

def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames:list, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    animation = anim.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    return animation

def show_one_episode(action_sampler:tp.Callable, n_max_steps=500, repeat=False):
    frames = []
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    obs, info = env.reset()
    with torch.no_grad():
        for step in range(n_max_steps):
            frames.append(env.render())
            action = action_sampler(obs)
            obs, reward, done, truncated, info = env.step(action)
            if done or truncated:
                print("done at step", step+1)
                break
    env.close()
    return plot_animation(frames, repeat=repeat)

# %% [markdown]
# # Cartpole Environment
# * GOAL: Keep the pole upright for as long as possible
# ```python
# Actions:
#     left: 0
#     right: 1
#
# Observation Space: (4,)
# ```
# ![image.png](attachment:image.png)
# * The cart x-position (index 0) can be take values between (-4.8, 4.8), but the episode terminates if the cart leaves the (-2.4, 2.4) range.
# * The pole angle can be observed between (-.418, .418) radians (or ±24°), but the episode terminates if the pole angle is not in the range (-.2095, .2095) (or ±12°)
#
# ## Rewards
# * Since the goal is to keep the pole upright for as long as possible, a reward of +1 for every step taken, including the termination step, is allotted
#
# ## Episode End
# * The episode ends if any one of the following occurs:
#     * Termination: Pole Angle is greater than ±12°
#     * Termination: Cart Position is greater than ±2.4 (center of the cart reaches the edge of the display)
#     * Truncation: Episode length is greater than 500

# %% [markdown]
# # Monte Carlo Policy Gradient Method

# %%
class config:
    num_iters:int = 800
    num_episodes_per_iter:int = 10
    max_steps_per_episode:int = 1000
    
    gamma:float = 0.95
    
    lr:float = 0.01
    weight_decay:float = 0.0

    device:torch.device = torch.device("cuda" if False else "cpu") # cpu good for very very small models
    dtype:torch.dtype = torch.float32 if "cpu" in device.type else torch.float16

    generator:torch.Generator = torch.Generator(device=device)
    generator.manual_seed(SEED+3)

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, info = env.reset(seed=1)
obs, obs.shape, info
# Out:
# (array([ 0.00118216,  0.04504637, -0.03558404,  0.04486495], dtype=float32),
#  (4,),
#  {})

# %%
class Policy(nn.Module):
    def __init__(self, num_inputs:int, num_hidden:int, num_outputs:int):
        super().__init__()
        self.linear1 = nn.Linear(num_inputs, num_hidden)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(num_hidden, num_outputs)
        self.last_act_func = nn.Sigmoid() if num_outputs == 1 else nn.Softmax(dim=-1)

    def forward(self, x:Tensor): # (B, num_inputs=4)
        x = self.relu(self.linear1(x)) # (B, num_hidden=8)
        x = self.last_act_func(self.linear2(x)) # (B, num_outputs=1)
        return x

# %%
class CosineDecayWithWarmup:
    def __init__(
        self,
        warmup_steps:int,
        max_learning_rate:float,
        decay_steps:int,
        min_learning_rate:float
    ):
        self.warmup_steps = warmup_steps
        self.max_learning_rate = max_learning_rate
        self.decay_steps = decay_steps
        self.min_learning_rate = min_learning_rate

    def __call__(self, step):
        # linear warmup for warmup_steps steps
        if step < self.warmup_steps:
            return self.max_learning_rate * step / self.warmup_steps
        # if it > decay_steps, return min learning rate
        if step > self.decay_steps:
            return self.min_learning_rate
        # in between, use cosine decay down to min learning rate
        decay_ratio = (step - self.warmup_steps) / (self.decay_steps - self.warmup_steps)
        coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
        return self.min_learning_rate + coeff * (self.max_learning_rate - self.min_learning_rate)

# %%
pi = Policy(
    num_inputs=env.observation_space.shape[0], # 4
    num_hidden=env.observation_space.shape[0]*2, # 8
    num_outputs=1 if env.action_space.n == 2 else env.action_space.n, #  (left, right)
)
pi.to(config.device)
optimizer = torch.optim.NAdam(
    pi.parameters(),
    lr=config.lr, 
    weight_decay=config.weight_decay,
    maximize=True # grad ascent
)
autocast = torch.autocast(device_type=config.device.type, dtype=config.dtype)
get_lr = CosineDecayWithWarmup(
    warmup_steps=1,
    max_learning_rate=config.lr,
    decay_steps=config.num_iters,
    min_learning_rate=config.lr*0.1
)
print(pi, sum(p.numel() for p in pi.parameters()), sep="\nNumber of parameters: ")
# Out:
# Policy(
#   (linear1): Linear(in_features=4, out_features=8, bias=True)
#   (relu): ReLU()
#   (linear2): Linear(in_features=8, out_features=1, bias=True)
#   (last_act_func): Sigmoid()
# )
# Number of parameters: 49

# %% [markdown]
# ![Alt](images/monte_carlo_policy_gradient.png)

# %%
@torch.compile
def loss_fn(pi:Policy, obs:Tensor) -> tuple[Tensor, Tensor]:
    left_proba = pi(obs.unsqueeze(0)) # (1, 1)
    action = torch.rand(size=(1, 1), device=config.device, generator=config.generator) > left_proba # If `left_proba` is high, then `action` will most likely be `False` or 0, which means left
    y_target = 1.0 if action==False else 0.0  # If `action` is left, then `y_target` will be 1.0 
    loss = torch.log(left_proba) * y_target + torch.log(1.0 - left_proba) * (1.0 - y_target)
    return loss.mean(), action

def play_one_episode(
    env:gym.Env,
    pi:Policy,
    obs:np.ndarray,
):
    obs = torch.as_tensor(obs, device=config.device)
    with autocast:
        loss, action_taken = loss_fn(pi, obs)
    loss.backward()
    grads = [p.grad for p in pi.parameters()]; pi.zero_grad()
    action_taken = int(action_taken.item())
    obs, reward, done, truncated, info = env.step(action_taken)
    return (obs, reward, done, truncated), (loss, grads)

def discount_rewards(rewards:list, discount_factor:float):
    discounted = np.array(rewards)
    for step in range(len(rewards) - 2, -1, -1):
        discounted[step] += discounted[step + 1] * discount_factor
    return discounted

def apply_grads(grads:list[list[Tensor]], rewards:list[list[Tensor]]):
    param_list_len = len([p for p in pi.parameters()])
    to_be_applied_grads:list[list[Tensor]] = [[] for _ in range(param_list_len)] # initialize list

    for n_ep_per_iter, grads_in_ep in enumerate(grads):
        for step, grads_in_step in enumerate(grads_in_ep):
            for i, grad in enumerate(grads_in_step):
                to_be_applied_grads[i].append(grad*rewards[n_ep_per_iter][step])

    grads:list[Tensor] = [torch.stack(grad_list).mean(dim=0) for grad_list in to_be_applied_grads]
    
    for p, grad in zip(pi.parameters(), grads):
        p.grad = grad

    optimizer.step()
    optimizer.zero_grad()

# %%
def play():
    episode_length_avgs = []
    for iter_num in range(1, config.num_iters+1):
        t0 = time.time()
        all_rewards, all_grads = [], []
        lr = get_lr(iter_num)
        for param_group in optimizer.param_groups:
            param_group["lr"] = lr

        for episode in range(config.num_episodes_per_iter):
            current_grads, current_rewards = [], []
            obs, info = env.reset()
            for step in range(config.max_steps_per_episode):
                (
                    (obs, reward, done, truncated), (loss, grads)
                ) = play_one_episode(env, pi, obs)
                current_grads.append(grads); current_rewards.append(reward)
                if done or truncated:
                    break
            
            all_rewards.append(current_rewards); all_grads.append(current_grads)
        t1 = time.time(); dt = t1-t0
        episode_len_avg = sum(map(len, all_rewards))/config.num_episodes_per_iter; episode_length_avgs.append(episode_len_avg)
        print(f"| Step: {iter_num}/{config.num_iters} || Average Episode Length {episode_len_avg:.2f} || lr: {lr:e} || dt: {dt:.2f}s |")

        all_rewards = list(map(lambda r:discount_rewards(r, config.gamma), all_rewards))

        flattened_rewards = np.concatenate(all_rewards)
        all_rewards = [r - flattened_rewards.mean()/ flattened_rewards.std() for r in all_rewards]
        apply_grads(all_grads, all_rewards)
    return episode_length_avgs

avg_episode_lengths = play()
# Out:
# | Step: 1/800 || Average Episode Length 20.50 || lr: 1.000000e-02 || dt: 4.12s |
# | Step: 2/800 || Average Episode Length 20.10 || lr: 9.999965e-03 || dt: 0.03s |
# | Step: 3/800 || Average Episode Length 22.50 || lr: 9.999861e-03 || dt: 0.03s |
# | Step: 4/800 || Average Episode Length 18.10 || lr: 9.999687e-03 || dt: 0.02s |
# | Step: 5/800 || Average Episode Length 26.60 || lr: 9.999443e-03 || dt: 0.04s |
# | Step: 6/800 || Average Episode Length 19.10 || lr: 9.999130e-03 || dt: 0.03s |
# | Step: 7/800 || Average Episode Length 16.50 || lr: 9.998748e-03 || dt: 0.02s |
# | Step: 8/800 || Average Episode Length 19.90 || lr: 9.998296e-03 || dt: 0.03s |
# | Step: 9/800 || Average Episode Length 24.30 || lr: 9.997774e-03 || dt: 0.03s |
# | Step: 10/800 || Average Episode Length 22.50 || lr: 9.997183e-03 || dt: 0.03s |
# | Step: 11/800 || Average Episode Length 24.40 || lr: 9.996522e-03 || dt: 0.03s |
# | Step: 12/800 || Average Episode Length 17.00 || lr: 9.995792e-03 || dt: 0.02s |
# | Step: 13/800 || Average Episode Length 15.70 || lr: 9.994992e-03 || dt: 0.02s |
# | Step: 14/800 || Average Episode Length 30.30 || lr: 9.994123e-03 || dt: 0.04s |
# | Step: 15/800 || Average Episode Length 28.40 || lr: 9.993184e-03 || dt: 0.04s |
# | Step: 16/800 || Average Episode Length 24.00 || lr: 9.992176e-03 || dt: 0.03s |
# | Step: 17/800 || Average Episode Length 23.20 || lr: 9.991098e-03 || dt: 0.03s |
# | Step: 18/800 || Average Episode Length 21.90 || lr: 9.989951e-03 || dt: 0.03s |
# | Step: 19/800 || Average Episode Length 19.90 || lr: 9.988734e-03 || dt: 0.03s |
# | Step: 20/800 || Average Episode Length 23.00 || lr: 9.987449e-03 || dt: 0.03s |
# | Step: 21/800 || Average Episode Length 27.20 || lr: 9.986093e-03 || dt: 0.04s |
# | Step: 22/800 || Average Episode Length 33.20 || lr: 9.984669e-03 || dt: 0.05s |
# | Step: 23/800 || Average Episode Length 23.10 || lr: 9.983175e-03 || dt: 0.03s |
# | Step: 24/800 || Average Episode Length 28.70 || lr: 9.981611e-03 || dt: 0.04s |
# | Step: 25/800 || Average Episode Length 22.40 || lr: 9.979979e-03 || dt: 0.04s |
# | Step: 26/800 || Average Episode Length 23.40 || lr: 9.978277e-03 || dt: 0.03s |
# | Step: 27/800 || Average Episode Length 29.80 || lr: 9.976506e-03 || dt: 0.04s |
# | Step: 28/800 || Average Episode Length 29.40 || lr: 9.974666e-03 || dt: 0.04s |
# | Step: 29/800 || Average Episode Length 25.80 || lr: 9.972756e-03 || dt: 0.03s |
# | Step: 30/800 || Average Episode Length 27.90 || lr: 9.970778e-03 || dt: 0.04s |
# | Step: 31/800 || Average Episode Length 38.00 || lr: 9.968730e-03 || dt: 0.05s |
# | Step: 32/800 || Average Episode Length 26.40 || lr: 9.966613e-03 || dt: 0.04s |
# | Step: 33/800 || Average Episode Length 37.30 || lr: 9.964427e-03 || dt: 0.05s |
# | Step: 34/800 || Average Episode Length 27.30 || lr: 9.962173e-03 || dt: 0.04s |
# | Step: 35/800 || Average Episode Length 35.20 || lr: 9.959849e-03 || dt: 0.05s |
# | Step: 36/800 || Average Episode Length 36.00 || lr: 9.957456e-03 || dt: 0.05s |
# | Step: 37/800 || Average Episode Length 24.50 || lr: 9.954994e-03 || dt: 0.03s |
# | Step: 38/800 || Average Episode Length 35.90 || lr: 9.952464e-03 || dt: 0.05s |
# | Step: 39/800 || Average Episode Length 37.90 || lr: 9.949864e-03 || dt: 0.05s |
# | Step: 40/800 || Average Episode Length 44.40 || lr: 9.947196e-03 || dt: 0.06s |
# | Step: 41/800 || Average Episode Length 34.90 || lr: 9.944459e-03 || dt: 0.05s |
# | Step: 42/800 || Average Episode Length 32.90 || lr: 9.941653e-03 || dt: 0.04s |
# | Step: 43/800 || Average Episode Length 34.70 || lr: 9.938779e-03 || dt: 0.05s |
# | Step: 44/800 || Average Episode Length 36.00 || lr: 9.935836e-03 || dt: 0.05s |
# | Step: 45/800 || Average Episode Length 34.30 || lr: 9.932825e-03 || dt: 0.05s |
# | Step: 46/800 || Average Episode Length 41.10 || lr: 9.929744e-03 || dt: 0.06s |
# | Step: 47/800 || Average Episode Length 38.00 || lr: 9.926596e-03 || dt: 0.05s |
# | Step: 48/800 || Average Episode Length 51.20 || lr: 9.923379e-03 || dt: 0.07s |
# | Step: 49/800 || Average Episode Length 42.40 || lr: 9.920094e-03 || dt: 0.06s |
# | Step: 50/800 || Average Episode Length 57.00 || lr: 9.916740e-03 || dt: 0.08s |
# | Step: 51/800 || Average Episode Length 41.30 || lr: 9.913318e-03 || dt: 0.06s |
# | Step: 52/800 || Average Episode Length 49.80 || lr: 9.909828e-03 || dt: 0.07s |
# | Step: 53/800 || Average Episode Length 52.60 || lr: 9.906269e-03 || dt: 0.07s |
# | Step: 54/800 || Average Episode Length 49.90 || lr: 9.902643e-03 || dt: 0.07s |
# | Step: 55/800 || Average Episode Length 45.50 || lr: 9.898948e-03 || dt: 0.06s |
# | Step: 56/800 || Average Episode Length 67.20 || lr: 9.895186e-03 || dt: 0.24s |
# | Step: 57/800 || Average Episode Length 45.10 || lr: 9.891355e-03 || dt: 0.06s |
# | Step: 58/800 || Average Episode Length 62.50 || lr: 9.887457e-03 || dt: 0.09s |
# | Step: 59/800 || Average Episode Length 60.80 || lr: 9.883490e-03 || dt: 0.09s |
# | Step: 60/800 || Average Episode Length 50.70 || lr: 9.879456e-03 || dt: 0.07s |
# | Step: 61/800 || Average Episode Length 64.00 || lr: 9.875355e-03 || dt: 0.09s |
# | Step: 62/800 || Average Episode Length 57.50 || lr: 9.871185e-03 || dt: 0.08s |
# | Step: 63/800 || Average Episode Length 62.10 || lr: 9.866948e-03 || dt: 0.08s |
# | Step: 64/800 || Average Episode Length 59.60 || lr: 9.862644e-03 || dt: 0.08s |
# | Step: 65/800 || Average Episode Length 43.10 || lr: 9.858272e-03 || dt: 0.06s |
# | Step: 66/800 || Average Episode Length 61.80 || lr: 9.853833e-03 || dt: 0.08s |
# | Step: 67/800 || Average Episode Length 65.30 || lr: 9.849326e-03 || dt: 0.09s |
# | Step: 68/800 || Average Episode Length 67.50 || lr: 9.844752e-03 || dt: 0.09s |
# | Step: 69/800 || Average Episode Length 57.60 || lr: 9.840111e-03 || dt: 0.08s |
# | Step: 70/800 || Average Episode Length 74.50 || lr: 9.835403e-03 || dt: 0.10s |
# | Step: 71/800 || Average Episode Length 71.50 || lr: 9.830628e-03 || dt: 0.10s |
# | Step: 72/800 || Average Episode Length 69.50 || lr: 9.825786e-03 || dt: 0.10s |
# | Step: 73/800 || Average Episode Length 78.40 || lr: 9.820877e-03 || dt: 0.11s |
# | Step: 74/800 || Average Episode Length 68.90 || lr: 9.815901e-03 || dt: 0.09s |
# | Step: 75/800 || Average Episode Length 101.00 || lr: 9.810859e-03 || dt: 0.14s |
# | Step: 76/800 || Average Episode Length 51.50 || lr: 9.805750e-03 || dt: 0.07s |
# | Step: 77/800 || Average Episode Length 78.90 || lr: 9.800574e-03 || dt: 0.11s |
# | Step: 78/800 || Average Episode Length 75.50 || lr: 9.795332e-03 || dt: 0.10s |
# | Step: 79/800 || Average Episode Length 103.20 || lr: 9.790023e-03 || dt: 0.14s |
# | Step: 80/800 || Average Episode Length 93.30 || lr: 9.784648e-03 || dt: 0.13s |
# | Step: 81/800 || Average Episode Length 94.40 || lr: 9.779207e-03 || dt: 0.13s |
# | Step: 82/800 || Average Episode Length 80.30 || lr: 9.773700e-03 || dt: 0.11s |
# | Step: 83/800 || Average Episode Length 83.10 || lr: 9.768127e-03 || dt: 0.11s |
# | Step: 84/800 || Average Episode Length 98.60 || lr: 9.762487e-03 || dt: 0.14s |
# | Step: 85/800 || Average Episode Length 113.50 || lr: 9.756782e-03 || dt: 0.16s |
# | Step: 86/800 || Average Episode Length 131.70 || lr: 9.751011e-03 || dt: 0.18s |
# | Step: 87/800 || Average Episode Length 87.40 || lr: 9.745174e-03 || dt: 0.12s |
# | Step: 88/800 || Average Episode Length 112.50 || lr: 9.739272e-03 || dt: 0.15s |
# | Step: 89/800 || Average Episode Length 110.90 || lr: 9.733304e-03 || dt: 0.15s |
# | Step: 90/800 || Average Episode Length 112.60 || lr: 9.727270e-03 || dt: 0.16s |
# | Step: 91/800 || Average Episode Length 124.00 || lr: 9.721172e-03 || dt: 0.17s |
# | Step: 92/800 || Average Episode Length 120.80 || lr: 9.715008e-03 || dt: 0.17s |
# | Step: 93/800 || Average Episode Length 107.00 || lr: 9.708778e-03 || dt: 0.15s |
# | Step: 94/800 || Average Episode Length 129.20 || lr: 9.702484e-03 || dt: 0.18s |
# | Step: 95/800 || Average Episode Length 165.60 || lr: 9.696125e-03 || dt: 0.23s |
# | Step: 96/800 || Average Episode Length 179.50 || lr: 9.689701e-03 || dt: 0.39s |
# | Step: 97/800 || Average Episode Length 144.20 || lr: 9.683212e-03 || dt: 0.21s |
# | Step: 98/800 || Average Episode Length 187.10 || lr: 9.676659e-03 || dt: 0.27s |
# | Step: 99/800 || Average Episode Length 147.80 || lr: 9.670040e-03 || dt: 0.21s |
# | Step: 100/800 || Average Episode Length 154.70 || lr: 9.663358e-03 || dt: 0.22s |
# | Step: 101/800 || Average Episode Length 159.30 || lr: 9.656611e-03 || dt: 0.22s |
# | Step: 102/800 || Average Episode Length 161.90 || lr: 9.649800e-03 || dt: 0.24s |
# | Step: 103/800 || Average Episode Length 184.30 || lr: 9.642924e-03 || dt: 0.25s |
# | Step: 104/800 || Average Episode Length 182.10 || lr: 9.635985e-03 || dt: 0.25s |
# | Step: 105/800 || Average Episode Length 133.50 || lr: 9.628982e-03 || dt: 0.18s |
# | Step: 106/800 || Average Episode Length 243.80 || lr: 9.621915e-03 || dt: 0.33s |
# | Step: 107/800 || Average Episode Length 217.70 || lr: 9.614784e-03 || dt: 0.30s |
# | Step: 108/800 || Average Episode Length 239.40 || lr: 9.607589e-03 || dt: 0.48s |
# | Step: 109/800 || Average Episode Length 269.60 || lr: 9.600331e-03 || dt: 0.37s |
# | Step: 110/800 || Average Episode Length 198.80 || lr: 9.593010e-03 || dt: 0.28s |
# | Step: 111/800 || Average Episode Length 314.40 || lr: 9.585625e-03 || dt: 0.43s |
# | Step: 112/800 || Average Episode Length 297.70 || lr: 9.578177e-03 || dt: 0.42s |
# | Step: 113/800 || Average Episode Length 200.70 || lr: 9.570666e-03 || dt: 0.28s |
# | Step: 114/800 || Average Episode Length 269.50 || lr: 9.563093e-03 || dt: 0.38s |
# | Step: 115/800 || Average Episode Length 298.00 || lr: 9.555456e-03 || dt: 0.42s |
# | Step: 116/800 || Average Episode Length 295.20 || lr: 9.547757e-03 || dt: 0.57s |
# | Step: 117/800 || Average Episode Length 275.00 || lr: 9.539995e-03 || dt: 0.39s |
# | Step: 118/800 || Average Episode Length 184.90 || lr: 9.532170e-03 || dt: 0.26s |
# | Step: 119/800 || Average Episode Length 263.50 || lr: 9.524284e-03 || dt: 0.37s |
# | Step: 120/800 || Average Episode Length 230.70 || lr: 9.516335e-03 || dt: 0.33s |
# | Step: 121/800 || Average Episode Length 216.50 || lr: 9.508324e-03 || dt: 0.31s |
# | Step: 122/800 || Average Episode Length 267.10 || lr: 9.500251e-03 || dt: 0.38s |
# | Step: 123/800 || Average Episode Length 217.70 || lr: 9.492116e-03 || dt: 0.31s |
# | Step: 124/800 || Average Episode Length 238.10 || lr: 9.483919e-03 || dt: 0.48s |
# | Step: 125/800 || Average Episode Length 293.00 || lr: 9.475661e-03 || dt: 0.42s |
# | Step: 126/800 || Average Episode Length 271.90 || lr: 9.467342e-03 || dt: 0.39s |
# | Step: 127/800 || Average Episode Length 214.20 || lr: 9.458961e-03 || dt: 0.31s |
# | Step: 128/800 || Average Episode Length 226.80 || lr: 9.450519e-03 || dt: 0.33s |
# | Step: 129/800 || Average Episode Length 180.80 || lr: 9.442015e-03 || dt: 0.27s |
# | Step: 130/800 || Average Episode Length 203.80 || lr: 9.433451e-03 || dt: 0.29s |
# | Step: 131/800 || Average Episode Length 198.70 || lr: 9.424826e-03 || dt: 0.28s |
# | Step: 132/800 || Average Episode Length 215.10 || lr: 9.416141e-03 || dt: 0.30s |
# | Step: 133/800 || Average Episode Length 182.80 || lr: 9.407395e-03 || dt: 0.25s |
# | Step: 134/800 || Average Episode Length 214.50 || lr: 9.398588e-03 || dt: 0.30s |
# | Step: 135/800 || Average Episode Length 193.20 || lr: 9.389721e-03 || dt: 0.27s |
# | Step: 136/800 || Average Episode Length 238.60 || lr: 9.380794e-03 || dt: 0.34s |
# | Step: 137/800 || Average Episode Length 285.50 || lr: 9.371807e-03 || dt: 0.40s |
# | Step: 138/800 || Average Episode Length 248.30 || lr: 9.362760e-03 || dt: 0.35s |
# | Step: 139/800 || Average Episode Length 296.20 || lr: 9.353654e-03 || dt: 0.41s |
# | Step: 140/800 || Average Episode Length 240.60 || lr: 9.344488e-03 || dt: 0.47s |
# | Step: 141/800 || Average Episode Length 214.20 || lr: 9.335262e-03 || dt: 0.30s |
# | Step: 142/800 || Average Episode Length 285.30 || lr: 9.325977e-03 || dt: 0.39s |
# | Step: 143/800 || Average Episode Length 316.80 || lr: 9.316633e-03 || dt: 0.43s |
# | Step: 144/800 || Average Episode Length 275.60 || lr: 9.307230e-03 || dt: 0.39s |
# | Step: 145/800 || Average Episode Length 214.80 || lr: 9.297768e-03 || dt: 0.30s |
# | Step: 146/800 || Average Episode Length 331.00 || lr: 9.288248e-03 || dt: 0.46s |
# | Step: 147/800 || Average Episode Length 261.20 || lr: 9.278668e-03 || dt: 0.49s |
# | Step: 148/800 || Average Episode Length 254.00 || lr: 9.269031e-03 || dt: 0.35s |
# | Step: 149/800 || Average Episode Length 285.90 || lr: 9.259335e-03 || dt: 0.39s |
# | Step: 150/800 || Average Episode Length 255.50 || lr: 9.249581e-03 || dt: 0.35s |
# | Step: 151/800 || Average Episode Length 323.40 || lr: 9.239769e-03 || dt: 0.44s |
# | Step: 152/800 || Average Episode Length 292.80 || lr: 9.229899e-03 || dt: 0.40s |
# | Step: 153/800 || Average Episode Length 307.70 || lr: 9.219972e-03 || dt: 0.56s |
# | Step: 154/800 || Average Episode Length 236.40 || lr: 9.209987e-03 || dt: 0.33s |
# | Step: 155/800 || Average Episode Length 160.90 || lr: 9.199945e-03 || dt: 0.22s |
# | Step: 156/800 || Average Episode Length 174.10 || lr: 9.189845e-03 || dt: 0.24s |
# | Step: 157/800 || Average Episode Length 147.40 || lr: 9.179689e-03 || dt: 0.20s |
# | Step: 158/800 || Average Episode Length 171.80 || lr: 9.169475e-03 || dt: 0.24s |
# | Step: 159/800 || Average Episode Length 157.90 || lr: 9.159205e-03 || dt: 0.22s |
# | Step: 160/800 || Average Episode Length 151.50 || lr: 9.148878e-03 || dt: 0.21s |
# | Step: 161/800 || Average Episode Length 172.10 || lr: 9.138495e-03 || dt: 0.23s |
# | Step: 162/800 || Average Episode Length 181.70 || lr: 9.128056e-03 || dt: 0.26s |
# | Step: 163/800 || Average Episode Length 211.40 || lr: 9.117561e-03 || dt: 0.29s |
# | Step: 164/800 || Average Episode Length 194.90 || lr: 9.107009e-03 || dt: 0.40s |
# | Step: 165/800 || Average Episode Length 158.70 || lr: 9.096402e-03 || dt: 0.22s |
# | Step: 166/800 || Average Episode Length 173.00 || lr: 9.085739e-03 || dt: 0.24s |
# | Step: 167/800 || Average Episode Length 160.90 || lr: 9.075021e-03 || dt: 0.22s |
# | Step: 168/800 || Average Episode Length 181.00 || lr: 9.064248e-03 || dt: 0.25s |
# | Step: 169/800 || Average Episode Length 163.40 || lr: 9.053419e-03 || dt: 0.23s |
# | Step: 170/800 || Average Episode Length 211.50 || lr: 9.042535e-03 || dt: 0.29s |
# | Step: 171/800 || Average Episode Length 173.50 || lr: 9.031597e-03 || dt: 0.25s |
# | Step: 172/800 || Average Episode Length 200.30 || lr: 9.020604e-03 || dt: 0.28s |
# | Step: 173/800 || Average Episode Length 245.10 || lr: 9.009557e-03 || dt: 0.34s |
# | Step: 174/800 || Average Episode Length 254.40 || lr: 8.998456e-03 || dt: 0.36s |
# | Step: 175/800 || Average Episode Length 254.00 || lr: 8.987300e-03 || dt: 0.36s |
# | Step: 176/800 || Average Episode Length 275.20 || lr: 8.976090e-03 || dt: 0.39s |
# | Step: 177/800 || Average Episode Length 333.80 || lr: 8.964827e-03 || dt: 0.47s |
# | Step: 178/800 || Average Episode Length 419.50 || lr: 8.953510e-03 || dt: 0.59s |
# | Step: 179/800 || Average Episode Length 339.30 || lr: 8.942140e-03 || dt: 0.48s |
# | Step: 180/800 || Average Episode Length 313.80 || lr: 8.930717e-03 || dt: 0.57s |
# | Step: 181/800 || Average Episode Length 323.40 || lr: 8.919240e-03 || dt: 0.45s |
# | Step: 182/800 || Average Episode Length 276.10 || lr: 8.907711e-03 || dt: 0.39s |
# | Step: 183/800 || Average Episode Length 283.60 || lr: 8.896129e-03 || dt: 0.39s |
# | Step: 184/800 || Average Episode Length 256.40 || lr: 8.884494e-03 || dt: 0.36s |
# | Step: 185/800 || Average Episode Length 321.60 || lr: 8.872807e-03 || dt: 0.45s |
# | Step: 186/800 || Average Episode Length 257.50 || lr: 8.861068e-03 || dt: 0.36s |
# | Step: 187/800 || Average Episode Length 241.60 || lr: 8.849277e-03 || dt: 0.34s |
# | Step: 188/800 || Average Episode Length 219.20 || lr: 8.837434e-03 || dt: 0.31s |
# | Step: 189/800 || Average Episode Length 202.30 || lr: 8.825540e-03 || dt: 0.29s |
# | Step: 190/800 || Average Episode Length 255.00 || lr: 8.813594e-03 || dt: 0.36s |
# | Step: 191/800 || Average Episode Length 253.70 || lr: 8.801597e-03 || dt: 0.36s |
# | Step: 192/800 || Average Episode Length 259.40 || lr: 8.789549e-03 || dt: 0.37s |
# | Step: 193/800 || Average Episode Length 290.40 || lr: 8.777450e-03 || dt: 0.41s |
# | Step: 194/800 || Average Episode Length 248.80 || lr: 8.765301e-03 || dt: 0.48s |
# | Step: 195/800 || Average Episode Length 262.00 || lr: 8.753101e-03 || dt: 0.37s |
# | Step: 196/800 || Average Episode Length 217.90 || lr: 8.740851e-03 || dt: 0.31s |
# | Step: 197/800 || Average Episode Length 251.00 || lr: 8.728550e-03 || dt: 0.35s |
# | Step: 198/800 || Average Episode Length 226.40 || lr: 8.716200e-03 || dt: 0.32s |
# | Step: 199/800 || Average Episode Length 216.00 || lr: 8.703800e-03 || dt: 0.31s |
# | Step: 200/800 || Average Episode Length 222.30 || lr: 8.691350e-03 || dt: 0.31s |
# | Step: 201/800 || Average Episode Length 306.10 || lr: 8.678851e-03 || dt: 0.43s |
# | Step: 202/800 || Average Episode Length 222.10 || lr: 8.666303e-03 || dt: 0.45s |
# | Step: 203/800 || Average Episode Length 257.20 || lr: 8.653706e-03 || dt: 0.35s |
# | Step: 204/800 || Average Episode Length 198.50 || lr: 8.641060e-03 || dt: 0.27s |
# | Step: 205/800 || Average Episode Length 215.00 || lr: 8.628366e-03 || dt: 0.29s |
# | Step: 206/800 || Average Episode Length 196.10 || lr: 8.615623e-03 || dt: 0.27s |
# | Step: 207/800 || Average Episode Length 204.70 || lr: 8.602832e-03 || dt: 0.28s |
# | Step: 208/800 || Average Episode Length 248.20 || lr: 8.589993e-03 || dt: 0.34s |
# | Step: 209/800 || Average Episode Length 260.70 || lr: 8.577107e-03 || dt: 0.36s |
# | Step: 210/800 || Average Episode Length 272.30 || lr: 8.564173e-03 || dt: 0.37s |
# | Step: 211/800 || Average Episode Length 269.00 || lr: 8.551191e-03 || dt: 0.37s |
# | Step: 212/800 || Average Episode Length 288.10 || lr: 8.538162e-03 || dt: 0.40s |
# | Step: 213/800 || Average Episode Length 306.40 || lr: 8.525087e-03 || dt: 0.42s |
# | Step: 214/800 || Average Episode Length 325.40 || lr: 8.511964e-03 || dt: 0.45s |
# | Step: 215/800 || Average Episode Length 367.80 || lr: 8.498795e-03 || dt: 0.51s |
# | Step: 216/800 || Average Episode Length 348.50 || lr: 8.485580e-03 || dt: 0.48s |
# | Step: 217/800 || Average Episode Length 369.50 || lr: 8.472318e-03 || dt: 0.51s |
# | Step: 218/800 || Average Episode Length 308.20 || lr: 8.459011e-03 || dt: 0.44s |
# | Step: 219/800 || Average Episode Length 353.50 || lr: 8.445657e-03 || dt: 0.49s |
# | Step: 220/800 || Average Episode Length 301.40 || lr: 8.432259e-03 || dt: 0.43s |
# | Step: 221/800 || Average Episode Length 329.10 || lr: 8.418815e-03 || dt: 0.47s |
# | Step: 222/800 || Average Episode Length 297.90 || lr: 8.405325e-03 || dt: 0.56s |
# | Step: 223/800 || Average Episode Length 293.00 || lr: 8.391791e-03 || dt: 0.41s |
# | Step: 224/800 || Average Episode Length 272.00 || lr: 8.378212e-03 || dt: 0.38s |
# | Step: 225/800 || Average Episode Length 256.00 || lr: 8.364589e-03 || dt: 0.36s |
# | Step: 226/800 || Average Episode Length 265.70 || lr: 8.350921e-03 || dt: 0.37s |
# | Step: 227/800 || Average Episode Length 281.90 || lr: 8.337210e-03 || dt: 0.39s |
# | Step: 228/800 || Average Episode Length 240.70 || lr: 8.323454e-03 || dt: 0.33s |
# | Step: 229/800 || Average Episode Length 233.50 || lr: 8.309655e-03 || dt: 0.32s |
# | Step: 230/800 || Average Episode Length 218.50 || lr: 8.295812e-03 || dt: 0.30s |
# | Step: 231/800 || Average Episode Length 242.20 || lr: 8.281926e-03 || dt: 0.34s |
# | Step: 232/800 || Average Episode Length 268.10 || lr: 8.267997e-03 || dt: 0.37s |
# | Step: 233/800 || Average Episode Length 251.80 || lr: 8.254026e-03 || dt: 0.36s |
# | Step: 234/800 || Average Episode Length 226.70 || lr: 8.240011e-03 || dt: 0.35s |
# | Step: 235/800 || Average Episode Length 252.70 || lr: 8.225955e-03 || dt: 0.38s |
# | Step: 236/800 || Average Episode Length 228.70 || lr: 8.211856e-03 || dt: 0.34s |
# | Step: 237/800 || Average Episode Length 221.30 || lr: 8.197715e-03 || dt: 0.33s |
# | Step: 238/800 || Average Episode Length 254.70 || lr: 8.183533e-03 || dt: 0.37s |
# | Step: 239/800 || Average Episode Length 370.80 || lr: 8.169309e-03 || dt: 0.51s |
# | Step: 240/800 || Average Episode Length 323.00 || lr: 8.155044e-03 || dt: 0.45s |
# | Step: 241/800 || Average Episode Length 386.10 || lr: 8.140737e-03 || dt: 0.55s |
# | Step: 242/800 || Average Episode Length 397.60 || lr: 8.126390e-03 || dt: 0.54s |
# | Step: 243/800 || Average Episode Length 396.90 || lr: 8.112003e-03 || dt: 0.55s |
# | Step: 244/800 || Average Episode Length 452.20 || lr: 8.097575e-03 || dt: 0.62s |
# | Step: 245/800 || Average Episode Length 475.80 || lr: 8.083107e-03 || dt: 0.65s |
# | Step: 246/800 || Average Episode Length 442.40 || lr: 8.068598e-03 || dt: 0.61s |
# | Step: 247/800 || Average Episode Length 473.40 || lr: 8.054051e-03 || dt: 0.65s |
# | Step: 248/800 || Average Episode Length 446.20 || lr: 8.039463e-03 || dt: 0.62s |
# | Step: 249/800 || Average Episode Length 465.80 || lr: 8.024837e-03 || dt: 0.64s |
# | Step: 250/800 || Average Episode Length 467.60 || lr: 8.010171e-03 || dt: 0.64s |
# | Step: 251/800 || Average Episode Length 480.00 || lr: 7.995467e-03 || dt: 0.66s |
# | Step: 252/800 || Average Episode Length 500.00 || lr: 7.980724e-03 || dt: 0.69s |
# | Step: 253/800 || Average Episode Length 489.20 || lr: 7.965942e-03 || dt: 0.68s |
# | Step: 254/800 || Average Episode Length 429.60 || lr: 7.951123e-03 || dt: 0.75s |
# | Step: 255/800 || Average Episode Length 463.00 || lr: 7.936266e-03 || dt: 0.64s |
# | Step: 256/800 || Average Episode Length 463.80 || lr: 7.921371e-03 || dt: 0.63s |
# | Step: 257/800 || Average Episode Length 475.10 || lr: 7.906438e-03 || dt: 0.66s |
# | Step: 258/800 || Average Episode Length 434.70 || lr: 7.891468e-03 || dt: 0.75s |
# | Step: 259/800 || Average Episode Length 477.30 || lr: 7.876462e-03 || dt: 0.65s |
# | Step: 260/800 || Average Episode Length 417.10 || lr: 7.861418e-03 || dt: 0.57s |
# | Step: 261/800 || Average Episode Length 477.80 || lr: 7.846339e-03 || dt: 0.67s |
# | Step: 262/800 || Average Episode Length 468.10 || lr: 7.831222e-03 || dt: 0.78s |
# | Step: 263/800 || Average Episode Length 464.30 || lr: 7.816070e-03 || dt: 0.64s |
# | Step: 264/800 || Average Episode Length 500.00 || lr: 7.800882e-03 || dt: 0.69s |
# | Step: 265/800 || Average Episode Length 477.80 || lr: 7.785659e-03 || dt: 0.65s |
# | Step: 266/800 || Average Episode Length 475.10 || lr: 7.770400e-03 || dt: 0.65s |
# | Step: 267/800 || Average Episode Length 496.20 || lr: 7.755106e-03 || dt: 0.68s |
# | Step: 268/800 || Average Episode Length 500.00 || lr: 7.739777e-03 || dt: 0.69s |
# | Step: 269/800 || Average Episode Length 447.50 || lr: 7.724413e-03 || dt: 0.75s |
# | Step: 270/800 || Average Episode Length 419.60 || lr: 7.709016e-03 || dt: 0.59s |
# | Step: 271/800 || Average Episode Length 498.40 || lr: 7.693583e-03 || dt: 0.69s |
# | Step: 272/800 || Average Episode Length 474.20 || lr: 7.678118e-03 || dt: 0.66s |
# | Step: 273/800 || Average Episode Length 459.70 || lr: 7.662618e-03 || dt: 0.77s |
# | Step: 274/800 || Average Episode Length 443.20 || lr: 7.647085e-03 || dt: 0.62s |
# | Step: 275/800 || Average Episode Length 451.80 || lr: 7.631519e-03 || dt: 0.63s |
# | Step: 276/800 || Average Episode Length 485.80 || lr: 7.615919e-03 || dt: 0.66s |
# | Step: 277/800 || Average Episode Length 436.40 || lr: 7.600287e-03 || dt: 0.73s |
# | Step: 278/800 || Average Episode Length 500.00 || lr: 7.584623e-03 || dt: 0.68s |
# | Step: 279/800 || Average Episode Length 500.00 || lr: 7.568926e-03 || dt: 0.68s |
# | Step: 280/800 || Average Episode Length 462.10 || lr: 7.553198e-03 || dt: 0.63s |
# | Step: 281/800 || Average Episode Length 468.90 || lr: 7.537438e-03 || dt: 0.65s |
# | Step: 282/800 || Average Episode Length 481.60 || lr: 7.521646e-03 || dt: 0.66s |
# | Step: 283/800 || Average Episode Length 483.70 || lr: 7.505823e-03 || dt: 0.66s |
# | Step: 284/800 || Average Episode Length 500.00 || lr: 7.489968e-03 || dt: 0.83s |
# | Step: 285/800 || Average Episode Length 480.40 || lr: 7.474084e-03 || dt: 0.67s |
# | Step: 286/800 || Average Episode Length 482.90 || lr: 7.458168e-03 || dt: 0.67s |
# | Step: 287/800 || Average Episode Length 481.50 || lr: 7.442223e-03 || dt: 0.66s |
# | Step: 288/800 || Average Episode Length 468.30 || lr: 7.426247e-03 || dt: 0.65s |
# | Step: 289/800 || Average Episode Length 500.00 || lr: 7.410241e-03 || dt: 0.69s |
# | Step: 290/800 || Average Episode Length 500.00 || lr: 7.394206e-03 || dt: 0.72s |
# | Step: 291/800 || Average Episode Length 500.00 || lr: 7.378142e-03 || dt: 0.87s |
# | Step: 292/800 || Average Episode Length 493.60 || lr: 7.362049e-03 || dt: 0.71s |
# | Step: 293/800 || Average Episode Length 478.60 || lr: 7.345927e-03 || dt: 0.67s |
# | Step: 294/800 || Average Episode Length 460.10 || lr: 7.329776e-03 || dt: 0.63s |
# | Step: 295/800 || Average Episode Length 448.10 || lr: 7.313597e-03 || dt: 0.75s |
# | Step: 296/800 || Average Episode Length 481.00 || lr: 7.297390e-03 || dt: 0.66s |
# | Step: 297/800 || Average Episode Length 469.00 || lr: 7.281155e-03 || dt: 0.64s |
# | Step: 298/800 || Average Episode Length 500.00 || lr: 7.264893e-03 || dt: 0.68s |
# | Step: 299/800 || Average Episode Length 483.90 || lr: 7.248604e-03 || dt: 0.79s |
# | Step: 300/800 || Average Episode Length 500.00 || lr: 7.232287e-03 || dt: 0.68s |
# | Step: 301/800 || Average Episode Length 445.50 || lr: 7.215944e-03 || dt: 0.61s |
# | Step: 302/800 || Average Episode Length 481.10 || lr: 7.199574e-03 || dt: 0.66s |
# | Step: 303/800 || Average Episode Length 402.90 || lr: 7.183177e-03 || dt: 0.56s |
# | Step: 304/800 || Average Episode Length 413.60 || lr: 7.166755e-03 || dt: 0.57s |
# | Step: 305/800 || Average Episode Length 430.80 || lr: 7.150307e-03 || dt: 0.61s |
# | Step: 306/800 || Average Episode Length 437.20 || lr: 7.133834e-03 || dt: 0.63s |
# | Step: 307/800 || Average Episode Length 423.90 || lr: 7.117335e-03 || dt: 0.72s |
# | Step: 308/800 || Average Episode Length 442.10 || lr: 7.100811e-03 || dt: 0.60s |
# | Step: 309/800 || Average Episode Length 401.40 || lr: 7.084263e-03 || dt: 0.55s |
# | Step: 310/800 || Average Episode Length 399.60 || lr: 7.067690e-03 || dt: 0.55s |
# | Step: 311/800 || Average Episode Length 429.70 || lr: 7.051092e-03 || dt: 0.72s |
# | Step: 312/800 || Average Episode Length 434.70 || lr: 7.034471e-03 || dt: 0.60s |
# | Step: 313/800 || Average Episode Length 470.10 || lr: 7.017826e-03 || dt: 0.65s |
# | Step: 314/800 || Average Episode Length 492.40 || lr: 7.001158e-03 || dt: 0.67s |
# | Step: 315/800 || Average Episode Length 473.60 || lr: 6.984466e-03 || dt: 0.65s |
# | Step: 316/800 || Average Episode Length 489.90 || lr: 6.967752e-03 || dt: 0.69s |
# | Step: 317/800 || Average Episode Length 500.00 || lr: 6.951014e-03 || dt: 0.70s |
# | Step: 318/800 || Average Episode Length 475.00 || lr: 6.934255e-03 || dt: 0.81s |
# | Step: 319/800 || Average Episode Length 500.00 || lr: 6.917473e-03 || dt: 0.71s |
# | Step: 320/800 || Average Episode Length 481.00 || lr: 6.900669e-03 || dt: 0.69s |
# | Step: 321/800 || Average Episode Length 498.20 || lr: 6.883844e-03 || dt: 0.71s |
# | Step: 322/800 || Average Episode Length 428.20 || lr: 6.866997e-03 || dt: 0.61s |
# | Step: 323/800 || Average Episode Length 416.60 || lr: 6.850129e-03 || dt: 0.58s |
# | Step: 324/800 || Average Episode Length 477.10 || lr: 6.833240e-03 || dt: 0.67s |
# | Step: 325/800 || Average Episode Length 442.80 || lr: 6.816331e-03 || dt: 0.60s |
# | Step: 326/800 || Average Episode Length 484.90 || lr: 6.799401e-03 || dt: 0.80s |
# | Step: 327/800 || Average Episode Length 500.00 || lr: 6.782451e-03 || dt: 0.69s |
# | Step: 328/800 || Average Episode Length 451.50 || lr: 6.765481e-03 || dt: 0.63s |
# | Step: 329/800 || Average Episode Length 461.30 || lr: 6.748492e-03 || dt: 0.66s |
# | Step: 330/800 || Average Episode Length 446.00 || lr: 6.731483e-03 || dt: 0.63s |
# | Step: 331/800 || Average Episode Length 472.40 || lr: 6.714456e-03 || dt: 0.66s |
# | Step: 332/800 || Average Episode Length 483.60 || lr: 6.697409e-03 || dt: 0.68s |
# | Step: 333/800 || Average Episode Length 468.30 || lr: 6.680345e-03 || dt: 0.65s |
# | Step: 334/800 || Average Episode Length 465.00 || lr: 6.663261e-03 || dt: 0.68s |
# | Step: 335/800 || Average Episode Length 442.70 || lr: 6.646160e-03 || dt: 0.60s |
# | Step: 336/800 || Average Episode Length 463.10 || lr: 6.629041e-03 || dt: 0.65s |
# | Step: 337/800 || Average Episode Length 413.10 || lr: 6.611905e-03 || dt: 0.58s |
# | Step: 338/800 || Average Episode Length 448.10 || lr: 6.594752e-03 || dt: 0.62s |
# | Step: 339/800 || Average Episode Length 418.30 || lr: 6.577581e-03 || dt: 0.58s |
# | Step: 340/800 || Average Episode Length 439.60 || lr: 6.560394e-03 || dt: 0.60s |
# | Step: 341/800 || Average Episode Length 435.80 || lr: 6.543191e-03 || dt: 0.60s |
# | Step: 342/800 || Average Episode Length 482.80 || lr: 6.525971e-03 || dt: 0.66s |
# | Step: 343/800 || Average Episode Length 444.70 || lr: 6.508736e-03 || dt: 0.61s |
# | Step: 344/800 || Average Episode Length 453.10 || lr: 6.491485e-03 || dt: 0.62s |
# | Step: 345/800 || Average Episode Length 403.90 || lr: 6.474218e-03 || dt: 0.55s |
# | Step: 346/800 || Average Episode Length 411.50 || lr: 6.456937e-03 || dt: 0.74s |
# | Step: 347/800 || Average Episode Length 463.50 || lr: 6.439640e-03 || dt: 0.64s |
# | Step: 348/800 || Average Episode Length 463.20 || lr: 6.422330e-03 || dt: 0.64s |
# | Step: 349/800 || Average Episode Length 454.50 || lr: 6.405005e-03 || dt: 0.78s |
# | Step: 350/800 || Average Episode Length 461.50 || lr: 6.387666e-03 || dt: 0.63s |
# | Step: 351/800 || Average Episode Length 467.30 || lr: 6.370313e-03 || dt: 0.64s |
# | Step: 352/800 || Average Episode Length 497.80 || lr: 6.352947e-03 || dt: 0.70s |
# | Step: 353/800 || Average Episode Length 484.40 || lr: 6.335567e-03 || dt: 0.80s |
# | Step: 354/800 || Average Episode Length 433.90 || lr: 6.318175e-03 || dt: 0.60s |
# | Step: 355/800 || Average Episode Length 500.00 || lr: 6.300770e-03 || dt: 0.68s |
# | Step: 356/800 || Average Episode Length 490.00 || lr: 6.283353e-03 || dt: 0.67s |
# | Step: 357/800 || Average Episode Length 500.00 || lr: 6.265923e-03 || dt: 0.70s |
# | Step: 358/800 || Average Episode Length 468.00 || lr: 6.248482e-03 || dt: 0.65s |
# | Step: 359/800 || Average Episode Length 500.00 || lr: 6.231029e-03 || dt: 0.70s |
# | Step: 360/800 || Average Episode Length 495.40 || lr: 6.213565e-03 || dt: 0.68s |
# | Step: 361/800 || Average Episode Length 500.00 || lr: 6.196090e-03 || dt: 0.69s |
# | Step: 362/800 || Average Episode Length 496.50 || lr: 6.178604e-03 || dt: 0.68s |
# | Step: 363/800 || Average Episode Length 495.20 || lr: 6.161108e-03 || dt: 0.68s |
# | Step: 364/800 || Average Episode Length 500.00 || lr: 6.143601e-03 || dt: 0.84s |
# | Step: 365/800 || Average Episode Length 445.10 || lr: 6.126084e-03 || dt: 0.62s |
# | Step: 366/800 || Average Episode Length 477.30 || lr: 6.108558e-03 || dt: 0.66s |
# | Step: 367/800 || Average Episode Length 447.80 || lr: 6.091022e-03 || dt: 0.63s |
# | Step: 368/800 || Average Episode Length 500.00 || lr: 6.073477e-03 || dt: 0.84s |
# | Step: 369/800 || Average Episode Length 496.50 || lr: 6.055924e-03 || dt: 0.70s |
# | Step: 370/800 || Average Episode Length 500.00 || lr: 6.038361e-03 || dt: 0.70s |
# | Step: 371/800 || Average Episode Length 465.30 || lr: 6.020791e-03 || dt: 0.65s |
# | Step: 372/800 || Average Episode Length 499.70 || lr: 6.003212e-03 || dt: 0.71s |
# | Step: 373/800 || Average Episode Length 500.00 || lr: 5.985626e-03 || dt: 0.70s |
# | Step: 374/800 || Average Episode Length 451.50 || lr: 5.968032e-03 || dt: 0.64s |
# | Step: 375/800 || Average Episode Length 500.00 || lr: 5.950431e-03 || dt: 0.83s |
# | Step: 376/800 || Average Episode Length 500.00 || lr: 5.932822e-03 || dt: 0.70s |
# | Step: 377/800 || Average Episode Length 500.00 || lr: 5.915208e-03 || dt: 0.70s |
# | Step: 378/800 || Average Episode Length 500.00 || lr: 5.897586e-03 || dt: 0.69s |
# | Step: 379/800 || Average Episode Length 467.10 || lr: 5.879959e-03 || dt: 0.65s |
# | Step: 380/800 || Average Episode Length 496.60 || lr: 5.862326e-03 || dt: 0.68s |
# | Step: 381/800 || Average Episode Length 500.00 || lr: 5.844687e-03 || dt: 0.70s |
# | Step: 382/800 || Average Episode Length 500.00 || lr: 5.827043e-03 || dt: 0.84s |
# | Step: 383/800 || Average Episode Length 488.10 || lr: 5.809393e-03 || dt: 0.67s |
# | Step: 384/800 || Average Episode Length 449.20 || lr: 5.791739e-03 || dt: 0.62s |
# | Step: 385/800 || Average Episode Length 465.00 || lr: 5.774081e-03 || dt: 0.64s |
# | Step: 386/800 || Average Episode Length 498.30 || lr: 5.756418e-03 || dt: 0.86s |
# | Step: 387/800 || Average Episode Length 474.10 || lr: 5.738751e-03 || dt: 0.68s |
# | Step: 388/800 || Average Episode Length 500.00 || lr: 5.721081e-03 || dt: 0.71s |
# | Step: 389/800 || Average Episode Length 500.00 || lr: 5.703407e-03 || dt: 0.68s |
# | Step: 390/800 || Average Episode Length 500.00 || lr: 5.685730e-03 || dt: 0.70s |
# | Step: 391/800 || Average Episode Length 500.00 || lr: 5.668050e-03 || dt: 0.71s |
# | Step: 392/800 || Average Episode Length 500.00 || lr: 5.650367e-03 || dt: 0.71s |
# | Step: 393/800 || Average Episode Length 500.00 || lr: 5.632683e-03 || dt: 0.71s |
# | Step: 394/800 || Average Episode Length 472.10 || lr: 5.614996e-03 || dt: 0.66s |
# | Step: 395/800 || Average Episode Length 473.70 || lr: 5.597307e-03 || dt: 0.65s |
# | Step: 396/800 || Average Episode Length 453.10 || lr: 5.579617e-03 || dt: 0.63s |
# | Step: 397/800 || Average Episode Length 500.00 || lr: 5.561926e-03 || dt: 0.69s |
# | Step: 398/800 || Average Episode Length 500.00 || lr: 5.544233e-03 || dt: 0.69s |
# | Step: 399/800 || Average Episode Length 500.00 || lr: 5.526540e-03 || dt: 0.71s |
# | Step: 400/800 || Average Episode Length 471.80 || lr: 5.508847e-03 || dt: 0.66s |
# | Step: 401/800 || Average Episode Length 466.90 || lr: 5.491153e-03 || dt: 0.80s |
# | Step: 402/800 || Average Episode Length 470.30 || lr: 5.473460e-03 || dt: 0.66s |
# | Step: 403/800 || Average Episode Length 460.50 || lr: 5.455767e-03 || dt: 0.65s |
# | Step: 404/800 || Average Episode Length 478.80 || lr: 5.438074e-03 || dt: 0.68s |
# | Step: 405/800 || Average Episode Length 492.50 || lr: 5.420383e-03 || dt: 0.71s |
# | Step: 406/800 || Average Episode Length 488.70 || lr: 5.402693e-03 || dt: 0.68s |
# | Step: 407/800 || Average Episode Length 500.00 || lr: 5.385004e-03 || dt: 0.71s |
# | Step: 408/800 || Average Episode Length 484.40 || lr: 5.367317e-03 || dt: 0.68s |
# | Step: 409/800 || Average Episode Length 485.50 || lr: 5.349633e-03 || dt: 0.69s |
# | Step: 410/800 || Average Episode Length 476.00 || lr: 5.331950e-03 || dt: 0.67s |
# | Step: 411/800 || Average Episode Length 464.80 || lr: 5.314270e-03 || dt: 0.66s |
# | Step: 412/800 || Average Episode Length 500.00 || lr: 5.296593e-03 || dt: 0.70s |
# | Step: 413/800 || Average Episode Length 483.90 || lr: 5.278919e-03 || dt: 0.68s |
# | Step: 414/800 || Average Episode Length 466.50 || lr: 5.261249e-03 || dt: 0.64s |
# | Step: 415/800 || Average Episode Length 500.00 || lr: 5.243582e-03 || dt: 0.69s |
# | Step: 416/800 || Average Episode Length 500.00 || lr: 5.225919e-03 || dt: 0.68s |
# | Step: 417/800 || Average Episode Length 475.60 || lr: 5.208261e-03 || dt: 0.67s |
# | Step: 418/800 || Average Episode Length 475.30 || lr: 5.190607e-03 || dt: 0.67s |
# | Step: 419/800 || Average Episode Length 500.00 || lr: 5.172957e-03 || dt: 0.84s |
# | Step: 420/800 || Average Episode Length 500.00 || lr: 5.155313e-03 || dt: 0.70s |
# | Step: 421/800 || Average Episode Length 500.00 || lr: 5.137674e-03 || dt: 0.70s |
# | Step: 422/800 || Average Episode Length 488.40 || lr: 5.120041e-03 || dt: 0.81s |
# | Step: 423/800 || Average Episode Length 500.00 || lr: 5.102414e-03 || dt: 0.69s |
# | Step: 424/800 || Average Episode Length 470.10 || lr: 5.084792e-03 || dt: 0.64s |
# | Step: 425/800 || Average Episode Length 500.00 || lr: 5.067178e-03 || dt: 0.69s |
# | Step: 426/800 || Average Episode Length 445.50 || lr: 5.049569e-03 || dt: 0.75s |
# | Step: 427/800 || Average Episode Length 479.80 || lr: 5.031968e-03 || dt: 0.65s |
# | Step: 428/800 || Average Episode Length 470.30 || lr: 5.014374e-03 || dt: 0.66s |
# | Step: 429/800 || Average Episode Length 489.80 || lr: 4.996788e-03 || dt: 0.69s |
# | Step: 430/800 || Average Episode Length 500.00 || lr: 4.979209e-03 || dt: 0.69s |
# | Step: 431/800 || Average Episode Length 463.10 || lr: 4.961639e-03 || dt: 0.64s |
# | Step: 432/800 || Average Episode Length 500.00 || lr: 4.944076e-03 || dt: 0.68s |
# | Step: 433/800 || Average Episode Length 500.00 || lr: 4.926523e-03 || dt: 0.82s |
# | Step: 434/800 || Average Episode Length 500.00 || lr: 4.908978e-03 || dt: 0.68s |
# | Step: 435/800 || Average Episode Length 453.80 || lr: 4.891442e-03 || dt: 0.62s |
# | Step: 436/800 || Average Episode Length 500.00 || lr: 4.873916e-03 || dt: 0.69s |
# | Step: 437/800 || Average Episode Length 492.00 || lr: 4.856399e-03 || dt: 0.81s |
# | Step: 438/800 || Average Episode Length 500.00 || lr: 4.838892e-03 || dt: 0.68s |
# | Step: 439/800 || Average Episode Length 454.60 || lr: 4.821396e-03 || dt: 0.62s |
# | Step: 440/800 || Average Episode Length 443.20 || lr: 4.803910e-03 || dt: 0.74s |
# | Step: 441/800 || Average Episode Length 492.20 || lr: 4.786435e-03 || dt: 0.69s |
# | Step: 442/800 || Average Episode Length 469.00 || lr: 4.768971e-03 || dt: 0.66s |
# | Step: 443/800 || Average Episode Length 444.20 || lr: 4.751518e-03 || dt: 0.62s |
# | Step: 444/800 || Average Episode Length 455.40 || lr: 4.734077e-03 || dt: 0.64s |
# | Step: 445/800 || Average Episode Length 478.00 || lr: 4.716647e-03 || dt: 0.67s |
# | Step: 446/800 || Average Episode Length 448.20 || lr: 4.699230e-03 || dt: 0.61s |
# | Step: 447/800 || Average Episode Length 471.30 || lr: 4.681825e-03 || dt: 0.64s |
# | Step: 448/800 || Average Episode Length 500.00 || lr: 4.664433e-03 || dt: 0.82s |
# | Step: 449/800 || Average Episode Length 478.20 || lr: 4.647053e-03 || dt: 0.66s |
# | Step: 450/800 || Average Episode Length 475.30 || lr: 4.629687e-03 || dt: 0.66s |
# | Step: 451/800 || Average Episode Length 500.00 || lr: 4.612334e-03 || dt: 0.83s |
# | Step: 452/800 || Average Episode Length 447.50 || lr: 4.594995e-03 || dt: 0.62s |
# | Step: 453/800 || Average Episode Length 471.60 || lr: 4.577670e-03 || dt: 0.64s |
# | Step: 454/800 || Average Episode Length 435.50 || lr: 4.560360e-03 || dt: 0.60s |
# | Step: 455/800 || Average Episode Length 455.80 || lr: 4.543063e-03 || dt: 0.76s |
# | Step: 456/800 || Average Episode Length 476.40 || lr: 4.525782e-03 || dt: 0.65s |
# | Step: 457/800 || Average Episode Length 485.80 || lr: 4.508515e-03 || dt: 0.66s |
# | Step: 458/800 || Average Episode Length 496.70 || lr: 4.491264e-03 || dt: 0.71s |
# | Step: 459/800 || Average Episode Length 500.00 || lr: 4.474029e-03 || dt: 0.68s |
# | Step: 460/800 || Average Episode Length 500.00 || lr: 4.456809e-03 || dt: 0.68s |
# | Step: 461/800 || Average Episode Length 451.70 || lr: 4.439606e-03 || dt: 0.62s |
# | Step: 462/800 || Average Episode Length 500.00 || lr: 4.422419e-03 || dt: 0.83s |
# | Step: 463/800 || Average Episode Length 458.30 || lr: 4.405248e-03 || dt: 0.64s |
# | Step: 464/800 || Average Episode Length 462.50 || lr: 4.388095e-03 || dt: 0.65s |
# | Step: 465/800 || Average Episode Length 487.90 || lr: 4.370959e-03 || dt: 0.67s |
# | Step: 466/800 || Average Episode Length 500.00 || lr: 4.353840e-03 || dt: 0.82s |
# | Step: 467/800 || Average Episode Length 500.00 || lr: 4.336739e-03 || dt: 0.69s |
# | Step: 468/800 || Average Episode Length 500.00 || lr: 4.319655e-03 || dt: 0.68s |
# | Step: 469/800 || Average Episode Length 479.60 || lr: 4.302591e-03 || dt: 0.67s |
# | Step: 470/800 || Average Episode Length 494.80 || lr: 4.285544e-03 || dt: 0.70s |
# | Step: 471/800 || Average Episode Length 500.00 || lr: 4.268517e-03 || dt: 0.69s |
# | Step: 472/800 || Average Episode Length 500.00 || lr: 4.251508e-03 || dt: 0.70s |
# | Step: 473/800 || Average Episode Length 481.90 || lr: 4.234519e-03 || dt: 0.81s |
# | Step: 474/800 || Average Episode Length 473.10 || lr: 4.217549e-03 || dt: 0.66s |
# | Step: 475/800 || Average Episode Length 463.30 || lr: 4.200599e-03 || dt: 0.63s |
# | Step: 476/800 || Average Episode Length 486.70 || lr: 4.183669e-03 || dt: 0.66s |
# | Step: 477/800 || Average Episode Length 464.20 || lr: 4.166760e-03 || dt: 0.64s |
# | Step: 478/800 || Average Episode Length 466.80 || lr: 4.149871e-03 || dt: 0.66s |
# | Step: 479/800 || Average Episode Length 500.00 || lr: 4.133003e-03 || dt: 0.68s |
# | Step: 480/800 || Average Episode Length 467.50 || lr: 4.116156e-03 || dt: 0.79s |
# | Step: 481/800 || Average Episode Length 466.50 || lr: 4.099331e-03 || dt: 0.64s |
# | Step: 482/800 || Average Episode Length 472.80 || lr: 4.082527e-03 || dt: 0.65s |
# | Step: 483/800 || Average Episode Length 449.80 || lr: 4.065745e-03 || dt: 0.63s |
# | Step: 484/800 || Average Episode Length 500.00 || lr: 4.048986e-03 || dt: 0.71s |
# | Step: 485/800 || Average Episode Length 500.00 || lr: 4.032248e-03 || dt: 0.71s |
# | Step: 486/800 || Average Episode Length 500.00 || lr: 4.015534e-03 || dt: 0.71s |
# | Step: 487/800 || Average Episode Length 486.20 || lr: 3.998842e-03 || dt: 0.69s |
# | Step: 488/800 || Average Episode Length 500.00 || lr: 3.982174e-03 || dt: 0.70s |
# | Step: 489/800 || Average Episode Length 500.00 || lr: 3.965529e-03 || dt: 0.71s |
# | Step: 490/800 || Average Episode Length 488.70 || lr: 3.948908e-03 || dt: 0.69s |
# | Step: 491/800 || Average Episode Length 473.60 || lr: 3.932310e-03 || dt: 0.80s |
# | Step: 492/800 || Average Episode Length 481.70 || lr: 3.915737e-03 || dt: 0.67s |
# | Step: 493/800 || Average Episode Length 472.10 || lr: 3.899189e-03 || dt: 0.67s |
# | Step: 494/800 || Average Episode Length 465.90 || lr: 3.882665e-03 || dt: 0.64s |
# | Step: 495/800 || Average Episode Length 488.40 || lr: 3.866166e-03 || dt: 0.68s |
# | Step: 496/800 || Average Episode Length 490.70 || lr: 3.849693e-03 || dt: 0.70s |
# | Step: 497/800 || Average Episode Length 499.70 || lr: 3.833245e-03 || dt: 0.69s |
# | Step: 498/800 || Average Episode Length 455.10 || lr: 3.816823e-03 || dt: 0.64s |
# | Step: 499/800 || Average Episode Length 500.00 || lr: 3.800426e-03 || dt: 0.72s |
# | Step: 500/800 || Average Episode Length 496.30 || lr: 3.784056e-03 || dt: 0.69s |
# | Step: 501/800 || Average Episode Length 500.00 || lr: 3.767713e-03 || dt: 0.69s |
# | Step: 502/800 || Average Episode Length 489.20 || lr: 3.751396e-03 || dt: 0.84s |
# | Step: 503/800 || Average Episode Length 500.00 || lr: 3.735107e-03 || dt: 0.72s |
# | Step: 504/800 || Average Episode Length 482.00 || lr: 3.718845e-03 || dt: 0.69s |
# | Step: 505/800 || Average Episode Length 500.00 || lr: 3.702610e-03 || dt: 0.72s |
# | Step: 506/800 || Average Episode Length 480.70 || lr: 3.686403e-03 || dt: 0.66s |
# | Step: 507/800 || Average Episode Length 500.00 || lr: 3.670224e-03 || dt: 0.71s |
# | Step: 508/800 || Average Episode Length 452.90 || lr: 3.654073e-03 || dt: 0.65s |
# | Step: 509/800 || Average Episode Length 471.60 || lr: 3.637951e-03 || dt: 0.66s |
# | Step: 510/800 || Average Episode Length 500.00 || lr: 3.621858e-03 || dt: 0.71s |
# | Step: 511/800 || Average Episode Length 480.20 || lr: 3.605794e-03 || dt: 0.69s |
# | Step: 512/800 || Average Episode Length 455.60 || lr: 3.589759e-03 || dt: 0.66s |
# | Step: 513/800 || Average Episode Length 481.80 || lr: 3.573753e-03 || dt: 0.80s |
# | Step: 514/800 || Average Episode Length 496.40 || lr: 3.557777e-03 || dt: 0.70s |
# | Step: 515/800 || Average Episode Length 500.00 || lr: 3.541832e-03 || dt: 0.73s |
# | Step: 516/800 || Average Episode Length 500.00 || lr: 3.525916e-03 || dt: 0.70s |
# | Step: 517/800 || Average Episode Length 455.80 || lr: 3.510032e-03 || dt: 0.63s |
# | Step: 518/800 || Average Episode Length 479.80 || lr: 3.494177e-03 || dt: 0.66s |
# | Step: 519/800 || Average Episode Length 472.80 || lr: 3.478354e-03 || dt: 0.65s |
# | Step: 520/800 || Average Episode Length 494.90 || lr: 3.462562e-03 || dt: 0.83s |
# | Step: 521/800 || Average Episode Length 500.00 || lr: 3.446802e-03 || dt: 0.69s |
# | Step: 522/800 || Average Episode Length 500.00 || lr: 3.431074e-03 || dt: 0.68s |
# | Step: 523/800 || Average Episode Length 472.70 || lr: 3.415377e-03 || dt: 0.66s |
# | Step: 524/800 || Average Episode Length 463.90 || lr: 3.399713e-03 || dt: 0.64s |
# | Step: 525/800 || Average Episode Length 441.10 || lr: 3.384081e-03 || dt: 0.61s |
# | Step: 526/800 || Average Episode Length 500.00 || lr: 3.368481e-03 || dt: 0.70s |
# | Step: 527/800 || Average Episode Length 500.00 || lr: 3.352915e-03 || dt: 0.73s |
# | Step: 528/800 || Average Episode Length 500.00 || lr: 3.337382e-03 || dt: 0.70s |
# | Step: 529/800 || Average Episode Length 500.00 || lr: 3.321882e-03 || dt: 0.69s |
# | Step: 530/800 || Average Episode Length 478.70 || lr: 3.306417e-03 || dt: 0.66s |
# | Step: 531/800 || Average Episode Length 464.50 || lr: 3.290984e-03 || dt: 0.81s |
# | Step: 532/800 || Average Episode Length 475.30 || lr: 3.275587e-03 || dt: 0.65s |
# | Step: 533/800 || Average Episode Length 500.00 || lr: 3.260223e-03 || dt: 0.69s |
# | Step: 534/800 || Average Episode Length 479.30 || lr: 3.244894e-03 || dt: 0.66s |
# | Step: 535/800 || Average Episode Length 497.40 || lr: 3.229600e-03 || dt: 0.82s |
# | Step: 536/800 || Average Episode Length 500.00 || lr: 3.214341e-03 || dt: 0.70s |
# | Step: 537/800 || Average Episode Length 441.40 || lr: 3.199118e-03 || dt: 0.60s |
# | Step: 538/800 || Average Episode Length 480.30 || lr: 3.183930e-03 || dt: 0.66s |
# | Step: 539/800 || Average Episode Length 500.00 || lr: 3.168778e-03 || dt: 0.71s |
# | Step: 540/800 || Average Episode Length 439.30 || lr: 3.153661e-03 || dt: 0.62s |
# | Step: 541/800 || Average Episode Length 486.60 || lr: 3.138582e-03 || dt: 0.67s |
# | Step: 542/800 || Average Episode Length 475.60 || lr: 3.123538e-03 || dt: 0.65s |
# | Step: 543/800 || Average Episode Length 500.00 || lr: 3.108532e-03 || dt: 0.69s |
# | Step: 544/800 || Average Episode Length 469.90 || lr: 3.093562e-03 || dt: 0.65s |
# | Step: 545/800 || Average Episode Length 477.60 || lr: 3.078629e-03 || dt: 0.66s |
# | Step: 546/800 || Average Episode Length 478.00 || lr: 3.063734e-03 || dt: 0.81s |
# | Step: 547/800 || Average Episode Length 467.80 || lr: 3.048877e-03 || dt: 0.64s |
# | Step: 548/800 || Average Episode Length 500.00 || lr: 3.034058e-03 || dt: 0.69s |
# | Step: 549/800 || Average Episode Length 471.50 || lr: 3.019276e-03 || dt: 0.65s |
# | Step: 550/800 || Average Episode Length 500.00 || lr: 3.004533e-03 || dt: 0.69s |
# | Step: 551/800 || Average Episode Length 478.00 || lr: 2.989829e-03 || dt: 0.68s |
# | Step: 552/800 || Average Episode Length 491.50 || lr: 2.975163e-03 || dt: 0.69s |
# | Step: 553/800 || Average Episode Length 500.00 || lr: 2.960537e-03 || dt: 0.71s |
# | Step: 554/800 || Average Episode Length 498.10 || lr: 2.945949e-03 || dt: 0.70s |
# | Step: 555/800 || Average Episode Length 500.00 || lr: 2.931402e-03 || dt: 0.71s |
# | Step: 556/800 || Average Episode Length 500.00 || lr: 2.916893e-03 || dt: 0.72s |
# | Step: 557/800 || Average Episode Length 435.40 || lr: 2.902425e-03 || dt: 0.78s |
# | Step: 558/800 || Average Episode Length 500.00 || lr: 2.887997e-03 || dt: 0.71s |
# | Step: 559/800 || Average Episode Length 500.00 || lr: 2.873610e-03 || dt: 0.71s |
# | Step: 560/800 || Average Episode Length 487.50 || lr: 2.859263e-03 || dt: 0.68s |
# | Step: 561/800 || Average Episode Length 485.40 || lr: 2.844956e-03 || dt: 0.68s |
# | Step: 562/800 || Average Episode Length 465.80 || lr: 2.830691e-03 || dt: 0.66s |
# | Step: 563/800 || Average Episode Length 408.60 || lr: 2.816467e-03 || dt: 0.62s |
# | Step: 564/800 || Average Episode Length 500.00 || lr: 2.802285e-03 || dt: 0.75s |
# | Step: 565/800 || Average Episode Length 493.20 || lr: 2.788144e-03 || dt: 0.75s |
# | Step: 566/800 || Average Episode Length 500.00 || lr: 2.774045e-03 || dt: 0.72s |
# | Step: 567/800 || Average Episode Length 500.00 || lr: 2.759989e-03 || dt: 0.72s |
# | Step: 568/800 || Average Episode Length 500.00 || lr: 2.745974e-03 || dt: 0.86s |
# | Step: 569/800 || Average Episode Length 476.90 || lr: 2.732003e-03 || dt: 0.67s |
# | Step: 570/800 || Average Episode Length 500.00 || lr: 2.718074e-03 || dt: 0.73s |
# | Step: 571/800 || Average Episode Length 500.00 || lr: 2.704188e-03 || dt: 0.73s |
# | Step: 572/800 || Average Episode Length 500.00 || lr: 2.690345e-03 || dt: 0.87s |
# | Step: 573/800 || Average Episode Length 472.30 || lr: 2.676546e-03 || dt: 0.68s |
# ...
# | Step: 611/800 || Average Episode Length 477.80 || lr: 2.186406e-03 || dt: 0.65s |
# | Step: 612/800 || Average Episode Length 463.50 || lr: 2.174460e-03 || dt: 0.77s |
# | Step: 613/800 || Average Episode Length 500.00 || lr: 2.162566e-03 || dt: 0.68s |
# | Step: 614/800 || Average Episode Length 479.10 || lr: 2.150723e-03 || dt: 0.67s |
# | Step: 615/800 || Average Episode Length 487.30 || lr: 2.138932e-03 || dt: 0.69s |
# | Step: 616/800 || Average Episode Length 500.00 || lr: 2.127193e-03 || dt: 0.71s |
# | Step: 617/800 || Average Episode Length 500.00 || lr: 2.115506e-03 || dt: 0.71s |
# | Step: 618/800 || Average Episode Length 449.10 || lr: 2.103871e-03 || dt: 0.62s |
# | Step: 619/800 || Average Episode Length 500.00 || lr: 2.092289e-03 || dt: 0.82s |
# | Step: 620/800 || Average Episode Length 500.00 || lr: 2.080760e-03 || dt: 0.69s |
# | Step: 621/800 || Average Episode Length 500.00 || lr: 2.069283e-03 || dt: 0.69s |
# | Step: 622/800 || Average Episode Length 471.50 || lr: 2.057860e-03 || dt: 0.65s |
# | Step: 623/800 || Average Episode Length 500.00 || lr: 2.046490e-03 || dt: 0.69s |
# | Step: 624/800 || Average Episode Length 500.00 || lr: 2.035173e-03 || dt: 0.69s |
# | Step: 625/800 || Average Episode Length 477.70 || lr: 2.023910e-03 || dt: 0.67s |
# | Step: 626/800 || Average Episode Length 500.00 || lr: 2.012700e-03 || dt: 0.84s |
# | Step: 627/800 || Average Episode Length 465.50 || lr: 2.001544e-03 || dt: 0.66s |
# | Step: 628/800 || Average Episode Length 500.00 || lr: 1.990443e-03 || dt: 0.70s |
# | Step: 629/800 || Average Episode Length 474.70 || lr: 1.979396e-03 || dt: 0.65s |
# | Step: 630/800 || Average Episode Length 474.30 || lr: 1.968403e-03 || dt: 0.79s |
# | Step: 631/800 || Average Episode Length 500.00 || lr: 1.957465e-03 || dt: 0.68s |
# | Step: 632/800 || Average Episode Length 500.00 || lr: 1.946581e-03 || dt: 0.68s |
# | Step: 633/800 || Average Episode Length 484.90 || lr: 1.935752e-03 || dt: 0.67s |
# | Step: 634/800 || Average Episode Length 500.00 || lr: 1.924979e-03 || dt: 0.68s |
# | Step: 635/800 || Average Episode Length 485.20 || lr: 1.914261e-03 || dt: 0.67s |
# | Step: 636/800 || Average Episode Length 500.00 || lr: 1.903598e-03 || dt: 0.68s |
# | Step: 637/800 || Average Episode Length 440.20 || lr: 1.892991e-03 || dt: 0.74s |
# | Step: 638/800 || Average Episode Length 468.50 || lr: 1.882439e-03 || dt: 0.64s |
# | Step: 639/800 || Average Episode Length 490.60 || lr: 1.871944e-03 || dt: 0.68s |
# | Step: 640/800 || Average Episode Length 500.00 || lr: 1.861505e-03 || dt: 0.69s |
# | Step: 641/800 || Average Episode Length 470.80 || lr: 1.851122e-03 || dt: 0.65s |
# | Step: 642/800 || Average Episode Length 482.30 || lr: 1.840795e-03 || dt: 0.67s |
# | Step: 643/800 || Average Episode Length 468.50 || lr: 1.830525e-03 || dt: 0.67s |
# | Step: 644/800 || Average Episode Length 500.00 || lr: 1.820311e-03 || dt: 0.84s |
# | Step: 645/800 || Average Episode Length 464.00 || lr: 1.810155e-03 || dt: 0.64s |
# | Step: 646/800 || Average Episode Length 500.00 || lr: 1.800055e-03 || dt: 0.69s |
# | Step: 647/800 || Average Episode Length 500.00 || lr: 1.790013e-03 || dt: 0.69s |
# | Step: 648/800 || Average Episode Length 500.00 || lr: 1.780028e-03 || dt: 0.81s |
# | Step: 649/800 || Average Episode Length 500.00 || lr: 1.770101e-03 || dt: 0.69s |
# | Step: 650/800 || Average Episode Length 500.00 || lr: 1.760231e-03 || dt: 0.68s |
# | Step: 651/800 || Average Episode Length 491.70 || lr: 1.750419e-03 || dt: 0.81s |
# | Step: 652/800 || Average Episode Length 500.00 || lr: 1.740665e-03 || dt: 0.68s |
# | Step: 653/800 || Average Episode Length 500.00 || lr: 1.730969e-03 || dt: 0.68s |
# | Step: 654/800 || Average Episode Length 484.70 || lr: 1.721332e-03 || dt: 0.66s |
# | Step: 655/800 || Average Episode Length 500.00 || lr: 1.711752e-03 || dt: 0.70s |
# | Step: 656/800 || Average Episode Length 470.50 || lr: 1.702232e-03 || dt: 0.67s |
# | Step: 657/800 || Average Episode Length 500.00 || lr: 1.692770e-03 || dt: 0.69s |
# | Step: 658/800 || Average Episode Length 500.00 || lr: 1.683367e-03 || dt: 0.68s |
# | Step: 659/800 || Average Episode Length 500.00 || lr: 1.674023e-03 || dt: 0.69s |
# | Step: 660/800 || Average Episode Length 500.00 || lr: 1.664738e-03 || dt: 0.69s |
# | Step: 661/800 || Average Episode Length 494.40 || lr: 1.655512e-03 || dt: 0.68s |
# | Step: 662/800 || Average Episode Length 500.00 || lr: 1.646346e-03 || dt: 0.68s |
# | Step: 663/800 || Average Episode Length 459.90 || lr: 1.637240e-03 || dt: 0.63s |
# | Step: 664/800 || Average Episode Length 466.80 || lr: 1.628193e-03 || dt: 0.64s |
# | Step: 665/800 || Average Episode Length 478.80 || lr: 1.619206e-03 || dt: 0.80s |
# | Step: 666/800 || Average Episode Length 497.00 || lr: 1.610279e-03 || dt: 0.68s |
# | Step: 667/800 || Average Episode Length 469.20 || lr: 1.601412e-03 || dt: 0.65s |
# | Step: 668/800 || Average Episode Length 500.00 || lr: 1.592605e-03 || dt: 0.68s |
# | Step: 669/800 || Average Episode Length 464.10 || lr: 1.583859e-03 || dt: 0.77s |
# | Step: 670/800 || Average Episode Length 494.60 || lr: 1.575174e-03 || dt: 0.68s |
# | Step: 671/800 || Average Episode Length 500.00 || lr: 1.566549e-03 || dt: 0.69s |
# | Step: 672/800 || Average Episode Length 471.60 || lr: 1.557985e-03 || dt: 0.65s |
# | Step: 673/800 || Average Episode Length 500.00 || lr: 1.549481e-03 || dt: 0.69s |
# | Step: 674/800 || Average Episode Length 470.30 || lr: 1.541039e-03 || dt: 0.64s |
# | Step: 675/800 || Average Episode Length 467.60 || lr: 1.532658e-03 || dt: 0.64s |
# | Step: 676/800 || Average Episode Length 500.00 || lr: 1.524339e-03 || dt: 0.83s |
# | Step: 677/800 || Average Episode Length 447.40 || lr: 1.516081e-03 || dt: 0.62s |
# | Step: 678/800 || Average Episode Length 500.00 || lr: 1.507884e-03 || dt: 0.69s |
# | Step: 679/800 || Average Episode Length 500.00 || lr: 1.499749e-03 || dt: 0.68s |
# | Step: 680/800 || Average Episode Length 500.00 || lr: 1.491676e-03 || dt: 0.82s |
# | Step: 681/800 || Average Episode Length 483.30 || lr: 1.483665e-03 || dt: 0.66s |
# | Step: 682/800 || Average Episode Length 478.20 || lr: 1.475716e-03 || dt: 0.66s |
# | Step: 683/800 || Average Episode Length 433.00 || lr: 1.467830e-03 || dt: 0.60s |
# | Step: 684/800 || Average Episode Length 500.00 || lr: 1.460005e-03 || dt: 0.69s |
# | Step: 685/800 || Average Episode Length 500.00 || lr: 1.452243e-03 || dt: 0.69s |
# | Step: 686/800 || Average Episode Length 500.00 || lr: 1.444544e-03 || dt: 0.69s |
# | Step: 687/800 || Average Episode Length 481.70 || lr: 1.436907e-03 || dt: 0.80s |
# | Step: 688/800 || Average Episode Length 500.00 || lr: 1.429334e-03 || dt: 0.68s |
# | Step: 689/800 || Average Episode Length 442.50 || lr: 1.421823e-03 || dt: 0.61s |
# | Step: 690/800 || Average Episode Length 494.00 || lr: 1.414375e-03 || dt: 0.68s |
# | Step: 691/800 || Average Episode Length 474.90 || lr: 1.406990e-03 || dt: 0.65s |
# | Step: 692/800 || Average Episode Length 500.00 || lr: 1.399669e-03 || dt: 0.69s |
# | Step: 693/800 || Average Episode Length 500.00 || lr: 1.392411e-03 || dt: 0.69s |
# | Step: 694/800 || Average Episode Length 500.00 || lr: 1.385216e-03 || dt: 0.84s |
# | Step: 695/800 || Average Episode Length 473.40 || lr: 1.378085e-03 || dt: 0.64s |
# | Step: 696/800 || Average Episode Length 477.60 || lr: 1.371018e-03 || dt: 0.65s |
# | Step: 697/800 || Average Episode Length 500.00 || lr: 1.364015e-03 || dt: 0.68s |
# | Step: 698/800 || Average Episode Length 500.00 || lr: 1.357076e-03 || dt: 0.69s |
# | Step: 699/800 || Average Episode Length 500.00 || lr: 1.350200e-03 || dt: 0.69s |
# | Step: 700/800 || Average Episode Length 475.90 || lr: 1.343389e-03 || dt: 0.65s |
# | Step: 701/800 || Average Episode Length 500.00 || lr: 1.336642e-03 || dt: 0.83s |
# | Step: 702/800 || Average Episode Length 457.40 || lr: 1.329960e-03 || dt: 0.63s |
# | Step: 703/800 || Average Episode Length 497.10 || lr: 1.323341e-03 || dt: 0.68s |
# | Step: 704/800 || Average Episode Length 500.00 || lr: 1.316788e-03 || dt: 0.69s |
# | Step: 705/800 || Average Episode Length 452.60 || lr: 1.310299e-03 || dt: 0.75s |
# | Step: 706/800 || Average Episode Length 438.80 || lr: 1.303875e-03 || dt: 0.60s |
# | Step: 707/800 || Average Episode Length 417.10 || lr: 1.297516e-03 || dt: 0.57s |
# | Step: 708/800 || Average Episode Length 441.80 || lr: 1.291222e-03 || dt: 0.61s |
# | Step: 709/800 || Average Episode Length 488.20 || lr: 1.284992e-03 || dt: 0.68s |
# | Step: 710/800 || Average Episode Length 466.10 || lr: 1.278828e-03 || dt: 0.66s |
# | Step: 711/800 || Average Episode Length 494.50 || lr: 1.272730e-03 || dt: 0.69s |
# | Step: 712/800 || Average Episode Length 500.00 || lr: 1.266696e-03 || dt: 0.84s |
# | Step: 713/800 || Average Episode Length 471.10 || lr: 1.260728e-03 || dt: 0.65s |
# | Step: 714/800 || Average Episode Length 498.50 || lr: 1.254826e-03 || dt: 0.68s |
# | Step: 715/800 || Average Episode Length 470.60 || lr: 1.248989e-03 || dt: 0.64s |
# | Step: 716/800 || Average Episode Length 481.10 || lr: 1.243218e-03 || dt: 0.68s |
# | Step: 717/800 || Average Episode Length 500.00 || lr: 1.237513e-03 || dt: 0.71s |
# | Step: 718/800 || Average Episode Length 468.40 || lr: 1.231873e-03 || dt: 0.66s |
# | Step: 719/800 || Average Episode Length 466.90 || lr: 1.226300e-03 || dt: 0.64s |
# | Step: 720/800 || Average Episode Length 500.00 || lr: 1.220793e-03 || dt: 0.68s |
# | Step: 721/800 || Average Episode Length 473.80 || lr: 1.215352e-03 || dt: 0.65s |
# | Step: 722/800 || Average Episode Length 500.00 || lr: 1.209977e-03 || dt: 0.71s |
# | Step: 723/800 || Average Episode Length 500.00 || lr: 1.204668e-03 || dt: 0.85s |
# | Step: 724/800 || Average Episode Length 472.30 || lr: 1.199426e-03 || dt: 0.67s |
# | Step: 725/800 || Average Episode Length 500.00 || lr: 1.194250e-03 || dt: 0.71s |
# | Step: 726/800 || Average Episode Length 500.00 || lr: 1.189141e-03 || dt: 0.71s |
# | Step: 727/800 || Average Episode Length 480.50 || lr: 1.184099e-03 || dt: 0.66s |
# | Step: 728/800 || Average Episode Length 500.00 || lr: 1.179123e-03 || dt: 0.68s |
# | Step: 729/800 || Average Episode Length 470.50 || lr: 1.174214e-03 || dt: 0.65s |
# | Step: 730/800 || Average Episode Length 500.00 || lr: 1.169372e-03 || dt: 0.82s |
# | Step: 731/800 || Average Episode Length 487.70 || lr: 1.164597e-03 || dt: 0.67s |
# | Step: 732/800 || Average Episode Length 500.00 || lr: 1.159889e-03 || dt: 0.69s |
# | Step: 733/800 || Average Episode Length 500.00 || lr: 1.155248e-03 || dt: 0.69s |
# | Step: 734/800 || Average Episode Length 454.90 || lr: 1.150674e-03 || dt: 0.63s |
# | Step: 735/800 || Average Episode Length 500.00 || lr: 1.146167e-03 || dt: 0.69s |
# | Step: 736/800 || Average Episode Length 500.00 || lr: 1.141728e-03 || dt: 0.69s |
# | Step: 737/800 || Average Episode Length 477.50 || lr: 1.137356e-03 || dt: 0.66s |
# | Step: 738/800 || Average Episode Length 481.20 || lr: 1.133052e-03 || dt: 0.66s |
# | Step: 739/800 || Average Episode Length 497.30 || lr: 1.128815e-03 || dt: 0.68s |
# | Step: 740/800 || Average Episode Length 448.70 || lr: 1.124645e-03 || dt: 0.61s |
# | Step: 741/800 || Average Episode Length 461.10 || lr: 1.120544e-03 || dt: 0.76s |
# | Step: 742/800 || Average Episode Length 500.00 || lr: 1.116510e-03 || dt: 0.68s |
# | Step: 743/800 || Average Episode Length 500.00 || lr: 1.112543e-03 || dt: 0.68s |
# | Step: 744/800 || Average Episode Length 483.60 || lr: 1.108645e-03 || dt: 0.80s |
# | Step: 745/800 || Average Episode Length 442.90 || lr: 1.104814e-03 || dt: 0.61s |
# | Step: 746/800 || Average Episode Length 480.90 || lr: 1.101052e-03 || dt: 0.66s |
# | Step: 747/800 || Average Episode Length 500.00 || lr: 1.097357e-03 || dt: 0.68s |
# | Step: 748/800 || Average Episode Length 469.80 || lr: 1.093731e-03 || dt: 0.65s |
# | Step: 749/800 || Average Episode Length 500.00 || lr: 1.090172e-03 || dt: 0.70s |
# | Step: 750/800 || Average Episode Length 500.00 || lr: 1.086682e-03 || dt: 0.71s |
# | Step: 751/800 || Average Episode Length 500.00 || lr: 1.083260e-03 || dt: 0.85s |
# | Step: 752/800 || Average Episode Length 480.10 || lr: 1.079906e-03 || dt: 0.68s |
# | Step: 753/800 || Average Episode Length 464.40 || lr: 1.076621e-03 || dt: 0.64s |
# | Step: 754/800 || Average Episode Length 471.00 || lr: 1.073404e-03 || dt: 0.65s |
# | Step: 755/800 || Average Episode Length 500.00 || lr: 1.070256e-03 || dt: 0.83s |
# | Step: 756/800 || Average Episode Length 472.00 || lr: 1.067175e-03 || dt: 0.68s |
# | Step: 757/800 || Average Episode Length 500.00 || lr: 1.064164e-03 || dt: 0.71s |
# | Step: 758/800 || Average Episode Length 486.20 || lr: 1.061221e-03 || dt: 0.69s |
# | Step: 759/800 || Average Episode Length 499.40 || lr: 1.058347e-03 || dt: 0.71s |
# | Step: 760/800 || Average Episode Length 485.90 || lr: 1.055541e-03 || dt: 0.69s |
# | Step: 761/800 || Average Episode Length 500.00 || lr: 1.052804e-03 || dt: 0.71s |
# | Step: 762/800 || Average Episode Length 500.00 || lr: 1.050136e-03 || dt: 0.85s |
# | Step: 763/800 || Average Episode Length 487.80 || lr: 1.047536e-03 || dt: 0.67s |
# | Step: 764/800 || Average Episode Length 500.00 || lr: 1.045006e-03 || dt: 0.69s |
# | Step: 765/800 || Average Episode Length 500.00 || lr: 1.042544e-03 || dt: 0.69s |
# | Step: 766/800 || Average Episode Length 475.50 || lr: 1.040151e-03 || dt: 0.66s |
# | Step: 767/800 || Average Episode Length 500.00 || lr: 1.037827e-03 || dt: 0.70s |
# | Step: 768/800 || Average Episode Length 500.00 || lr: 1.035573e-03 || dt: 0.70s |
# | Step: 769/800 || Average Episode Length 474.60 || lr: 1.033387e-03 || dt: 0.67s |
# | Step: 770/800 || Average Episode Length 467.20 || lr: 1.031270e-03 || dt: 0.64s |
# | Step: 771/800 || Average Episode Length 447.30 || lr: 1.029222e-03 || dt: 0.62s |
# | Step: 772/800 || Average Episode Length 500.00 || lr: 1.027244e-03 || dt: 0.69s |
# | Step: 773/800 || Average Episode Length 500.00 || lr: 1.025334e-03 || dt: 0.83s |
# | Step: 774/800 || Average Episode Length 500.00 || lr: 1.023494e-03 || dt: 0.69s |
# | Step: 775/800 || Average Episode Length 494.20 || lr: 1.021723e-03 || dt: 0.68s |
# | Step: 776/800 || Average Episode Length 468.20 || lr: 1.020021e-03 || dt: 0.65s |
# | Step: 777/800 || Average Episode Length 500.00 || lr: 1.018389e-03 || dt: 0.69s |
# | Step: 778/800 || Average Episode Length 471.70 || lr: 1.016825e-03 || dt: 0.65s |
# | Step: 779/800 || Average Episode Length 500.00 || lr: 1.015331e-03 || dt: 0.69s |
# | Step: 780/800 || Average Episode Length 470.70 || lr: 1.013907e-03 || dt: 0.66s |
# | Step: 781/800 || Average Episode Length 500.00 || lr: 1.012551e-03 || dt: 0.69s |
# | Step: 782/800 || Average Episode Length 470.90 || lr: 1.011266e-03 || dt: 0.65s |
# | Step: 783/800 || Average Episode Length 500.00 || lr: 1.010049e-03 || dt: 0.71s |
# | Step: 784/800 || Average Episode Length 481.40 || lr: 1.008902e-03 || dt: 0.82s |
# | Step: 785/800 || Average Episode Length 479.60 || lr: 1.007824e-03 || dt: 0.68s |
# | Step: 786/800 || Average Episode Length 471.40 || lr: 1.006816e-03 || dt: 0.67s |
# | Step: 787/800 || Average Episode Length 491.60 || lr: 1.005877e-03 || dt: 0.70s |
# | Step: 788/800 || Average Episode Length 500.00 || lr: 1.005008e-03 || dt: 0.71s |
# | Step: 789/800 || Average Episode Length 476.40 || lr: 1.004208e-03 || dt: 0.66s |
# | Step: 790/800 || Average Episode Length 480.10 || lr: 1.003478e-03 || dt: 0.67s |
# | Step: 791/800 || Average Episode Length 496.30 || lr: 1.002817e-03 || dt: 0.70s |
# | Step: 792/800 || Average Episode Length 481.10 || lr: 1.002226e-03 || dt: 0.69s |
# | Step: 793/800 || Average Episode Length 477.80 || lr: 1.001704e-03 || dt: 0.65s |
# | Step: 794/800 || Average Episode Length 449.00 || lr: 1.001252e-03 || dt: 0.62s |
# | Step: 795/800 || Average Episode Length 439.00 || lr: 1.000870e-03 || dt: 0.74s |
# | Step: 796/800 || Average Episode Length 468.00 || lr: 1.000557e-03 || dt: 0.64s |
# | Step: 797/800 || Average Episode Length 478.90 || lr: 1.000313e-03 || dt: 0.65s |
# | Step: 798/800 || Average Episode Length 463.00 || lr: 1.000139e-03 || dt: 0.63s |
# | Step: 799/800 || Average Episode Length 439.00 || lr: 1.000035e-03 || dt: 0.73s |
# | Step: 800/800 || Average Episode Length 500.00 || lr: 1.000000e-03 || dt: 0.68s |

# %%
plt.plot(avg_episode_lengths)
plt.xlabel("Number of Iterations")
plt.ylabel("Average Episode Length")
plt.show()

# %%
@torch.no_grad()
def sample_action(obs):
    left_proba = pi(torch.as_tensor(obs[np.newaxis], device=config.device)).squeeze().item()
    return int(random.random() > left_proba)

# %%
# %matplotlib ipympl
show_one_episode(sample_action, repeat=False, n_max_steps=500)
# Out:
# done at step 499
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
show_one_episode(sample_action, repeat=False, n_max_steps=500)
# Out:
# done at step 499
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
