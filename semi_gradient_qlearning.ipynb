# %% [markdown]
# # Import Modules

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
import typing as tp
import time
import random
import math
from collections import deque

import torch
from torch import nn, Tensor

SEED = 42
random.seed(SEED)
np.random.seed(SEED+1)
torch.manual_seed(SEED+2)
torch.use_deterministic_algorithms(mode=True, warn_only=False)

# %% [markdown]
# # Ops

# %%
def plot_environment(env:gym.Env, figsize:tuple[int, int]=(5, 4)):
    plt.figure(figsize=figsize)
    img = env.render()
    plt.imshow(img)
    plt.axis("off")
    return img

def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames:list, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    animation = anim.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    return animation

def show_one_episode(action_sampler:tp.Callable, n_max_steps=500, repeat=False):
    frames = []
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    obs, info = env.reset()
    with torch.no_grad():
        for step in range(n_max_steps):
            frames.append(env.render())
            action = action_sampler(obs).cpu().item()
            obs, reward, done, truncated, info = env.step(action)
            if done or truncated:
                print("done at step", step)
                break
    env.close()
    return plot_animation(frames, repeat=repeat)

# %%
class CosineDecayWithWarmup:
    def __init__(
        self,
        warmup_steps:int,
        max_learning_rate:float,
        decay_steps:int,
        min_learning_rate:float
    ):
        self.warmup_steps = warmup_steps
        self.max_learning_rate = max_learning_rate
        self.decay_steps = decay_steps
        self.min_learning_rate = min_learning_rate

    def __call__(self, step):
        # linear warmup for warmup_steps steps
        if step < self.warmup_steps:
            return self.max_learning_rate * step / self.warmup_steps
        # if it > decay_steps, return min learning rate
        if step > self.decay_steps:
            return self.min_learning_rate
        # in between, use cosine decay down to min learning rate
        decay_ratio = (step - self.warmup_steps) / (self.decay_steps - self.warmup_steps)
        coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
        return self.min_learning_rate + coeff * (self.max_learning_rate - self.min_learning_rate)

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, info = env.reset(seed=1)
obs, obs.shape, info
# Out:
# (array([ 0.00118216,  0.04504637, -0.03558404,  0.04486495], dtype=float32),
#  (4,),
#  {})

# %% [markdown]
# # Cartpole Environment
# * GOAL: Keep the pole upright for as long as possible
# ```python
# Actions:
#     left: 0
#     right: 1
#
# Observation Space: (4,)
# ```
# ![image.png](images/carpole_info.png)
# * The cart x-position (index 0) can be take values between (-4.8, 4.8), but the episode terminates if the cart leaves the (-2.4, 2.4) range.
# * The pole angle can be observed between (-.418, .418) radians (or ±24°), but the episode terminates if the pole angle is not in the range (-.2095, .2095) (or ±12°)
#
# ## Rewards
# * Since the goal is to keep the pole upright for as long as possible, a reward of +1 for every step taken, including the termination step, is allotted
#
# ## Episode End
# * The episode ends if any one of the following occurs:
#     * Termination: Pole Angle is greater than ±12°
#     * Termination: Cart Position is greater than ±2.4 (center of the cart reaches the edge of the display)
#     * Truncation: Episode length is greater than 500

# %% [markdown]
# # Q-learning

# %%
class config:
    num_iters:int = 800
    num_episodes_per_iter:int = 10
    max_steps_per_episode:int = 1000
    
    gamma:float = 0.95
    
    lr:float = 0.01
    weight_decay:float = 0.0
    batch_size:int = 64
    

    device:torch.device = torch.device("cuda" if False else "cpu") # cpu good for very very small models
    dtype:torch.dtype = torch.float16 if "cpu" in device.type else torch.float32

    autocast:torch.autocast = torch.autocast(
        device_type=device.type, dtype=dtype, enabled="cuda" in device.type
    )
    logging_interval:int = 1

    generator:torch.Generator = torch.Generator(device=device).manual_seed(SEED+3)

# %%
class DQN(nn.Module):
    def __init__(self, num_inputs:int, num_hidden:int, num_outputs:int):
        super().__init__()
        self.linear1 = nn.Linear(num_inputs, num_hidden)  # (4, 32)  (32,)
        self.linear2 = nn.Linear(num_hidden, num_hidden)  # (32, 32) (32,)
        self.linear3 = nn.Linear(num_hidden, num_outputs) # (32, 2)  (2,)

        self.elu = nn.ELU()
        self.num_actions = num_outputs

    def forward(self, x:Tensor):      # (B, num_inputs=4)
        x = self.elu(self.linear1(x)) # (B, num_hidden)
        x = self.elu(self.linear2(x)) # (B, num_hidden)
        x = self.linear3(x)           # (B, num_outputs=2) # num_outputs = number of actions
        return x

# %%
dqn = DQN(
    num_inputs=env.observation_space.shape[0],
    num_hidden=32,
    num_outputs=env.action_space.n
)
dqn.to(config.device)
# dqn.compile()

optimizer = torch.optim.NAdam(
    dqn.parameters(),
    lr=config.lr, 
    weight_decay=config.weight_decay,
)
get_lr = CosineDecayWithWarmup(
    warmup_steps=1,
    max_learning_rate=config.lr,
    decay_steps=config.num_iters,
    min_learning_rate=config.lr*0.1
)
print(len(list(dqn.parameters())), sum(p.numel() for p in dqn.parameters()), sep="\nNumber of parameters: ")
# Out:
# 6
# Number of parameters: 1282

# %%
@torch.no_grad()
def action_policy(dqn:DQN, obs:np.ndarray, epsilon:float) -> Tensor:
    if random.random() <= epsilon: return torch.randint(low=0, high=dqn.num_actions, size=(1,), device=config.device)
    else: return dqn(torch.as_tensor(obs, device=config.device).unsqueeze(0)).squeeze(0).argmax()

# %%
def play_step(dqn:DQN, obs:np.ndarray, eps:float, replay_buffer:deque):
    action = action_policy(dqn, obs, eps).item()
    next_obs, reward, done, truncated, info = env.step(action)
    done = done or truncated
    replay_buffer.append([next_obs, action, reward, obs, done])
    return next_obs, reward, done

def sample_instances_from_buffer(replay_buffer:deque, batch_size:int):
    batch_sample = random.sample(replay_buffer, batch_size) # [[s', a, r, s], [s', a, r, s], ...] with len `batch_size`
    return batch_sample

# %% [markdown]
# ![image.png](images/semi_grad_sarsa.png)

# %%
# @torch.compile
def train_step(dqn:DQN, replay_buffer:deque):
    # sample instances
    batched_samples = sample_instances_from_buffer(replay_buffer, batch_size=config.batch_size)
    instances = list(zip(*batched_samples))
    next_obs, actions, rewards, current_states, dones = [torch.as_tensor(np.array(inst), device=config.device, dtype=torch.float32) for inst in instances]
    # input model
    with torch.no_grad():
        with config.autocast:
            next_Q_val:Tensor = dqn(next_obs) # (B, num_actions)
            next_Q_val = next_Q_val.max(dim=1).values # (B,)
            #for the condition from the algorithm above
            zero_if_terminal_else_one = (~(dones.bool())).float() # 0 if done else 1
    
        Qtarget:Tensor = (rewards + config.gamma * next_Q_val * zero_if_terminal_else_one) # (B,)
    
    with config.autocast:
        Qpred:Tensor = dqn(current_states)
        Qpred = Qpred.gather(1, actions.unsqueeze(1).long()).squeeze(-1) # (B,)
        loss = nn.functional.mse_loss(Qpred, Qtarget)
    loss.backward()
    grads = [param.grad for param in dqn.parameters()]; dqn.zero_grad()
    return grads # len = 6

# %%
def apply_grads(grads:list[list[Tensor]]): # (num_episodes_per_iter=10, 6)
    param_list_len = len(grads[0]) # 6
    to_be_applied_grads:list[list[Tensor]] = [[] for _ in range(param_list_len)] # initialize list

    for n_ep_per_iter, grads_in_ep in enumerate(grads):
        for i, grad in enumerate(grads_in_ep): # (6,)
            to_be_applied_grads[i].append(grad)

    grads:list[Tensor] = [torch.stack(grad_list).mean(dim=0) for grad_list in to_be_applied_grads]
    
    for p, grad in zip(dqn.parameters(), grads):
        p.grad = grad

    optimizer.step()
    optimizer.zero_grad()

def play():
    replay_buffer = deque(maxlen=config.num_iters*config.num_episodes_per_iter*config.max_steps_per_episode)
    episode_lens = []
    # Iter Episodes
    for iter_num in range(1, config.num_iters+1):
        epsilon = max(1 - iter_num / config.num_iters, 0.01); t0 = time.time()
        all_grads = []   # (num_episodes_per_iter, 6)
        all_rewards = [] # (num_episodes_per_iter, max_steps_per_episode)

        lr = get_lr(iter_num)
        for param_group in optimizer.param_groups:
            param_group["lr"] = lr

        for episode in range(config.num_episodes_per_iter): # 10
            obs, info = env.reset(); current_rewards = []
            for step in range(config.max_steps_per_episode):
                obs, reward, done = play_step(dqn, obs, epsilon, replay_buffer)
                current_rewards.append(reward)
                if done: break
        
            # train step to get loss
            if len(replay_buffer) > config.batch_size:
                grads = train_step(dqn, replay_buffer)
                all_grads.append(grads) # (num_episodes_per_iter, 6)

            all_rewards.append(current_rewards) # ()

        # some logging
        episode_len_avg = sum(map(len, all_rewards))/config.num_episodes_per_iter; t1 = time.time(); dt = t1-t0
        episode_lens.append(episode_len_avg)
        if iter_num % config.logging_interval == 0:
            print(f"| Step: {iter_num:<4}/ {config.num_iters:<4} || Average Episode Length {episode_len_avg:<6.2f} || lr: {lr:<12e} || dt: {dt:<5.2f}s |")     

        # average gradients and apply them to increase the stability of the model (idk if this is usually done but it seems like a good idea)
        apply_grads(all_grads)
    return episode_lens

episode_lens = play()
# Out:
# | Step: 1   / 800  || Average Episode Length 22.20  || lr: 1.000000e-02 || dt: 0.02 s |
# | Step: 2   / 800  || Average Episode Length 23.70  || lr: 9.999965e-03 || dt: 0.01 s |
# | Step: 3   / 800  || Average Episode Length 24.50  || lr: 9.999861e-03 || dt: 0.01 s |
# | Step: 4   / 800  || Average Episode Length 18.80  || lr: 9.999687e-03 || dt: 0.01 s |
# | Step: 5   / 800  || Average Episode Length 24.10  || lr: 9.999443e-03 || dt: 0.01 s |
# | Step: 6   / 800  || Average Episode Length 25.50  || lr: 9.999130e-03 || dt: 0.01 s |
# | Step: 7   / 800  || Average Episode Length 17.30  || lr: 9.998748e-03 || dt: 0.01 s |
# | Step: 8   / 800  || Average Episode Length 23.30  || lr: 9.998296e-03 || dt: 0.01 s |
# | Step: 9   / 800  || Average Episode Length 27.50  || lr: 9.997774e-03 || dt: 0.01 s |
# | Step: 10  / 800  || Average Episode Length 16.80  || lr: 9.997183e-03 || dt: 0.01 s |
# | Step: 11  / 800  || Average Episode Length 19.20  || lr: 9.996522e-03 || dt: 0.01 s |
# | Step: 12  / 800  || Average Episode Length 18.90  || lr: 9.995792e-03 || dt: 0.01 s |
# | Step: 13  / 800  || Average Episode Length 17.60  || lr: 9.994992e-03 || dt: 0.01 s |
# | Step: 14  / 800  || Average Episode Length 22.00  || lr: 9.994123e-03 || dt: 0.01 s |
# | Step: 15  / 800  || Average Episode Length 19.80  || lr: 9.993184e-03 || dt: 0.01 s |
# | Step: 16  / 800  || Average Episode Length 25.10  || lr: 9.992176e-03 || dt: 0.01 s |
# | Step: 17  / 800  || Average Episode Length 16.60  || lr: 9.991098e-03 || dt: 0.01 s |
# | Step: 18  / 800  || Average Episode Length 17.40  || lr: 9.989951e-03 || dt: 0.01 s |
# | Step: 19  / 800  || Average Episode Length 21.30  || lr: 9.988734e-03 || dt: 0.01 s |
# | Step: 20  / 800  || Average Episode Length 24.70  || lr: 9.987449e-03 || dt: 0.01 s |
# | Step: 21  / 800  || Average Episode Length 20.30  || lr: 9.986093e-03 || dt: 0.01 s |
# | Step: 22  / 800  || Average Episode Length 30.60  || lr: 9.984669e-03 || dt: 0.01 s |
# | Step: 23  / 800  || Average Episode Length 32.60  || lr: 9.983175e-03 || dt: 0.01 s |
# | Step: 24  / 800  || Average Episode Length 26.30  || lr: 9.981611e-03 || dt: 0.01 s |
# | Step: 25  / 800  || Average Episode Length 21.30  || lr: 9.979979e-03 || dt: 0.01 s |
# | Step: 26  / 800  || Average Episode Length 19.80  || lr: 9.978277e-03 || dt: 0.01 s |
# | Step: 27  / 800  || Average Episode Length 26.50  || lr: 9.976506e-03 || dt: 0.01 s |
# | Step: 28  / 800  || Average Episode Length 25.90  || lr: 9.974666e-03 || dt: 0.01 s |
# | Step: 29  / 800  || Average Episode Length 29.90  || lr: 9.972756e-03 || dt: 0.01 s |
# | Step: 30  / 800  || Average Episode Length 22.30  || lr: 9.970778e-03 || dt: 0.01 s |
# | Step: 31  / 800  || Average Episode Length 19.70  || lr: 9.968730e-03 || dt: 0.01 s |
# | Step: 32  / 800  || Average Episode Length 21.70  || lr: 9.966613e-03 || dt: 0.01 s |
# | Step: 33  / 800  || Average Episode Length 21.00  || lr: 9.964427e-03 || dt: 0.01 s |
# | Step: 34  / 800  || Average Episode Length 27.10  || lr: 9.962173e-03 || dt: 0.01 s |
# | Step: 35  / 800  || Average Episode Length 23.40  || lr: 9.959849e-03 || dt: 0.01 s |
# | Step: 36  / 800  || Average Episode Length 19.30  || lr: 9.957456e-03 || dt: 0.01 s |
# | Step: 37  / 800  || Average Episode Length 27.80  || lr: 9.954994e-03 || dt: 0.01 s |
# | Step: 38  / 800  || Average Episode Length 22.70  || lr: 9.952464e-03 || dt: 0.01 s |
# | Step: 39  / 800  || Average Episode Length 23.90  || lr: 9.949864e-03 || dt: 0.01 s |
# | Step: 40  / 800  || Average Episode Length 33.70  || lr: 9.947196e-03 || dt: 0.01 s |
# | Step: 41  / 800  || Average Episode Length 17.40  || lr: 9.944459e-03 || dt: 0.01 s |
# | Step: 42  / 800  || Average Episode Length 30.20  || lr: 9.941653e-03 || dt: 0.01 s |
# | Step: 43  / 800  || Average Episode Length 18.70  || lr: 9.938779e-03 || dt: 0.01 s |
# | Step: 44  / 800  || Average Episode Length 20.20  || lr: 9.935836e-03 || dt: 0.01 s |
# | Step: 45  / 800  || Average Episode Length 25.70  || lr: 9.932825e-03 || dt: 0.01 s |
# | Step: 46  / 800  || Average Episode Length 26.50  || lr: 9.929744e-03 || dt: 0.01 s |
# | Step: 47  / 800  || Average Episode Length 20.50  || lr: 9.926596e-03 || dt: 0.01 s |
# | Step: 48  / 800  || Average Episode Length 16.30  || lr: 9.923379e-03 || dt: 0.01 s |
# | Step: 49  / 800  || Average Episode Length 21.60  || lr: 9.920094e-03 || dt: 0.01 s |
# | Step: 50  / 800  || Average Episode Length 27.40  || lr: 9.916740e-03 || dt: 0.01 s |
# | Step: 51  / 800  || Average Episode Length 19.20  || lr: 9.913318e-03 || dt: 0.01 s |
# | Step: 52  / 800  || Average Episode Length 26.00  || lr: 9.909828e-03 || dt: 0.01 s |
# | Step: 53  / 800  || Average Episode Length 26.90  || lr: 9.906269e-03 || dt: 0.01 s |
# | Step: 54  / 800  || Average Episode Length 26.20  || lr: 9.902643e-03 || dt: 0.01 s |
# | Step: 55  / 800  || Average Episode Length 25.10  || lr: 9.898948e-03 || dt: 0.01 s |
# | Step: 56  / 800  || Average Episode Length 30.00  || lr: 9.895186e-03 || dt: 0.01 s |
# | Step: 57  / 800  || Average Episode Length 19.70  || lr: 9.891355e-03 || dt: 0.01 s |
# | Step: 58  / 800  || Average Episode Length 33.80  || lr: 9.887457e-03 || dt: 0.01 s |
# | Step: 59  / 800  || Average Episode Length 29.80  || lr: 9.883490e-03 || dt: 0.01 s |
# | Step: 60  / 800  || Average Episode Length 30.00  || lr: 9.879456e-03 || dt: 0.01 s |
# | Step: 61  / 800  || Average Episode Length 29.20  || lr: 9.875355e-03 || dt: 0.01 s |
# | Step: 62  / 800  || Average Episode Length 31.60  || lr: 9.871185e-03 || dt: 0.01 s |
# | Step: 63  / 800  || Average Episode Length 19.70  || lr: 9.866948e-03 || dt: 0.01 s |
# | Step: 64  / 800  || Average Episode Length 33.70  || lr: 9.862644e-03 || dt: 0.01 s |
# | Step: 65  / 800  || Average Episode Length 26.20  || lr: 9.858272e-03 || dt: 0.01 s |
# | Step: 66  / 800  || Average Episode Length 24.60  || lr: 9.853833e-03 || dt: 0.01 s |
# | Step: 67  / 800  || Average Episode Length 24.50  || lr: 9.849326e-03 || dt: 0.01 s |
# | Step: 68  / 800  || Average Episode Length 30.50  || lr: 9.844752e-03 || dt: 0.01 s |
# | Step: 69  / 800  || Average Episode Length 25.10  || lr: 9.840111e-03 || dt: 0.01 s |
# | Step: 70  / 800  || Average Episode Length 23.70  || lr: 9.835403e-03 || dt: 0.01 s |
# | Step: 71  / 800  || Average Episode Length 26.80  || lr: 9.830628e-03 || dt: 0.01 s |
# | Step: 72  / 800  || Average Episode Length 25.10  || lr: 9.825786e-03 || dt: 0.01 s |
# | Step: 73  / 800  || Average Episode Length 26.50  || lr: 9.820877e-03 || dt: 0.01 s |
# | Step: 74  / 800  || Average Episode Length 26.00  || lr: 9.815901e-03 || dt: 0.01 s |
# | Step: 75  / 800  || Average Episode Length 35.90  || lr: 9.810859e-03 || dt: 0.01 s |
# | Step: 76  / 800  || Average Episode Length 20.60  || lr: 9.805750e-03 || dt: 0.01 s |
# | Step: 77  / 800  || Average Episode Length 20.50  || lr: 9.800574e-03 || dt: 0.01 s |
# | Step: 78  / 800  || Average Episode Length 23.80  || lr: 9.795332e-03 || dt: 0.01 s |
# | Step: 79  / 800  || Average Episode Length 22.10  || lr: 9.790023e-03 || dt: 0.01 s |
# | Step: 80  / 800  || Average Episode Length 34.20  || lr: 9.784648e-03 || dt: 0.01 s |
# | Step: 81  / 800  || Average Episode Length 26.00  || lr: 9.779207e-03 || dt: 0.01 s |
# | Step: 82  / 800  || Average Episode Length 18.50  || lr: 9.773700e-03 || dt: 0.01 s |
# | Step: 83  / 800  || Average Episode Length 22.50  || lr: 9.768127e-03 || dt: 0.01 s |
# | Step: 84  / 800  || Average Episode Length 34.40  || lr: 9.762487e-03 || dt: 0.01 s |
# | Step: 85  / 800  || Average Episode Length 30.50  || lr: 9.756782e-03 || dt: 0.01 s |
# | Step: 86  / 800  || Average Episode Length 30.20  || lr: 9.751011e-03 || dt: 0.01 s |
# | Step: 87  / 800  || Average Episode Length 32.10  || lr: 9.745174e-03 || dt: 0.01 s |
# | Step: 88  / 800  || Average Episode Length 29.70  || lr: 9.739272e-03 || dt: 0.01 s |
# | Step: 89  / 800  || Average Episode Length 29.10  || lr: 9.733304e-03 || dt: 0.01 s |
# | Step: 90  / 800  || Average Episode Length 33.60  || lr: 9.727270e-03 || dt: 0.01 s |
# | Step: 91  / 800  || Average Episode Length 39.50  || lr: 9.721172e-03 || dt: 0.01 s |
# | Step: 92  / 800  || Average Episode Length 18.30  || lr: 9.715008e-03 || dt: 0.01 s |
# | Step: 93  / 800  || Average Episode Length 26.20  || lr: 9.708778e-03 || dt: 0.01 s |
# | Step: 94  / 800  || Average Episode Length 24.10  || lr: 9.702484e-03 || dt: 0.01 s |
# | Step: 95  / 800  || Average Episode Length 34.50  || lr: 9.696125e-03 || dt: 0.01 s |
# | Step: 96  / 800  || Average Episode Length 23.20  || lr: 9.689701e-03 || dt: 0.01 s |
# | Step: 97  / 800  || Average Episode Length 24.10  || lr: 9.683212e-03 || dt: 0.01 s |
# | Step: 98  / 800  || Average Episode Length 21.20  || lr: 9.676659e-03 || dt: 0.01 s |
# | Step: 99  / 800  || Average Episode Length 28.30  || lr: 9.670040e-03 || dt: 0.01 s |
# | Step: 100 / 800  || Average Episode Length 38.00  || lr: 9.663358e-03 || dt: 0.01 s |
# | Step: 101 / 800  || Average Episode Length 24.20  || lr: 9.656611e-03 || dt: 0.01 s |
# | Step: 102 / 800  || Average Episode Length 28.20  || lr: 9.649800e-03 || dt: 0.01 s |
# | Step: 103 / 800  || Average Episode Length 32.40  || lr: 9.642924e-03 || dt: 0.01 s |
# | Step: 104 / 800  || Average Episode Length 32.40  || lr: 9.635985e-03 || dt: 0.01 s |
# | Step: 105 / 800  || Average Episode Length 41.90  || lr: 9.628982e-03 || dt: 0.01 s |
# | Step: 106 / 800  || Average Episode Length 28.80  || lr: 9.621915e-03 || dt: 0.01 s |
# | Step: 107 / 800  || Average Episode Length 30.10  || lr: 9.614784e-03 || dt: 0.01 s |
# | Step: 108 / 800  || Average Episode Length 24.40  || lr: 9.607589e-03 || dt: 0.01 s |
# | Step: 109 / 800  || Average Episode Length 27.70  || lr: 9.600331e-03 || dt: 0.01 s |
# | Step: 110 / 800  || Average Episode Length 24.80  || lr: 9.593010e-03 || dt: 0.01 s |
# | Step: 111 / 800  || Average Episode Length 37.90  || lr: 9.585625e-03 || dt: 0.01 s |
# | Step: 112 / 800  || Average Episode Length 29.30  || lr: 9.578177e-03 || dt: 0.01 s |
# | Step: 113 / 800  || Average Episode Length 29.70  || lr: 9.570666e-03 || dt: 0.01 s |
# | Step: 114 / 800  || Average Episode Length 28.50  || lr: 9.563093e-03 || dt: 0.01 s |
# | Step: 115 / 800  || Average Episode Length 40.60  || lr: 9.555456e-03 || dt: 0.01 s |
# | Step: 116 / 800  || Average Episode Length 34.10  || lr: 9.547757e-03 || dt: 0.01 s |
# | Step: 117 / 800  || Average Episode Length 28.70  || lr: 9.539995e-03 || dt: 0.01 s |
# | Step: 118 / 800  || Average Episode Length 27.70  || lr: 9.532170e-03 || dt: 0.01 s |
# | Step: 119 / 800  || Average Episode Length 27.00  || lr: 9.524284e-03 || dt: 0.01 s |
# | Step: 120 / 800  || Average Episode Length 29.10  || lr: 9.516335e-03 || dt: 0.01 s |
# | Step: 121 / 800  || Average Episode Length 44.20  || lr: 9.508324e-03 || dt: 0.01 s |
# | Step: 122 / 800  || Average Episode Length 41.90  || lr: 9.500251e-03 || dt: 0.01 s |
# | Step: 123 / 800  || Average Episode Length 29.50  || lr: 9.492116e-03 || dt: 0.01 s |
# | Step: 124 / 800  || Average Episode Length 42.40  || lr: 9.483919e-03 || dt: 0.01 s |
# | Step: 125 / 800  || Average Episode Length 30.40  || lr: 9.475661e-03 || dt: 0.01 s |
# | Step: 126 / 800  || Average Episode Length 30.70  || lr: 9.467342e-03 || dt: 0.01 s |
# | Step: 127 / 800  || Average Episode Length 35.90  || lr: 9.458961e-03 || dt: 0.01 s |
# | Step: 128 / 800  || Average Episode Length 39.70  || lr: 9.450519e-03 || dt: 0.01 s |
# | Step: 129 / 800  || Average Episode Length 43.80  || lr: 9.442015e-03 || dt: 0.01 s |
# | Step: 130 / 800  || Average Episode Length 50.10  || lr: 9.433451e-03 || dt: 0.01 s |
# | Step: 131 / 800  || Average Episode Length 33.70  || lr: 9.424826e-03 || dt: 0.01 s |
# | Step: 132 / 800  || Average Episode Length 27.90  || lr: 9.416141e-03 || dt: 0.01 s |
# | Step: 133 / 800  || Average Episode Length 27.10  || lr: 9.407395e-03 || dt: 0.01 s |
# | Step: 134 / 800  || Average Episode Length 36.90  || lr: 9.398588e-03 || dt: 0.01 s |
# | Step: 135 / 800  || Average Episode Length 42.10  || lr: 9.389721e-03 || dt: 0.01 s |
# | Step: 136 / 800  || Average Episode Length 24.10  || lr: 9.380794e-03 || dt: 0.01 s |
# | Step: 137 / 800  || Average Episode Length 33.90  || lr: 9.371807e-03 || dt: 0.01 s |
# | Step: 138 / 800  || Average Episode Length 33.80  || lr: 9.362760e-03 || dt: 0.01 s |
# | Step: 139 / 800  || Average Episode Length 42.20  || lr: 9.353654e-03 || dt: 0.01 s |
# | Step: 140 / 800  || Average Episode Length 40.00  || lr: 9.344488e-03 || dt: 0.01 s |
# | Step: 141 / 800  || Average Episode Length 30.80  || lr: 9.335262e-03 || dt: 0.01 s |
# | Step: 142 / 800  || Average Episode Length 25.90  || lr: 9.325977e-03 || dt: 0.01 s |
# | Step: 143 / 800  || Average Episode Length 39.00  || lr: 9.316633e-03 || dt: 0.01 s |
# | Step: 144 / 800  || Average Episode Length 40.20  || lr: 9.307230e-03 || dt: 0.01 s |
# | Step: 145 / 800  || Average Episode Length 37.90  || lr: 9.297768e-03 || dt: 0.10 s |
# | Step: 146 / 800  || Average Episode Length 31.30  || lr: 9.288248e-03 || dt: 0.01 s |
# | Step: 147 / 800  || Average Episode Length 40.40  || lr: 9.278668e-03 || dt: 0.01 s |
# | Step: 148 / 800  || Average Episode Length 38.20  || lr: 9.269031e-03 || dt: 0.01 s |
# | Step: 149 / 800  || Average Episode Length 33.80  || lr: 9.259335e-03 || dt: 0.01 s |
# | Step: 150 / 800  || Average Episode Length 24.20  || lr: 9.249581e-03 || dt: 0.01 s |
# | Step: 151 / 800  || Average Episode Length 46.30  || lr: 9.239769e-03 || dt: 0.01 s |
# | Step: 152 / 800  || Average Episode Length 33.20  || lr: 9.229899e-03 || dt: 0.01 s |
# | Step: 153 / 800  || Average Episode Length 35.30  || lr: 9.219972e-03 || dt: 0.01 s |
# | Step: 154 / 800  || Average Episode Length 26.60  || lr: 9.209987e-03 || dt: 0.01 s |
# | Step: 155 / 800  || Average Episode Length 33.40  || lr: 9.199945e-03 || dt: 0.01 s |
# | Step: 156 / 800  || Average Episode Length 37.60  || lr: 9.189845e-03 || dt: 0.01 s |
# | Step: 157 / 800  || Average Episode Length 37.60  || lr: 9.179689e-03 || dt: 0.01 s |
# | Step: 158 / 800  || Average Episode Length 40.60  || lr: 9.169475e-03 || dt: 0.01 s |
# | Step: 159 / 800  || Average Episode Length 40.30  || lr: 9.159205e-03 || dt: 0.01 s |
# | Step: 160 / 800  || Average Episode Length 45.40  || lr: 9.148878e-03 || dt: 0.01 s |
# | Step: 161 / 800  || Average Episode Length 37.60  || lr: 9.138495e-03 || dt: 0.01 s |
# | Step: 162 / 800  || Average Episode Length 28.10  || lr: 9.128056e-03 || dt: 0.01 s |
# | Step: 163 / 800  || Average Episode Length 24.60  || lr: 9.117561e-03 || dt: 0.01 s |
# | Step: 164 / 800  || Average Episode Length 45.30  || lr: 9.107009e-03 || dt: 0.01 s |
# | Step: 165 / 800  || Average Episode Length 29.70  || lr: 9.096402e-03 || dt: 0.01 s |
# | Step: 166 / 800  || Average Episode Length 27.40  || lr: 9.085739e-03 || dt: 0.01 s |
# | Step: 167 / 800  || Average Episode Length 46.80  || lr: 9.075021e-03 || dt: 0.01 s |
# | Step: 168 / 800  || Average Episode Length 34.00  || lr: 9.064248e-03 || dt: 0.01 s |
# | Step: 169 / 800  || Average Episode Length 31.10  || lr: 9.053419e-03 || dt: 0.01 s |
# | Step: 170 / 800  || Average Episode Length 38.20  || lr: 9.042535e-03 || dt: 0.01 s |
# | Step: 171 / 800  || Average Episode Length 47.20  || lr: 9.031597e-03 || dt: 0.01 s |
# | Step: 172 / 800  || Average Episode Length 38.20  || lr: 9.020604e-03 || dt: 0.01 s |
# | Step: 173 / 800  || Average Episode Length 51.60  || lr: 9.009557e-03 || dt: 0.01 s |
# | Step: 174 / 800  || Average Episode Length 52.00  || lr: 8.998456e-03 || dt: 0.01 s |
# | Step: 175 / 800  || Average Episode Length 31.40  || lr: 8.987300e-03 || dt: 0.01 s |
# | Step: 176 / 800  || Average Episode Length 26.00  || lr: 8.976090e-03 || dt: 0.01 s |
# | Step: 177 / 800  || Average Episode Length 37.60  || lr: 8.964827e-03 || dt: 0.01 s |
# | Step: 178 / 800  || Average Episode Length 49.10  || lr: 8.953510e-03 || dt: 0.01 s |
# | Step: 179 / 800  || Average Episode Length 33.90  || lr: 8.942140e-03 || dt: 0.01 s |
# | Step: 180 / 800  || Average Episode Length 27.70  || lr: 8.930717e-03 || dt: 0.01 s |
# | Step: 181 / 800  || Average Episode Length 39.60  || lr: 8.919240e-03 || dt: 0.01 s |
# | Step: 182 / 800  || Average Episode Length 40.80  || lr: 8.907711e-03 || dt: 0.01 s |
# | Step: 183 / 800  || Average Episode Length 42.10  || lr: 8.896129e-03 || dt: 0.01 s |
# | Step: 184 / 800  || Average Episode Length 39.90  || lr: 8.884494e-03 || dt: 0.01 s |
# | Step: 185 / 800  || Average Episode Length 34.60  || lr: 8.872807e-03 || dt: 0.01 s |
# | Step: 186 / 800  || Average Episode Length 33.90  || lr: 8.861068e-03 || dt: 0.01 s |
# | Step: 187 / 800  || Average Episode Length 44.90  || lr: 8.849277e-03 || dt: 0.01 s |
# | Step: 188 / 800  || Average Episode Length 38.00  || lr: 8.837434e-03 || dt: 0.01 s |
# | Step: 189 / 800  || Average Episode Length 38.90  || lr: 8.825540e-03 || dt: 0.01 s |
# | Step: 190 / 800  || Average Episode Length 33.00  || lr: 8.813594e-03 || dt: 0.01 s |
# | Step: 191 / 800  || Average Episode Length 46.20  || lr: 8.801597e-03 || dt: 0.01 s |
# | Step: 192 / 800  || Average Episode Length 39.30  || lr: 8.789549e-03 || dt: 0.01 s |
# | Step: 193 / 800  || Average Episode Length 53.90  || lr: 8.777450e-03 || dt: 0.01 s |
# | Step: 194 / 800  || Average Episode Length 49.70  || lr: 8.765301e-03 || dt: 0.01 s |
# | Step: 195 / 800  || Average Episode Length 29.90  || lr: 8.753101e-03 || dt: 0.01 s |
# | Step: 196 / 800  || Average Episode Length 30.30  || lr: 8.740851e-03 || dt: 0.01 s |
# | Step: 197 / 800  || Average Episode Length 48.40  || lr: 8.728550e-03 || dt: 0.01 s |
# | Step: 198 / 800  || Average Episode Length 49.80  || lr: 8.716200e-03 || dt: 0.01 s |
# | Step: 199 / 800  || Average Episode Length 57.10  || lr: 8.703800e-03 || dt: 0.01 s |
# | Step: 200 / 800  || Average Episode Length 37.70  || lr: 8.691350e-03 || dt: 0.01 s |
# | Step: 201 / 800  || Average Episode Length 49.70  || lr: 8.678851e-03 || dt: 0.01 s |
# | Step: 202 / 800  || Average Episode Length 49.40  || lr: 8.666303e-03 || dt: 0.01 s |
# | Step: 203 / 800  || Average Episode Length 45.90  || lr: 8.653706e-03 || dt: 0.01 s |
# | Step: 204 / 800  || Average Episode Length 53.80  || lr: 8.641060e-03 || dt: 0.01 s |
# | Step: 205 / 800  || Average Episode Length 33.00  || lr: 8.628366e-03 || dt: 0.01 s |
# | Step: 206 / 800  || Average Episode Length 49.00  || lr: 8.615623e-03 || dt: 0.01 s |
# | Step: 207 / 800  || Average Episode Length 41.90  || lr: 8.602832e-03 || dt: 0.01 s |
# | Step: 208 / 800  || Average Episode Length 44.10  || lr: 8.589993e-03 || dt: 0.01 s |
# | Step: 209 / 800  || Average Episode Length 50.30  || lr: 8.577107e-03 || dt: 0.01 s |
# | Step: 210 / 800  || Average Episode Length 38.40  || lr: 8.564173e-03 || dt: 0.01 s |
# | Step: 211 / 800  || Average Episode Length 49.30  || lr: 8.551191e-03 || dt: 0.01 s |
# | Step: 212 / 800  || Average Episode Length 44.90  || lr: 8.538162e-03 || dt: 0.01 s |
# | Step: 213 / 800  || Average Episode Length 46.30  || lr: 8.525087e-03 || dt: 0.01 s |
# | Step: 214 / 800  || Average Episode Length 42.90  || lr: 8.511964e-03 || dt: 0.01 s |
# | Step: 215 / 800  || Average Episode Length 90.90  || lr: 8.498795e-03 || dt: 0.02 s |
# | Step: 216 / 800  || Average Episode Length 36.70  || lr: 8.485580e-03 || dt: 0.01 s |
# | Step: 217 / 800  || Average Episode Length 49.10  || lr: 8.472318e-03 || dt: 0.01 s |
# | Step: 218 / 800  || Average Episode Length 63.70  || lr: 8.459011e-03 || dt: 0.02 s |
# | Step: 219 / 800  || Average Episode Length 63.20  || lr: 8.445657e-03 || dt: 0.02 s |
# | Step: 220 / 800  || Average Episode Length 39.50  || lr: 8.432259e-03 || dt: 0.01 s |
# | Step: 221 / 800  || Average Episode Length 43.90  || lr: 8.418815e-03 || dt: 0.01 s |
# | Step: 222 / 800  || Average Episode Length 52.50  || lr: 8.405325e-03 || dt: 0.01 s |
# | Step: 223 / 800  || Average Episode Length 54.70  || lr: 8.391791e-03 || dt: 0.01 s |
# | Step: 224 / 800  || Average Episode Length 67.30  || lr: 8.378212e-03 || dt: 0.01 s |
# | Step: 225 / 800  || Average Episode Length 34.60  || lr: 8.364589e-03 || dt: 0.01 s |
# | Step: 226 / 800  || Average Episode Length 36.60  || lr: 8.350921e-03 || dt: 0.01 s |
# | Step: 227 / 800  || Average Episode Length 49.10  || lr: 8.337210e-03 || dt: 0.01 s |
# | Step: 228 / 800  || Average Episode Length 60.00  || lr: 8.323454e-03 || dt: 0.01 s |
# | Step: 229 / 800  || Average Episode Length 39.70  || lr: 8.309655e-03 || dt: 0.01 s |
# | Step: 230 / 800  || Average Episode Length 51.00  || lr: 8.295812e-03 || dt: 0.01 s |
# | Step: 231 / 800  || Average Episode Length 81.90  || lr: 8.281926e-03 || dt: 0.02 s |
# | Step: 232 / 800  || Average Episode Length 55.50  || lr: 8.267997e-03 || dt: 0.01 s |
# | Step: 233 / 800  || Average Episode Length 41.70  || lr: 8.254026e-03 || dt: 0.01 s |
# | Step: 234 / 800  || Average Episode Length 67.20  || lr: 8.240011e-03 || dt: 0.02 s |
# | Step: 235 / 800  || Average Episode Length 53.40  || lr: 8.225955e-03 || dt: 0.01 s |
# | Step: 236 / 800  || Average Episode Length 79.40  || lr: 8.211856e-03 || dt: 0.02 s |
# | Step: 237 / 800  || Average Episode Length 43.70  || lr: 8.197715e-03 || dt: 0.01 s |
# | Step: 238 / 800  || Average Episode Length 59.30  || lr: 8.183533e-03 || dt: 0.01 s |
# | Step: 239 / 800  || Average Episode Length 64.60  || lr: 8.169309e-03 || dt: 0.01 s |
# | Step: 240 / 800  || Average Episode Length 63.20  || lr: 8.155044e-03 || dt: 0.01 s |
# | Step: 241 / 800  || Average Episode Length 58.90  || lr: 8.140737e-03 || dt: 0.01 s |
# | Step: 242 / 800  || Average Episode Length 65.90  || lr: 8.126390e-03 || dt: 0.01 s |
# | Step: 243 / 800  || Average Episode Length 60.70  || lr: 8.112003e-03 || dt: 0.01 s |
# | Step: 244 / 800  || Average Episode Length 75.70  || lr: 8.097575e-03 || dt: 0.01 s |
# | Step: 245 / 800  || Average Episode Length 53.80  || lr: 8.083107e-03 || dt: 0.01 s |
# | Step: 246 / 800  || Average Episode Length 62.50  || lr: 8.068598e-03 || dt: 0.01 s |
# | Step: 247 / 800  || Average Episode Length 56.50  || lr: 8.054051e-03 || dt: 0.01 s |
# | Step: 248 / 800  || Average Episode Length 58.90  || lr: 8.039463e-03 || dt: 0.01 s |
# | Step: 249 / 800  || Average Episode Length 63.40  || lr: 8.024837e-03 || dt: 0.01 s |
# | Step: 250 / 800  || Average Episode Length 69.30  || lr: 8.010171e-03 || dt: 0.01 s |
# | Step: 251 / 800  || Average Episode Length 49.60  || lr: 7.995467e-03 || dt: 0.01 s |
# | Step: 252 / 800  || Average Episode Length 62.70  || lr: 7.980724e-03 || dt: 0.01 s |
# | Step: 253 / 800  || Average Episode Length 71.20  || lr: 7.965942e-03 || dt: 0.01 s |
# | Step: 254 / 800  || Average Episode Length 69.90  || lr: 7.951123e-03 || dt: 0.01 s |
# | Step: 255 / 800  || Average Episode Length 63.10  || lr: 7.936266e-03 || dt: 0.01 s |
# | Step: 256 / 800  || Average Episode Length 49.30  || lr: 7.921371e-03 || dt: 0.01 s |
# | Step: 257 / 800  || Average Episode Length 48.60  || lr: 7.906438e-03 || dt: 0.01 s |
# | Step: 258 / 800  || Average Episode Length 68.30  || lr: 7.891468e-03 || dt: 0.02 s |
# | Step: 259 / 800  || Average Episode Length 64.10  || lr: 7.876462e-03 || dt: 0.01 s |
# | Step: 260 / 800  || Average Episode Length 60.30  || lr: 7.861418e-03 || dt: 0.01 s |
# | Step: 261 / 800  || Average Episode Length 79.30  || lr: 7.846339e-03 || dt: 0.02 s |
# | Step: 262 / 800  || Average Episode Length 57.00  || lr: 7.831222e-03 || dt: 0.02 s |
# | Step: 263 / 800  || Average Episode Length 61.10  || lr: 7.816070e-03 || dt: 0.01 s |
# | Step: 264 / 800  || Average Episode Length 68.30  || lr: 7.800882e-03 || dt: 0.02 s |
# | Step: 265 / 800  || Average Episode Length 76.50  || lr: 7.785659e-03 || dt: 0.02 s |
# | Step: 266 / 800  || Average Episode Length 78.70  || lr: 7.770400e-03 || dt: 0.02 s |
# | Step: 267 / 800  || Average Episode Length 49.20  || lr: 7.755106e-03 || dt: 0.01 s |
# | Step: 268 / 800  || Average Episode Length 75.60  || lr: 7.739777e-03 || dt: 0.02 s |
# | Step: 269 / 800  || Average Episode Length 72.70  || lr: 7.724413e-03 || dt: 0.02 s |
# | Step: 270 / 800  || Average Episode Length 84.50  || lr: 7.709016e-03 || dt: 0.02 s |
# | Step: 271 / 800  || Average Episode Length 77.00  || lr: 7.693583e-03 || dt: 0.02 s |
# | Step: 272 / 800  || Average Episode Length 62.70  || lr: 7.678118e-03 || dt: 0.01 s |
# | Step: 273 / 800  || Average Episode Length 95.70  || lr: 7.662618e-03 || dt: 0.02 s |
# | Step: 274 / 800  || Average Episode Length 59.80  || lr: 7.647085e-03 || dt: 0.01 s |
# | Step: 275 / 800  || Average Episode Length 91.90  || lr: 7.631519e-03 || dt: 0.02 s |
# | Step: 276 / 800  || Average Episode Length 76.10  || lr: 7.615919e-03 || dt: 0.02 s |
# | Step: 277 / 800  || Average Episode Length 66.90  || lr: 7.600287e-03 || dt: 0.02 s |
# | Step: 278 / 800  || Average Episode Length 74.30  || lr: 7.584623e-03 || dt: 0.02 s |
# | Step: 279 / 800  || Average Episode Length 70.10  || lr: 7.568926e-03 || dt: 0.01 s |
# | Step: 280 / 800  || Average Episode Length 54.00  || lr: 7.553198e-03 || dt: 0.01 s |
# | Step: 281 / 800  || Average Episode Length 61.40  || lr: 7.537438e-03 || dt: 0.01 s |
# | Step: 282 / 800  || Average Episode Length 62.70  || lr: 7.521646e-03 || dt: 0.01 s |
# | Step: 283 / 800  || Average Episode Length 45.50  || lr: 7.505823e-03 || dt: 0.01 s |
# | Step: 284 / 800  || Average Episode Length 65.70  || lr: 7.489968e-03 || dt: 0.01 s |
# | Step: 285 / 800  || Average Episode Length 82.70  || lr: 7.474084e-03 || dt: 0.02 s |
# | Step: 286 / 800  || Average Episode Length 67.30  || lr: 7.458168e-03 || dt: 0.01 s |
# | Step: 287 / 800  || Average Episode Length 96.90  || lr: 7.442223e-03 || dt: 0.02 s |
# | Step: 288 / 800  || Average Episode Length 63.60  || lr: 7.426247e-03 || dt: 0.02 s |
# | Step: 289 / 800  || Average Episode Length 89.30  || lr: 7.410241e-03 || dt: 0.02 s |
# | Step: 290 / 800  || Average Episode Length 74.70  || lr: 7.394206e-03 || dt: 0.02 s |
# | Step: 291 / 800  || Average Episode Length 82.60  || lr: 7.378142e-03 || dt: 0.02 s |
# | Step: 292 / 800  || Average Episode Length 67.80  || lr: 7.362049e-03 || dt: 0.02 s |
# | Step: 293 / 800  || Average Episode Length 86.90  || lr: 7.345927e-03 || dt: 0.02 s |
# | Step: 294 / 800  || Average Episode Length 91.90  || lr: 7.329776e-03 || dt: 0.02 s |
# | Step: 295 / 800  || Average Episode Length 58.00  || lr: 7.313597e-03 || dt: 0.01 s |
# | Step: 296 / 800  || Average Episode Length 78.10  || lr: 7.297390e-03 || dt: 0.02 s |
# | Step: 297 / 800  || Average Episode Length 92.10  || lr: 7.281155e-03 || dt: 0.02 s |
# | Step: 298 / 800  || Average Episode Length 81.10  || lr: 7.264893e-03 || dt: 0.02 s |
# | Step: 299 / 800  || Average Episode Length 72.90  || lr: 7.248604e-03 || dt: 0.02 s |
# | Step: 300 / 800  || Average Episode Length 83.00  || lr: 7.232287e-03 || dt: 0.02 s |
# | Step: 301 / 800  || Average Episode Length 60.60  || lr: 7.215944e-03 || dt: 0.02 s |
# | Step: 302 / 800  || Average Episode Length 81.20  || lr: 7.199574e-03 || dt: 0.02 s |
# | Step: 303 / 800  || Average Episode Length 74.30  || lr: 7.183177e-03 || dt: 0.02 s |
# | Step: 304 / 800  || Average Episode Length 70.60  || lr: 7.166755e-03 || dt: 0.02 s |
# | Step: 305 / 800  || Average Episode Length 74.30  || lr: 7.150307e-03 || dt: 0.02 s |
# | Step: 306 / 800  || Average Episode Length 67.60  || lr: 7.133834e-03 || dt: 0.02 s |
# | Step: 307 / 800  || Average Episode Length 64.90  || lr: 7.117335e-03 || dt: 0.02 s |
# | Step: 308 / 800  || Average Episode Length 96.10  || lr: 7.100811e-03 || dt: 0.11 s |
# | Step: 309 / 800  || Average Episode Length 67.90  || lr: 7.084263e-03 || dt: 0.02 s |
# | Step: 310 / 800  || Average Episode Length 78.20  || lr: 7.067690e-03 || dt: 0.02 s |
# | Step: 311 / 800  || Average Episode Length 88.40  || lr: 7.051092e-03 || dt: 0.02 s |
# | Step: 312 / 800  || Average Episode Length 80.70  || lr: 7.034471e-03 || dt: 0.02 s |
# | Step: 313 / 800  || Average Episode Length 67.60  || lr: 7.017826e-03 || dt: 0.02 s |
# | Step: 314 / 800  || Average Episode Length 107.30 || lr: 7.001158e-03 || dt: 0.02 s |
# | Step: 315 / 800  || Average Episode Length 89.20  || lr: 6.984466e-03 || dt: 0.02 s |
# | Step: 316 / 800  || Average Episode Length 108.50 || lr: 6.967752e-03 || dt: 0.02 s |
# | Step: 317 / 800  || Average Episode Length 43.60  || lr: 6.951014e-03 || dt: 0.01 s |
# | Step: 318 / 800  || Average Episode Length 92.10  || lr: 6.934255e-03 || dt: 0.02 s |
# | Step: 319 / 800  || Average Episode Length 119.60 || lr: 6.917473e-03 || dt: 0.02 s |
# | Step: 320 / 800  || Average Episode Length 77.30  || lr: 6.900669e-03 || dt: 0.02 s |
# | Step: 321 / 800  || Average Episode Length 87.10  || lr: 6.883844e-03 || dt: 0.02 s |
# | Step: 322 / 800  || Average Episode Length 73.70  || lr: 6.866997e-03 || dt: 0.02 s |
# | Step: 323 / 800  || Average Episode Length 117.30 || lr: 6.850129e-03 || dt: 0.02 s |
# | Step: 324 / 800  || Average Episode Length 62.70  || lr: 6.833240e-03 || dt: 0.02 s |
# | Step: 325 / 800  || Average Episode Length 97.60  || lr: 6.816331e-03 || dt: 0.02 s |
# | Step: 326 / 800  || Average Episode Length 115.70 || lr: 6.799401e-03 || dt: 0.02 s |
# | Step: 327 / 800  || Average Episode Length 106.20 || lr: 6.782451e-03 || dt: 0.02 s |
# | Step: 328 / 800  || Average Episode Length 114.10 || lr: 6.765481e-03 || dt: 0.02 s |
# | Step: 329 / 800  || Average Episode Length 108.30 || lr: 6.748492e-03 || dt: 0.03 s |
# | Step: 330 / 800  || Average Episode Length 140.20 || lr: 6.731483e-03 || dt: 0.03 s |
# | Step: 331 / 800  || Average Episode Length 98.90  || lr: 6.714456e-03 || dt: 0.02 s |
# | Step: 332 / 800  || Average Episode Length 92.90  || lr: 6.697409e-03 || dt: 0.02 s |
# | Step: 333 / 800  || Average Episode Length 93.10  || lr: 6.680345e-03 || dt: 0.02 s |
# | Step: 334 / 800  || Average Episode Length 78.50  || lr: 6.663261e-03 || dt: 0.02 s |
# | Step: 335 / 800  || Average Episode Length 100.90 || lr: 6.646160e-03 || dt: 0.02 s |
# | Step: 336 / 800  || Average Episode Length 90.40  || lr: 6.629041e-03 || dt: 0.02 s |
# | Step: 337 / 800  || Average Episode Length 76.50  || lr: 6.611905e-03 || dt: 0.02 s |
# | Step: 338 / 800  || Average Episode Length 118.00 || lr: 6.594752e-03 || dt: 0.02 s |
# | Step: 339 / 800  || Average Episode Length 62.80  || lr: 6.577581e-03 || dt: 0.02 s |
# | Step: 340 / 800  || Average Episode Length 114.00 || lr: 6.560394e-03 || dt: 0.03 s |
# | Step: 341 / 800  || Average Episode Length 145.30 || lr: 6.543191e-03 || dt: 0.03 s |
# | Step: 342 / 800  || Average Episode Length 160.70 || lr: 6.525971e-03 || dt: 0.03 s |
# | Step: 343 / 800  || Average Episode Length 109.10 || lr: 6.508736e-03 || dt: 0.02 s |
# | Step: 344 / 800  || Average Episode Length 84.00  || lr: 6.491485e-03 || dt: 0.02 s |
# | Step: 345 / 800  || Average Episode Length 104.80 || lr: 6.474218e-03 || dt: 0.02 s |
# | Step: 346 / 800  || Average Episode Length 73.50  || lr: 6.456937e-03 || dt: 0.02 s |
# | Step: 347 / 800  || Average Episode Length 111.50 || lr: 6.439640e-03 || dt: 0.02 s |
# | Step: 348 / 800  || Average Episode Length 126.30 || lr: 6.422330e-03 || dt: 0.03 s |
# | Step: 349 / 800  || Average Episode Length 119.50 || lr: 6.405005e-03 || dt: 0.03 s |
# | Step: 350 / 800  || Average Episode Length 95.40  || lr: 6.387666e-03 || dt: 0.02 s |
# | Step: 351 / 800  || Average Episode Length 89.60  || lr: 6.370313e-03 || dt: 0.02 s |
# | Step: 352 / 800  || Average Episode Length 96.00  || lr: 6.352947e-03 || dt: 0.02 s |
# | Step: 353 / 800  || Average Episode Length 86.80  || lr: 6.335567e-03 || dt: 0.02 s |
# | Step: 354 / 800  || Average Episode Length 84.60  || lr: 6.318175e-03 || dt: 0.02 s |
# | Step: 355 / 800  || Average Episode Length 86.90  || lr: 6.300770e-03 || dt: 0.02 s |
# | Step: 356 / 800  || Average Episode Length 141.90 || lr: 6.283353e-03 || dt: 0.03 s |
# | Step: 357 / 800  || Average Episode Length 97.40  || lr: 6.265923e-03 || dt: 0.02 s |
# | Step: 358 / 800  || Average Episode Length 88.20  || lr: 6.248482e-03 || dt: 0.02 s |
# | Step: 359 / 800  || Average Episode Length 123.10 || lr: 6.231029e-03 || dt: 0.03 s |
# | Step: 360 / 800  || Average Episode Length 104.10 || lr: 6.213565e-03 || dt: 0.02 s |
# | Step: 361 / 800  || Average Episode Length 89.90  || lr: 6.196090e-03 || dt: 0.02 s |
# | Step: 362 / 800  || Average Episode Length 138.10 || lr: 6.178604e-03 || dt: 0.03 s |
# | Step: 363 / 800  || Average Episode Length 78.80  || lr: 6.161108e-03 || dt: 0.02 s |
# | Step: 364 / 800  || Average Episode Length 144.60 || lr: 6.143601e-03 || dt: 0.03 s |
# | Step: 365 / 800  || Average Episode Length 131.60 || lr: 6.126084e-03 || dt: 0.03 s |
# | Step: 366 / 800  || Average Episode Length 169.90 || lr: 6.108558e-03 || dt: 0.03 s |
# | Step: 367 / 800  || Average Episode Length 139.00 || lr: 6.091022e-03 || dt: 0.03 s |
# | Step: 368 / 800  || Average Episode Length 126.60 || lr: 6.073477e-03 || dt: 0.03 s |
# | Step: 369 / 800  || Average Episode Length 76.40  || lr: 6.055924e-03 || dt: 0.02 s |
# | Step: 370 / 800  || Average Episode Length 123.80 || lr: 6.038361e-03 || dt: 0.03 s |
# | Step: 371 / 800  || Average Episode Length 119.80 || lr: 6.020791e-03 || dt: 0.02 s |
# | Step: 372 / 800  || Average Episode Length 140.70 || lr: 6.003212e-03 || dt: 0.03 s |
# | Step: 373 / 800  || Average Episode Length 145.60 || lr: 5.985626e-03 || dt: 0.03 s |
# | Step: 374 / 800  || Average Episode Length 138.40 || lr: 5.968032e-03 || dt: 0.03 s |
# | Step: 375 / 800  || Average Episode Length 126.00 || lr: 5.950431e-03 || dt: 0.03 s |
# | Step: 376 / 800  || Average Episode Length 190.00 || lr: 5.932822e-03 || dt: 0.04 s |
# | Step: 377 / 800  || Average Episode Length 241.00 || lr: 5.915208e-03 || dt: 0.05 s |
# | Step: 378 / 800  || Average Episode Length 100.10 || lr: 5.897586e-03 || dt: 0.02 s |
# | Step: 379 / 800  || Average Episode Length 136.30 || lr: 5.879959e-03 || dt: 0.03 s |
# | Step: 380 / 800  || Average Episode Length 169.20 || lr: 5.862326e-03 || dt: 0.03 s |
# | Step: 381 / 800  || Average Episode Length 139.00 || lr: 5.844687e-03 || dt: 0.03 s |
# | Step: 382 / 800  || Average Episode Length 156.10 || lr: 5.827043e-03 || dt: 0.03 s |
# | Step: 383 / 800  || Average Episode Length 135.30 || lr: 5.809393e-03 || dt: 0.03 s |
# | Step: 384 / 800  || Average Episode Length 150.20 || lr: 5.791739e-03 || dt: 0.03 s |
# | Step: 385 / 800  || Average Episode Length 108.70 || lr: 5.774081e-03 || dt: 0.02 s |
# | Step: 386 / 800  || Average Episode Length 95.10  || lr: 5.756418e-03 || dt: 0.02 s |
# | Step: 387 / 800  || Average Episode Length 102.90 || lr: 5.738751e-03 || dt: 0.02 s |
# | Step: 388 / 800  || Average Episode Length 133.60 || lr: 5.721081e-03 || dt: 0.03 s |
# | Step: 389 / 800  || Average Episode Length 134.10 || lr: 5.703407e-03 || dt: 0.03 s |
# | Step: 390 / 800  || Average Episode Length 162.00 || lr: 5.685730e-03 || dt: 0.03 s |
# | Step: 391 / 800  || Average Episode Length 164.40 || lr: 5.668050e-03 || dt: 0.03 s |
# | Step: 392 / 800  || Average Episode Length 175.40 || lr: 5.650367e-03 || dt: 0.04 s |
# | Step: 393 / 800  || Average Episode Length 135.20 || lr: 5.632683e-03 || dt: 0.03 s |
# | Step: 394 / 800  || Average Episode Length 138.70 || lr: 5.614996e-03 || dt: 0.03 s |
# | Step: 395 / 800  || Average Episode Length 127.60 || lr: 5.597307e-03 || dt: 0.03 s |
# | Step: 396 / 800  || Average Episode Length 180.80 || lr: 5.579617e-03 || dt: 0.04 s |
# | Step: 397 / 800  || Average Episode Length 137.90 || lr: 5.561926e-03 || dt: 0.03 s |
# | Step: 398 / 800  || Average Episode Length 114.30 || lr: 5.544233e-03 || dt: 0.03 s |
# | Step: 399 / 800  || Average Episode Length 168.80 || lr: 5.526540e-03 || dt: 0.03 s |
# | Step: 400 / 800  || Average Episode Length 168.70 || lr: 5.508847e-03 || dt: 0.04 s |
# | Step: 401 / 800  || Average Episode Length 143.60 || lr: 5.491153e-03 || dt: 0.03 s |
# | Step: 402 / 800  || Average Episode Length 159.50 || lr: 5.473460e-03 || dt: 0.03 s |
# | Step: 403 / 800  || Average Episode Length 169.90 || lr: 5.455767e-03 || dt: 0.04 s |
# | Step: 404 / 800  || Average Episode Length 139.20 || lr: 5.438074e-03 || dt: 0.03 s |
# | Step: 405 / 800  || Average Episode Length 157.40 || lr: 5.420383e-03 || dt: 0.03 s |
# | Step: 406 / 800  || Average Episode Length 116.80 || lr: 5.402693e-03 || dt: 0.12 s |
# | Step: 407 / 800  || Average Episode Length 134.40 || lr: 5.385004e-03 || dt: 0.03 s |
# | Step: 408 / 800  || Average Episode Length 122.00 || lr: 5.367317e-03 || dt: 0.03 s |
# | Step: 409 / 800  || Average Episode Length 151.30 || lr: 5.349633e-03 || dt: 0.03 s |
# | Step: 410 / 800  || Average Episode Length 180.00 || lr: 5.331950e-03 || dt: 0.04 s |
# | Step: 411 / 800  || Average Episode Length 150.00 || lr: 5.314270e-03 || dt: 0.03 s |
# | Step: 412 / 800  || Average Episode Length 99.30  || lr: 5.296593e-03 || dt: 0.02 s |
# | Step: 413 / 800  || Average Episode Length 145.40 || lr: 5.278919e-03 || dt: 0.03 s |
# | Step: 414 / 800  || Average Episode Length 198.10 || lr: 5.261249e-03 || dt: 0.04 s |
# | Step: 415 / 800  || Average Episode Length 116.00 || lr: 5.243582e-03 || dt: 0.03 s |
# | Step: 416 / 800  || Average Episode Length 160.40 || lr: 5.225919e-03 || dt: 0.04 s |
# | Step: 417 / 800  || Average Episode Length 169.00 || lr: 5.208261e-03 || dt: 0.04 s |
# | Step: 418 / 800  || Average Episode Length 123.50 || lr: 5.190607e-03 || dt: 0.03 s |
# | Step: 419 / 800  || Average Episode Length 208.10 || lr: 5.172957e-03 || dt: 0.04 s |
# | Step: 420 / 800  || Average Episode Length 183.80 || lr: 5.155313e-03 || dt: 0.04 s |
# | Step: 421 / 800  || Average Episode Length 146.60 || lr: 5.137674e-03 || dt: 0.03 s |
# | Step: 422 / 800  || Average Episode Length 122.20 || lr: 5.120041e-03 || dt: 0.03 s |
# | Step: 423 / 800  || Average Episode Length 155.00 || lr: 5.102414e-03 || dt: 0.04 s |
# | Step: 424 / 800  || Average Episode Length 140.00 || lr: 5.084792e-03 || dt: 0.03 s |
# | Step: 425 / 800  || Average Episode Length 147.30 || lr: 5.067178e-03 || dt: 0.03 s |
# | Step: 426 / 800  || Average Episode Length 184.00 || lr: 5.049569e-03 || dt: 0.04 s |
# | Step: 427 / 800  || Average Episode Length 184.00 || lr: 5.031968e-03 || dt: 0.05 s |
# | Step: 428 / 800  || Average Episode Length 127.90 || lr: 5.014374e-03 || dt: 0.03 s |
# | Step: 429 / 800  || Average Episode Length 194.80 || lr: 4.996788e-03 || dt: 0.04 s |
# | Step: 430 / 800  || Average Episode Length 150.70 || lr: 4.979209e-03 || dt: 0.04 s |
# | Step: 431 / 800  || Average Episode Length 203.20 || lr: 4.961639e-03 || dt: 0.04 s |
# | Step: 432 / 800  || Average Episode Length 200.10 || lr: 4.944076e-03 || dt: 0.05 s |
# | Step: 433 / 800  || Average Episode Length 171.50 || lr: 4.926523e-03 || dt: 0.04 s |
# | Step: 434 / 800  || Average Episode Length 185.80 || lr: 4.908978e-03 || dt: 0.04 s |
# | Step: 435 / 800  || Average Episode Length 137.10 || lr: 4.891442e-03 || dt: 0.03 s |
# | Step: 436 / 800  || Average Episode Length 139.80 || lr: 4.873916e-03 || dt: 0.03 s |
# | Step: 437 / 800  || Average Episode Length 169.80 || lr: 4.856399e-03 || dt: 0.04 s |
# | Step: 438 / 800  || Average Episode Length 173.80 || lr: 4.838892e-03 || dt: 0.05 s |
# | Step: 439 / 800  || Average Episode Length 223.70 || lr: 4.821396e-03 || dt: 0.06 s |
# | Step: 440 / 800  || Average Episode Length 141.30 || lr: 4.803910e-03 || dt: 0.03 s |
# | Step: 441 / 800  || Average Episode Length 198.80 || lr: 4.786435e-03 || dt: 0.04 s |
# | Step: 442 / 800  || Average Episode Length 228.60 || lr: 4.768971e-03 || dt: 0.05 s |
# | Step: 443 / 800  || Average Episode Length 192.20 || lr: 4.751518e-03 || dt: 0.05 s |
# | Step: 444 / 800  || Average Episode Length 198.70 || lr: 4.734077e-03 || dt: 0.05 s |
# | Step: 445 / 800  || Average Episode Length 160.10 || lr: 4.716647e-03 || dt: 0.04 s |
# | Step: 446 / 800  || Average Episode Length 149.40 || lr: 4.699230e-03 || dt: 0.04 s |
# | Step: 447 / 800  || Average Episode Length 217.10 || lr: 4.681825e-03 || dt: 0.05 s |
# | Step: 448 / 800  || Average Episode Length 215.10 || lr: 4.664433e-03 || dt: 0.05 s |
# | Step: 449 / 800  || Average Episode Length 231.10 || lr: 4.647053e-03 || dt: 0.05 s |
# | Step: 450 / 800  || Average Episode Length 207.90 || lr: 4.629687e-03 || dt: 0.05 s |
# | Step: 451 / 800  || Average Episode Length 201.20 || lr: 4.612334e-03 || dt: 0.05 s |
# | Step: 452 / 800  || Average Episode Length 265.00 || lr: 4.594995e-03 || dt: 0.06 s |
# | Step: 453 / 800  || Average Episode Length 180.80 || lr: 4.577670e-03 || dt: 0.04 s |
# | Step: 454 / 800  || Average Episode Length 205.10 || lr: 4.560360e-03 || dt: 0.05 s |
# | Step: 455 / 800  || Average Episode Length 207.10 || lr: 4.543063e-03 || dt: 0.05 s |
# | Step: 456 / 800  || Average Episode Length 187.20 || lr: 4.525782e-03 || dt: 0.04 s |
# | Step: 457 / 800  || Average Episode Length 204.60 || lr: 4.508515e-03 || dt: 0.05 s |
# | Step: 458 / 800  || Average Episode Length 138.40 || lr: 4.491264e-03 || dt: 0.03 s |
# | Step: 459 / 800  || Average Episode Length 177.70 || lr: 4.474029e-03 || dt: 0.04 s |
# | Step: 460 / 800  || Average Episode Length 223.30 || lr: 4.456809e-03 || dt: 0.05 s |
# | Step: 461 / 800  || Average Episode Length 188.60 || lr: 4.439606e-03 || dt: 0.04 s |
# | Step: 462 / 800  || Average Episode Length 168.30 || lr: 4.422419e-03 || dt: 0.04 s |
# | Step: 463 / 800  || Average Episode Length 209.20 || lr: 4.405248e-03 || dt: 0.05 s |
# | Step: 464 / 800  || Average Episode Length 209.80 || lr: 4.388095e-03 || dt: 0.05 s |
# | Step: 465 / 800  || Average Episode Length 211.40 || lr: 4.370959e-03 || dt: 0.05 s |
# | Step: 466 / 800  || Average Episode Length 196.20 || lr: 4.353840e-03 || dt: 0.05 s |
# | Step: 467 / 800  || Average Episode Length 167.80 || lr: 4.336739e-03 || dt: 0.04 s |
# | Step: 468 / 800  || Average Episode Length 164.70 || lr: 4.319655e-03 || dt: 0.04 s |
# | Step: 469 / 800  || Average Episode Length 194.30 || lr: 4.302591e-03 || dt: 0.04 s |
# | Step: 470 / 800  || Average Episode Length 199.40 || lr: 4.285544e-03 || dt: 0.05 s |
# | Step: 471 / 800  || Average Episode Length 216.60 || lr: 4.268517e-03 || dt: 0.05 s |
# | Step: 472 / 800  || Average Episode Length 250.60 || lr: 4.251508e-03 || dt: 0.06 s |
# | Step: 473 / 800  || Average Episode Length 232.20 || lr: 4.234519e-03 || dt: 0.05 s |
# | Step: 474 / 800  || Average Episode Length 134.60 || lr: 4.217549e-03 || dt: 0.03 s |
# | Step: 475 / 800  || Average Episode Length 235.30 || lr: 4.200599e-03 || dt: 0.05 s |
# | Step: 476 / 800  || Average Episode Length 256.90 || lr: 4.183669e-03 || dt: 0.06 s |
# | Step: 477 / 800  || Average Episode Length 299.20 || lr: 4.166760e-03 || dt: 0.07 s |
# | Step: 478 / 800  || Average Episode Length 279.00 || lr: 4.149871e-03 || dt: 0.06 s |
# | Step: 479 / 800  || Average Episode Length 241.90 || lr: 4.133003e-03 || dt: 0.06 s |
# | Step: 480 / 800  || Average Episode Length 208.10 || lr: 4.116156e-03 || dt: 0.05 s |
# | Step: 481 / 800  || Average Episode Length 219.80 || lr: 4.099331e-03 || dt: 0.05 s |
# | Step: 482 / 800  || Average Episode Length 248.00 || lr: 4.082527e-03 || dt: 0.17 s |
# | Step: 483 / 800  || Average Episode Length 206.00 || lr: 4.065745e-03 || dt: 0.05 s |
# | Step: 484 / 800  || Average Episode Length 216.30 || lr: 4.048986e-03 || dt: 0.05 s |
# | Step: 485 / 800  || Average Episode Length 228.10 || lr: 4.032248e-03 || dt: 0.05 s |
# | Step: 486 / 800  || Average Episode Length 202.00 || lr: 4.015534e-03 || dt: 0.05 s |
# | Step: 487 / 800  || Average Episode Length 204.20 || lr: 3.998842e-03 || dt: 0.05 s |
# | Step: 488 / 800  || Average Episode Length 178.50 || lr: 3.982174e-03 || dt: 0.04 s |
# | Step: 489 / 800  || Average Episode Length 195.80 || lr: 3.965529e-03 || dt: 0.05 s |
# | Step: 490 / 800  || Average Episode Length 228.60 || lr: 3.948908e-03 || dt: 0.05 s |
# | Step: 491 / 800  || Average Episode Length 230.20 || lr: 3.932310e-03 || dt: 0.06 s |
# | Step: 492 / 800  || Average Episode Length 187.80 || lr: 3.915737e-03 || dt: 0.05 s |
# | Step: 493 / 800  || Average Episode Length 232.30 || lr: 3.899189e-03 || dt: 0.05 s |
# | Step: 494 / 800  || Average Episode Length 227.80 || lr: 3.882665e-03 || dt: 0.05 s |
# | Step: 495 / 800  || Average Episode Length 286.00 || lr: 3.866166e-03 || dt: 0.07 s |
# | Step: 496 / 800  || Average Episode Length 217.90 || lr: 3.849693e-03 || dt: 0.05 s |
# | Step: 497 / 800  || Average Episode Length 300.10 || lr: 3.833245e-03 || dt: 0.07 s |
# | Step: 498 / 800  || Average Episode Length 234.90 || lr: 3.816823e-03 || dt: 0.06 s |
# | Step: 499 / 800  || Average Episode Length 226.60 || lr: 3.800426e-03 || dt: 0.06 s |
# | Step: 500 / 800  || Average Episode Length 285.90 || lr: 3.784056e-03 || dt: 0.07 s |
# | Step: 501 / 800  || Average Episode Length 213.20 || lr: 3.767713e-03 || dt: 0.05 s |
# | Step: 502 / 800  || Average Episode Length 250.10 || lr: 3.751396e-03 || dt: 0.06 s |
# | Step: 503 / 800  || Average Episode Length 223.40 || lr: 3.735107e-03 || dt: 0.06 s |
# | Step: 504 / 800  || Average Episode Length 244.70 || lr: 3.718845e-03 || dt: 0.06 s |
# | Step: 505 / 800  || Average Episode Length 147.40 || lr: 3.702610e-03 || dt: 0.04 s |
# | Step: 506 / 800  || Average Episode Length 207.30 || lr: 3.686403e-03 || dt: 0.05 s |
# | Step: 507 / 800  || Average Episode Length 207.80 || lr: 3.670224e-03 || dt: 0.05 s |
# | Step: 508 / 800  || Average Episode Length 219.40 || lr: 3.654073e-03 || dt: 0.06 s |
# | Step: 509 / 800  || Average Episode Length 233.10 || lr: 3.637951e-03 || dt: 0.06 s |
# | Step: 510 / 800  || Average Episode Length 240.60 || lr: 3.621858e-03 || dt: 0.06 s |
# | Step: 511 / 800  || Average Episode Length 264.30 || lr: 3.605794e-03 || dt: 0.07 s |
# | Step: 512 / 800  || Average Episode Length 171.10 || lr: 3.589759e-03 || dt: 0.05 s |
# | Step: 513 / 800  || Average Episode Length 207.30 || lr: 3.573753e-03 || dt: 0.05 s |
# | Step: 514 / 800  || Average Episode Length 186.60 || lr: 3.557777e-03 || dt: 0.05 s |
# | Step: 515 / 800  || Average Episode Length 201.80 || lr: 3.541832e-03 || dt: 0.05 s |
# | Step: 516 / 800  || Average Episode Length 246.60 || lr: 3.525916e-03 || dt: 0.06 s |
# | Step: 517 / 800  || Average Episode Length 241.40 || lr: 3.510032e-03 || dt: 0.06 s |
# | Step: 518 / 800  || Average Episode Length 265.30 || lr: 3.494177e-03 || dt: 0.07 s |
# | Step: 519 / 800  || Average Episode Length 217.30 || lr: 3.478354e-03 || dt: 0.06 s |
# | Step: 520 / 800  || Average Episode Length 177.00 || lr: 3.462562e-03 || dt: 0.05 s |
# | Step: 521 / 800  || Average Episode Length 221.10 || lr: 3.446802e-03 || dt: 0.06 s |
# | Step: 522 / 800  || Average Episode Length 199.20 || lr: 3.431074e-03 || dt: 0.05 s |
# | Step: 523 / 800  || Average Episode Length 249.90 || lr: 3.415377e-03 || dt: 0.06 s |
# | Step: 524 / 800  || Average Episode Length 188.20 || lr: 3.399713e-03 || dt: 0.05 s |
# | Step: 525 / 800  || Average Episode Length 234.50 || lr: 3.384081e-03 || dt: 0.06 s |
# | Step: 526 / 800  || Average Episode Length 193.70 || lr: 3.368481e-03 || dt: 0.05 s |
# | Step: 527 / 800  || Average Episode Length 225.70 || lr: 3.352915e-03 || dt: 0.06 s |
# | Step: 528 / 800  || Average Episode Length 214.10 || lr: 3.337382e-03 || dt: 0.06 s |
# | Step: 529 / 800  || Average Episode Length 259.10 || lr: 3.321882e-03 || dt: 0.06 s |
# | Step: 530 / 800  || Average Episode Length 197.20 || lr: 3.306417e-03 || dt: 0.05 s |
# | Step: 531 / 800  || Average Episode Length 272.00 || lr: 3.290984e-03 || dt: 0.07 s |
# | Step: 532 / 800  || Average Episode Length 243.10 || lr: 3.275587e-03 || dt: 0.06 s |
# | Step: 533 / 800  || Average Episode Length 276.60 || lr: 3.260223e-03 || dt: 0.07 s |
# | Step: 534 / 800  || Average Episode Length 319.20 || lr: 3.244894e-03 || dt: 0.08 s |
# | Step: 535 / 800  || Average Episode Length 303.40 || lr: 3.229600e-03 || dt: 0.08 s |
# | Step: 536 / 800  || Average Episode Length 230.80 || lr: 3.214341e-03 || dt: 0.06 s |
# | Step: 537 / 800  || Average Episode Length 311.50 || lr: 3.199118e-03 || dt: 0.08 s |
# | Step: 538 / 800  || Average Episode Length 235.90 || lr: 3.183930e-03 || dt: 0.06 s |
# | Step: 539 / 800  || Average Episode Length 283.00 || lr: 3.168778e-03 || dt: 0.07 s |
# | Step: 540 / 800  || Average Episode Length 211.30 || lr: 3.153661e-03 || dt: 0.06 s |
# | Step: 541 / 800  || Average Episode Length 255.70 || lr: 3.138582e-03 || dt: 0.07 s |
# | Step: 542 / 800  || Average Episode Length 296.00 || lr: 3.123538e-03 || dt: 0.08 s |
# | Step: 543 / 800  || Average Episode Length 284.80 || lr: 3.108532e-03 || dt: 0.07 s |
# | Step: 544 / 800  || Average Episode Length 243.50 || lr: 3.093562e-03 || dt: 0.06 s |
# | Step: 545 / 800  || Average Episode Length 237.20 || lr: 3.078629e-03 || dt: 0.06 s |
# ...
# | Step: 620 / 800  || Average Episode Length 289.50 || lr: 2.080760e-03 || dt: 0.09 s |
# | Step: 621 / 800  || Average Episode Length 310.00 || lr: 2.069283e-03 || dt: 0.10 s |
# | Step: 622 / 800  || Average Episode Length 292.00 || lr: 2.057860e-03 || dt: 0.08 s |
# | Step: 623 / 800  || Average Episode Length 266.30 || lr: 2.046490e-03 || dt: 0.08 s |
# | Step: 624 / 800  || Average Episode Length 262.20 || lr: 2.035173e-03 || dt: 0.08 s |
# | Step: 625 / 800  || Average Episode Length 264.20 || lr: 2.023910e-03 || dt: 0.08 s |
# | Step: 626 / 800  || Average Episode Length 275.40 || lr: 2.012700e-03 || dt: 0.08 s |
# | Step: 627 / 800  || Average Episode Length 225.00 || lr: 2.001544e-03 || dt: 0.07 s |
# | Step: 628 / 800  || Average Episode Length 253.40 || lr: 1.990443e-03 || dt: 0.08 s |
# | Step: 629 / 800  || Average Episode Length 258.80 || lr: 1.979396e-03 || dt: 0.08 s |
# | Step: 630 / 800  || Average Episode Length 314.40 || lr: 1.968403e-03 || dt: 0.09 s |
# | Step: 631 / 800  || Average Episode Length 253.20 || lr: 1.957465e-03 || dt: 0.08 s |
# | Step: 632 / 800  || Average Episode Length 236.10 || lr: 1.946581e-03 || dt: 0.07 s |
# | Step: 633 / 800  || Average Episode Length 238.50 || lr: 1.935752e-03 || dt: 0.08 s |
# | Step: 634 / 800  || Average Episode Length 264.30 || lr: 1.924979e-03 || dt: 0.08 s |
# | Step: 635 / 800  || Average Episode Length 236.20 || lr: 1.914261e-03 || dt: 0.07 s |
# | Step: 636 / 800  || Average Episode Length 265.40 || lr: 1.903598e-03 || dt: 0.08 s |
# | Step: 637 / 800  || Average Episode Length 251.90 || lr: 1.892991e-03 || dt: 0.08 s |
# | Step: 638 / 800  || Average Episode Length 245.20 || lr: 1.882439e-03 || dt: 0.08 s |
# | Step: 639 / 800  || Average Episode Length 251.00 || lr: 1.871944e-03 || dt: 0.08 s |
# | Step: 640 / 800  || Average Episode Length 257.60 || lr: 1.861505e-03 || dt: 0.23 s |
# | Step: 641 / 800  || Average Episode Length 266.70 || lr: 1.851122e-03 || dt: 0.08 s |
# | Step: 642 / 800  || Average Episode Length 240.60 || lr: 1.840795e-03 || dt: 0.08 s |
# | Step: 643 / 800  || Average Episode Length 256.60 || lr: 1.830525e-03 || dt: 0.08 s |
# | Step: 644 / 800  || Average Episode Length 285.60 || lr: 1.820311e-03 || dt: 0.09 s |
# | Step: 645 / 800  || Average Episode Length 282.10 || lr: 1.810155e-03 || dt: 0.09 s |
# | Step: 646 / 800  || Average Episode Length 273.20 || lr: 1.800055e-03 || dt: 0.09 s |
# | Step: 647 / 800  || Average Episode Length 276.70 || lr: 1.790013e-03 || dt: 0.08 s |
# | Step: 648 / 800  || Average Episode Length 277.80 || lr: 1.780028e-03 || dt: 0.08 s |
# | Step: 649 / 800  || Average Episode Length 264.60 || lr: 1.770101e-03 || dt: 0.09 s |
# | Step: 650 / 800  || Average Episode Length 280.70 || lr: 1.760231e-03 || dt: 0.09 s |
# | Step: 651 / 800  || Average Episode Length 310.80 || lr: 1.750419e-03 || dt: 0.09 s |
# | Step: 652 / 800  || Average Episode Length 287.60 || lr: 1.740665e-03 || dt: 0.09 s |
# | Step: 653 / 800  || Average Episode Length 291.30 || lr: 1.730969e-03 || dt: 0.09 s |
# | Step: 654 / 800  || Average Episode Length 251.60 || lr: 1.721332e-03 || dt: 0.08 s |
# | Step: 655 / 800  || Average Episode Length 264.70 || lr: 1.711752e-03 || dt: 0.09 s |
# | Step: 656 / 800  || Average Episode Length 279.50 || lr: 1.702232e-03 || dt: 0.09 s |
# | Step: 657 / 800  || Average Episode Length 262.40 || lr: 1.692770e-03 || dt: 0.08 s |
# | Step: 658 / 800  || Average Episode Length 267.30 || lr: 1.683367e-03 || dt: 0.09 s |
# | Step: 659 / 800  || Average Episode Length 273.70 || lr: 1.674023e-03 || dt: 0.09 s |
# | Step: 660 / 800  || Average Episode Length 254.30 || lr: 1.664738e-03 || dt: 0.08 s |
# | Step: 661 / 800  || Average Episode Length 295.60 || lr: 1.655512e-03 || dt: 0.10 s |
# | Step: 662 / 800  || Average Episode Length 249.60 || lr: 1.646346e-03 || dt: 0.08 s |
# | Step: 663 / 800  || Average Episode Length 272.40 || lr: 1.637240e-03 || dt: 0.09 s |
# | Step: 664 / 800  || Average Episode Length 268.40 || lr: 1.628193e-03 || dt: 0.09 s |
# | Step: 665 / 800  || Average Episode Length 274.10 || lr: 1.619206e-03 || dt: 0.09 s |
# | Step: 666 / 800  || Average Episode Length 257.00 || lr: 1.610279e-03 || dt: 0.08 s |
# | Step: 667 / 800  || Average Episode Length 266.50 || lr: 1.601412e-03 || dt: 0.09 s |
# | Step: 668 / 800  || Average Episode Length 266.20 || lr: 1.592605e-03 || dt: 0.09 s |
# | Step: 669 / 800  || Average Episode Length 274.90 || lr: 1.583859e-03 || dt: 0.09 s |
# | Step: 670 / 800  || Average Episode Length 307.50 || lr: 1.575174e-03 || dt: 0.10 s |
# | Step: 671 / 800  || Average Episode Length 280.80 || lr: 1.566549e-03 || dt: 0.09 s |
# | Step: 672 / 800  || Average Episode Length 259.40 || lr: 1.557985e-03 || dt: 0.08 s |
# | Step: 673 / 800  || Average Episode Length 266.30 || lr: 1.549481e-03 || dt: 0.09 s |
# | Step: 674 / 800  || Average Episode Length 267.40 || lr: 1.541039e-03 || dt: 0.09 s |
# | Step: 675 / 800  || Average Episode Length 287.00 || lr: 1.532658e-03 || dt: 0.09 s |
# | Step: 676 / 800  || Average Episode Length 301.20 || lr: 1.524339e-03 || dt: 0.10 s |
# | Step: 677 / 800  || Average Episode Length 283.30 || lr: 1.516081e-03 || dt: 0.09 s |
# | Step: 678 / 800  || Average Episode Length 289.60 || lr: 1.507884e-03 || dt: 0.09 s |
# | Step: 679 / 800  || Average Episode Length 312.20 || lr: 1.499749e-03 || dt: 0.10 s |
# | Step: 680 / 800  || Average Episode Length 317.40 || lr: 1.491676e-03 || dt: 0.10 s |
# | Step: 681 / 800  || Average Episode Length 285.70 || lr: 1.483665e-03 || dt: 0.10 s |
# | Step: 682 / 800  || Average Episode Length 323.50 || lr: 1.475716e-03 || dt: 0.11 s |
# | Step: 683 / 800  || Average Episode Length 305.70 || lr: 1.467830e-03 || dt: 0.10 s |
# | Step: 684 / 800  || Average Episode Length 327.00 || lr: 1.460005e-03 || dt: 0.11 s |
# | Step: 685 / 800  || Average Episode Length 284.30 || lr: 1.452243e-03 || dt: 0.10 s |
# | Step: 686 / 800  || Average Episode Length 325.00 || lr: 1.444544e-03 || dt: 0.10 s |
# | Step: 687 / 800  || Average Episode Length 313.30 || lr: 1.436907e-03 || dt: 0.10 s |
# | Step: 688 / 800  || Average Episode Length 313.40 || lr: 1.429334e-03 || dt: 0.10 s |
# | Step: 689 / 800  || Average Episode Length 340.60 || lr: 1.421823e-03 || dt: 0.11 s |
# | Step: 690 / 800  || Average Episode Length 379.30 || lr: 1.414375e-03 || dt: 0.12 s |
# | Step: 691 / 800  || Average Episode Length 281.50 || lr: 1.406990e-03 || dt: 0.10 s |
# | Step: 692 / 800  || Average Episode Length 305.20 || lr: 1.399669e-03 || dt: 0.10 s |
# | Step: 693 / 800  || Average Episode Length 273.00 || lr: 1.392411e-03 || dt: 0.10 s |
# | Step: 694 / 800  || Average Episode Length 312.00 || lr: 1.385216e-03 || dt: 0.10 s |
# | Step: 695 / 800  || Average Episode Length 344.80 || lr: 1.378085e-03 || dt: 0.11 s |
# | Step: 696 / 800  || Average Episode Length 279.60 || lr: 1.371018e-03 || dt: 0.10 s |
# | Step: 697 / 800  || Average Episode Length 278.00 || lr: 1.364015e-03 || dt: 0.10 s |
# | Step: 698 / 800  || Average Episode Length 315.30 || lr: 1.357076e-03 || dt: 0.11 s |
# | Step: 699 / 800  || Average Episode Length 327.20 || lr: 1.350200e-03 || dt: 0.11 s |
# | Step: 700 / 800  || Average Episode Length 286.20 || lr: 1.343389e-03 || dt: 0.10 s |
# | Step: 701 / 800  || Average Episode Length 309.90 || lr: 1.336642e-03 || dt: 0.10 s |
# | Step: 702 / 800  || Average Episode Length 291.00 || lr: 1.329960e-03 || dt: 0.10 s |
# | Step: 703 / 800  || Average Episode Length 319.60 || lr: 1.323341e-03 || dt: 0.11 s |
# | Step: 704 / 800  || Average Episode Length 323.30 || lr: 1.316788e-03 || dt: 0.11 s |
# | Step: 705 / 800  || Average Episode Length 324.80 || lr: 1.310299e-03 || dt: 0.11 s |
# | Step: 706 / 800  || Average Episode Length 311.30 || lr: 1.303875e-03 || dt: 0.11 s |
# | Step: 707 / 800  || Average Episode Length 291.90 || lr: 1.297516e-03 || dt: 0.10 s |
# | Step: 708 / 800  || Average Episode Length 291.40 || lr: 1.291222e-03 || dt: 0.10 s |
# | Step: 709 / 800  || Average Episode Length 307.50 || lr: 1.284992e-03 || dt: 0.11 s |
# | Step: 710 / 800  || Average Episode Length 329.00 || lr: 1.278828e-03 || dt: 0.11 s |
# | Step: 711 / 800  || Average Episode Length 313.30 || lr: 1.272730e-03 || dt: 0.11 s |
# | Step: 712 / 800  || Average Episode Length 293.90 || lr: 1.266696e-03 || dt: 0.10 s |
# | Step: 713 / 800  || Average Episode Length 307.00 || lr: 1.260728e-03 || dt: 0.10 s |
# | Step: 714 / 800  || Average Episode Length 300.70 || lr: 1.254826e-03 || dt: 0.10 s |
# | Step: 715 / 800  || Average Episode Length 295.10 || lr: 1.248989e-03 || dt: 0.10 s |
# | Step: 716 / 800  || Average Episode Length 297.40 || lr: 1.243218e-03 || dt: 0.10 s |
# | Step: 717 / 800  || Average Episode Length 312.00 || lr: 1.237513e-03 || dt: 0.11 s |
# | Step: 718 / 800  || Average Episode Length 306.10 || lr: 1.231873e-03 || dt: 0.10 s |
# | Step: 719 / 800  || Average Episode Length 314.30 || lr: 1.226300e-03 || dt: 0.11 s |
# | Step: 720 / 800  || Average Episode Length 291.50 || lr: 1.220793e-03 || dt: 0.10 s |
# | Step: 721 / 800  || Average Episode Length 303.90 || lr: 1.215352e-03 || dt: 0.11 s |
# | Step: 722 / 800  || Average Episode Length 277.40 || lr: 1.209977e-03 || dt: 0.11 s |
# | Step: 723 / 800  || Average Episode Length 281.80 || lr: 1.204668e-03 || dt: 0.11 s |
# | Step: 724 / 800  || Average Episode Length 313.70 || lr: 1.199426e-03 || dt: 0.11 s |
# | Step: 725 / 800  || Average Episode Length 300.80 || lr: 1.194250e-03 || dt: 0.11 s |
# | Step: 726 / 800  || Average Episode Length 289.20 || lr: 1.189141e-03 || dt: 0.11 s |
# | Step: 727 / 800  || Average Episode Length 290.00 || lr: 1.184099e-03 || dt: 0.11 s |
# | Step: 728 / 800  || Average Episode Length 296.10 || lr: 1.179123e-03 || dt: 0.11 s |
# | Step: 729 / 800  || Average Episode Length 274.80 || lr: 1.174214e-03 || dt: 0.10 s |
# | Step: 730 / 800  || Average Episode Length 260.70 || lr: 1.169372e-03 || dt: 0.10 s |
# | Step: 731 / 800  || Average Episode Length 292.40 || lr: 1.164597e-03 || dt: 0.11 s |
# | Step: 732 / 800  || Average Episode Length 290.50 || lr: 1.159889e-03 || dt: 0.11 s |
# | Step: 733 / 800  || Average Episode Length 275.60 || lr: 1.155248e-03 || dt: 0.10 s |
# | Step: 734 / 800  || Average Episode Length 291.40 || lr: 1.150674e-03 || dt: 0.27 s |
# | Step: 735 / 800  || Average Episode Length 281.50 || lr: 1.146167e-03 || dt: 0.11 s |
# | Step: 736 / 800  || Average Episode Length 292.30 || lr: 1.141728e-03 || dt: 0.11 s |
# | Step: 737 / 800  || Average Episode Length 268.80 || lr: 1.137356e-03 || dt: 0.10 s |
# | Step: 738 / 800  || Average Episode Length 277.00 || lr: 1.133052e-03 || dt: 0.11 s |
# | Step: 739 / 800  || Average Episode Length 281.90 || lr: 1.128815e-03 || dt: 0.11 s |
# | Step: 740 / 800  || Average Episode Length 307.30 || lr: 1.124645e-03 || dt: 0.11 s |
# | Step: 741 / 800  || Average Episode Length 293.20 || lr: 1.120544e-03 || dt: 0.10 s |
# | Step: 742 / 800  || Average Episode Length 272.40 || lr: 1.116510e-03 || dt: 0.10 s |
# | Step: 743 / 800  || Average Episode Length 268.20 || lr: 1.112543e-03 || dt: 0.10 s |
# | Step: 744 / 800  || Average Episode Length 264.60 || lr: 1.108645e-03 || dt: 0.10 s |
# | Step: 745 / 800  || Average Episode Length 281.40 || lr: 1.104814e-03 || dt: 0.11 s |
# | Step: 746 / 800  || Average Episode Length 265.60 || lr: 1.101052e-03 || dt: 0.11 s |
# | Step: 747 / 800  || Average Episode Length 260.70 || lr: 1.097357e-03 || dt: 0.11 s |
# | Step: 748 / 800  || Average Episode Length 255.30 || lr: 1.093731e-03 || dt: 0.11 s |
# | Step: 749 / 800  || Average Episode Length 267.70 || lr: 1.090172e-03 || dt: 0.11 s |
# | Step: 750 / 800  || Average Episode Length 281.70 || lr: 1.086682e-03 || dt: 0.11 s |
# | Step: 751 / 800  || Average Episode Length 306.90 || lr: 1.083260e-03 || dt: 0.12 s |
# | Step: 752 / 800  || Average Episode Length 261.00 || lr: 1.079906e-03 || dt: 0.11 s |
# | Step: 753 / 800  || Average Episode Length 269.90 || lr: 1.076621e-03 || dt: 0.11 s |
# | Step: 754 / 800  || Average Episode Length 255.40 || lr: 1.073404e-03 || dt: 0.10 s |
# | Step: 755 / 800  || Average Episode Length 259.50 || lr: 1.070256e-03 || dt: 0.10 s |
# | Step: 756 / 800  || Average Episode Length 264.00 || lr: 1.067175e-03 || dt: 0.10 s |
# | Step: 757 / 800  || Average Episode Length 257.50 || lr: 1.064164e-03 || dt: 0.11 s |
# | Step: 758 / 800  || Average Episode Length 269.00 || lr: 1.061221e-03 || dt: 0.10 s |
# | Step: 759 / 800  || Average Episode Length 246.30 || lr: 1.058347e-03 || dt: 0.10 s |
# | Step: 760 / 800  || Average Episode Length 256.40 || lr: 1.055541e-03 || dt: 0.10 s |
# | Step: 761 / 800  || Average Episode Length 253.30 || lr: 1.052804e-03 || dt: 0.11 s |
# | Step: 762 / 800  || Average Episode Length 251.10 || lr: 1.050136e-03 || dt: 0.10 s |
# | Step: 763 / 800  || Average Episode Length 258.00 || lr: 1.047536e-03 || dt: 0.10 s |
# | Step: 764 / 800  || Average Episode Length 275.30 || lr: 1.045006e-03 || dt: 0.11 s |
# | Step: 765 / 800  || Average Episode Length 262.20 || lr: 1.042544e-03 || dt: 0.11 s |
# | Step: 766 / 800  || Average Episode Length 257.30 || lr: 1.040151e-03 || dt: 0.10 s |
# | Step: 767 / 800  || Average Episode Length 279.00 || lr: 1.037827e-03 || dt: 0.11 s |
# | Step: 768 / 800  || Average Episode Length 254.50 || lr: 1.035573e-03 || dt: 0.10 s |
# | Step: 769 / 800  || Average Episode Length 271.40 || lr: 1.033387e-03 || dt: 0.12 s |
# | Step: 770 / 800  || Average Episode Length 254.60 || lr: 1.031270e-03 || dt: 0.11 s |
# | Step: 771 / 800  || Average Episode Length 270.60 || lr: 1.029222e-03 || dt: 0.11 s |
# | Step: 772 / 800  || Average Episode Length 260.40 || lr: 1.027244e-03 || dt: 0.11 s |
# | Step: 773 / 800  || Average Episode Length 253.10 || lr: 1.025334e-03 || dt: 0.11 s |
# | Step: 774 / 800  || Average Episode Length 248.60 || lr: 1.023494e-03 || dt: 0.11 s |
# | Step: 775 / 800  || Average Episode Length 266.30 || lr: 1.021723e-03 || dt: 0.11 s |
# | Step: 776 / 800  || Average Episode Length 263.00 || lr: 1.020021e-03 || dt: 0.11 s |
# | Step: 777 / 800  || Average Episode Length 252.30 || lr: 1.018389e-03 || dt: 0.11 s |
# | Step: 778 / 800  || Average Episode Length 274.20 || lr: 1.016825e-03 || dt: 0.12 s |
# | Step: 779 / 800  || Average Episode Length 264.50 || lr: 1.015331e-03 || dt: 0.11 s |
# | Step: 780 / 800  || Average Episode Length 262.90 || lr: 1.013907e-03 || dt: 0.11 s |
# | Step: 781 / 800  || Average Episode Length 267.60 || lr: 1.012551e-03 || dt: 0.11 s |
# | Step: 782 / 800  || Average Episode Length 258.90 || lr: 1.011266e-03 || dt: 0.11 s |
# | Step: 783 / 800  || Average Episode Length 266.60 || lr: 1.010049e-03 || dt: 0.11 s |
# | Step: 784 / 800  || Average Episode Length 281.20 || lr: 1.008902e-03 || dt: 0.12 s |
# | Step: 785 / 800  || Average Episode Length 261.30 || lr: 1.007824e-03 || dt: 0.11 s |
# | Step: 786 / 800  || Average Episode Length 250.00 || lr: 1.006816e-03 || dt: 0.11 s |
# | Step: 787 / 800  || Average Episode Length 267.40 || lr: 1.005877e-03 || dt: 0.12 s |
# | Step: 788 / 800  || Average Episode Length 259.70 || lr: 1.005008e-03 || dt: 0.11 s |
# | Step: 789 / 800  || Average Episode Length 274.90 || lr: 1.004208e-03 || dt: 0.12 s |
# | Step: 790 / 800  || Average Episode Length 261.70 || lr: 1.003478e-03 || dt: 0.12 s |
# | Step: 791 / 800  || Average Episode Length 276.20 || lr: 1.002817e-03 || dt: 0.12 s |
# | Step: 792 / 800  || Average Episode Length 277.30 || lr: 1.002226e-03 || dt: 0.12 s |
# | Step: 793 / 800  || Average Episode Length 276.90 || lr: 1.001704e-03 || dt: 0.12 s |
# | Step: 794 / 800  || Average Episode Length 285.80 || lr: 1.001252e-03 || dt: 0.12 s |
# | Step: 795 / 800  || Average Episode Length 271.60 || lr: 1.000870e-03 || dt: 0.12 s |
# | Step: 796 / 800  || Average Episode Length 252.20 || lr: 1.000557e-03 || dt: 0.11 s |
# | Step: 797 / 800  || Average Episode Length 282.30 || lr: 1.000313e-03 || dt: 0.12 s |
# | Step: 798 / 800  || Average Episode Length 304.40 || lr: 1.000139e-03 || dt: 0.13 s |
# | Step: 799 / 800  || Average Episode Length 341.70 || lr: 1.000035e-03 || dt: 0.14 s |
# | Step: 800 / 800  || Average Episode Length 296.30 || lr: 1.000000e-03 || dt: 0.13 s |

# %%
plt.plot(episode_lens)
plt.xlabel("Iterations")
plt.ylabel("Average Episode Length")
plt.show()

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0), repeat=False)
# Out:
# done at step 279
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
