# %% [markdown]
# # Import Modules

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
import typing as tp
import time
import random
import math
from collections import deque

import torch
from torch import nn, Tensor

SEED = 42
random.seed(SEED)
np.random.seed(SEED+1)
torch.manual_seed(SEED+2)
torch.use_deterministic_algorithms(mode=True, warn_only=False)

# %% [markdown]
# # Ops

# %%
def plot_environment(env:gym.Env, figsize:tuple[int, int]=(5, 4)):
    plt.figure(figsize=figsize)
    img = env.render()
    plt.imshow(img)
    plt.axis("off")
    return img

def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames:list, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    animation = anim.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    return animation

def show_one_episode(action_sampler:tp.Callable, n_max_steps=500, repeat=False):
    frames = []
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    obs, info = env.reset()
    with torch.no_grad():
        for step in range(n_max_steps):
            frames.append(env.render())
            action = action_sampler(obs).cpu().item()
            obs, reward, done, truncated, info = env.step(action)
            if done or truncated:
                print("done at step", step)
                break
    env.close()
    return plot_animation(frames, repeat=repeat)

# %%
class CosineDecayWithWarmup:
    def __init__(
        self,
        warmup_steps:int,
        max_learning_rate:float,
        decay_steps:int,
        min_learning_rate:float
    ):
        self.warmup_steps = warmup_steps
        self.max_learning_rate = max_learning_rate
        self.decay_steps = decay_steps
        self.min_learning_rate = min_learning_rate

    def __call__(self, step):
        # linear warmup for warmup_steps steps
        if step < self.warmup_steps:
            return self.max_learning_rate * step / self.warmup_steps
        # if it > decay_steps, return min learning rate
        if step > self.decay_steps:
            return self.min_learning_rate
        # in between, use cosine decay down to min learning rate
        decay_ratio = (step - self.warmup_steps) / (self.decay_steps - self.warmup_steps)
        coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
        return self.min_learning_rate + coeff * (self.max_learning_rate - self.min_learning_rate)

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, info = env.reset(seed=1)
obs, obs.shape, info
# Out:
# (array([ 0.00118216,  0.04504637, -0.03558404,  0.04486495], dtype=float32),
#  (4,),
#  {})

# %% [markdown]
# # Cartpole Environment
# * GOAL: Keep the pole upright for as long as possible
# ```python
# Actions:
#     left: 0
#     right: 1
#
# Observation Space: (4,)
# ```
# ![image.png](images/carpole_info.png)
# * The cart x-position (index 0) can be take values between (-4.8, 4.8), but the episode terminates if the cart leaves the (-2.4, 2.4) range.
# * The pole angle can be observed between (-.418, .418) radians (or ±24°), but the episode terminates if the pole angle is not in the range (-.2095, .2095) (or ±12°)
#
# ## Rewards
# * Since the goal is to keep the pole upright for as long as possible, a reward of +1 for every step taken, including the termination step, is allotted
#
# ## Episode End
# * The episode ends if any one of the following occurs:
#     * Termination: Pole Angle is greater than ±12°
#     * Termination: Cart Position is greater than ±2.4 (center of the cart reaches the edge of the display)
#     * Truncation: Episode length is greater than 500

# %% [markdown]
# # Q-learning

# %%
class config:
    num_iters:int = 800
    num_episodes_per_iter:int = 10
    max_steps_per_episode:int = 1000
    
    gamma:float = 0.95
    
    lr:float = 0.01
    weight_decay:float = 0.0
    batch_size:int = 64
    

    device:torch.device = torch.device("cuda" if False else "cpu") # cpu good for very very small models
    dtype:torch.dtype = torch.float16 if "cpu" in device.type else torch.float32

    autocast:torch.autocast = torch.autocast(
        device_type=device.type, dtype=dtype, enabled="cuda" in device.type
    )
    logging_interval:int = 1

    generator:torch.Generator = torch.Generator(device=device).manual_seed(SEED+343434)

# %%
class DQN(nn.Module):
    def __init__(self, num_inputs:int, num_hidden:int, num_outputs:int):
        super().__init__()
        self.linear1 = nn.Linear(num_inputs, num_hidden)  # (4, 32)  (32,)
        self.linear2 = nn.Linear(num_hidden, num_hidden)  # (32, 32) (32,)
        self.linear3 = nn.Linear(num_hidden, num_outputs) # (32, 2)  (2,)

        self.elu = nn.ELU()
        self.num_actions = num_outputs

    def forward(self, x:Tensor):      # (B, num_inputs=4)
        x = self.elu(self.linear1(x)) # (B, num_hidden)
        x = self.elu(self.linear2(x)) # (B, num_hidden)
        x = self.linear3(x)           # (B, num_outputs=2) # num_outputs = number of actions
        return x

# %%
dqn = DQN(
    num_inputs=env.observation_space.shape[0],
    num_hidden=32,
    num_outputs=env.action_space.n
)
dqn.to(config.device)
# dqn.compile()

optimizer = torch.optim.NAdam(
    dqn.parameters(),
    lr=config.lr, 
    weight_decay=config.weight_decay,
)
get_lr = CosineDecayWithWarmup(
    warmup_steps=1,
    max_learning_rate=config.lr,
    decay_steps=config.num_iters,
    min_learning_rate=config.lr*0.1
)
print(len(list(dqn.parameters())), sum(p.numel() for p in dqn.parameters()), sep="\nNumber of parameters: ")
# Out:
# 6
# Number of parameters: 1282

# %%
@torch.no_grad()
def action_policy(dqn:DQN, obs:np.ndarray, epsilon:float) -> Tensor:
    if random.random() <= epsilon: return torch.randint(low=0, high=dqn.num_actions, size=(1,), device=config.device, generator=config.generator)
    else: return dqn(torch.as_tensor(obs, device=config.device).unsqueeze(0)).squeeze(0).argmax()

# %%
def play_step(dqn:DQN, obs:np.ndarray, eps:float, replay_buffer:deque):
    action = action_policy(dqn, obs, eps).item()
    next_obs, reward, done, truncated, info = env.step(action)
    done = done or truncated
    replay_buffer.append([next_obs, action, reward, obs, done])
    return next_obs, reward, done

def sample_instances_from_buffer(replay_buffer:deque, batch_size:int):
    batch_sample = random.sample(replay_buffer, batch_size) # [[s', a, r, s], [s', a, r, s], ...] with len `batch_size`
    return batch_sample

# %% [markdown]
# ![image.png](images/semi_grad_sarsa.png)

# %%
@torch.compile
def train_step(dqn:DQN, replay_buffer:deque):
    # sample instances
    batched_samples = sample_instances_from_buffer(replay_buffer, batch_size=config.batch_size)
    instances = list(zip(*batched_samples))
    next_obs, actions, rewards, current_states, dones = [torch.as_tensor(np.array(inst), device=config.device, dtype=torch.float32) for inst in instances]
    # input model
    with torch.no_grad():
        with config.autocast:
            next_Q_val:Tensor = dqn(next_obs) # (B, num_actions)
            next_Q_val = next_Q_val.max(dim=1).values # (B,)
            #for the condition from the algorithm above
            zero_if_terminal_else_one = (~(dones.bool())).float() # 0 if done else 1
    
        Qtarget:Tensor = (rewards + config.gamma * next_Q_val * zero_if_terminal_else_one) # (B,)
    
    with config.autocast:
        Qpred:Tensor = dqn(current_states)
        Qpred = Qpred.gather(1, actions.unsqueeze(1).long()).squeeze(-1) # (B,)
        loss = nn.functional.mse_loss(Qpred, Qtarget)
    loss.backward()
    grads = [param.grad for param in dqn.parameters()]; dqn.zero_grad()
    return grads # len = 6

# %%
def apply_grads(grads:list[list[Tensor]]): # (num_episodes_per_iter=10, 6)
    param_list_len = len(grads[0]) # 6
    to_be_applied_grads:list[list[Tensor]] = [[] for _ in range(param_list_len)] # initialize list

    for n_ep_per_iter, grads_in_ep in enumerate(grads):
        for i, grad in enumerate(grads_in_ep): # (6,)
            to_be_applied_grads[i].append(grad)

    grads:list[Tensor] = [torch.stack(grad_list).mean(dim=0) for grad_list in to_be_applied_grads]
    
    for p, grad in zip(dqn.parameters(), grads):
        p.grad = grad

    optimizer.step()
    optimizer.zero_grad()

def play():
    replay_buffer = deque(maxlen=config.num_iters*config.num_episodes_per_iter*config.max_steps_per_episode)
    episode_lens = []
    # Iter Episodes
    for iter_num in range(1, config.num_iters+1):
        epsilon = 0.1 if iter_num<180 else 0.01; t0 = time.time()
        all_grads = []   # (num_episodes_per_iter, 6)
        all_rewards = [] # (num_episodes_per_iter, max_steps_per_episode)

        lr = get_lr(iter_num)
        for param_group in optimizer.param_groups:
            param_group["lr"] = lr

        for episode in range(config.num_episodes_per_iter): # 10
            obs, info = env.reset(); current_rewards = []
            for step in range(config.max_steps_per_episode):
                obs, reward, done = play_step(dqn, obs, epsilon, replay_buffer)
                current_rewards.append(reward)
                if done: break
        
            # train step to get loss
            if len(replay_buffer) > config.batch_size:
                grads = train_step(dqn, replay_buffer)
                all_grads.append(grads) # (num_episodes_per_iter, 6)

            all_rewards.append(current_rewards) # ()

        # some logging
        episode_len_avg = sum(map(len, all_rewards))/config.num_episodes_per_iter; t1 = time.time(); dt = t1-t0
        episode_lens.append(episode_len_avg)
        if iter_num % config.logging_interval == 0:
            print(f"| Step: {iter_num:<4}/ {config.num_iters:<4} || Average Episode Length {episode_len_avg:<6.2f} || lr: {lr:<12e} || dt: {dt:<5.2f}s |")     

        # average gradients and apply them to increase the stability of the model (idk if this is usually done but it seems like a good idea)
        apply_grads(all_grads)
    return episode_lens

episode_lens = play()
# Out:
# [W928 12:11:38.709896580 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:38.709910260 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:38.709913660 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:38.710174249 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:38.710185289 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:38.710187769 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.966182606 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.966195596 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.966239206 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.966242716 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.966251386 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.966279425 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.968189054 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.968197494 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.968201354 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.968233084 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.968236134 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.968238634 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.812497628 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.812518258 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.812586357 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:40.812591307 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.465080771 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.465094311 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.465104991 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.465108161 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.465110811 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.465113810 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.481724182 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.481733612 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.481739852 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.481763012 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.481766282 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:41.481799381 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# | Step: 1   / 800  || Average Episode Length 10.10  || lr: 1.000000e-02 || dt: 8.05 s |
# [W928 12:11:42.862659968 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.862672928 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.862677488 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.862683988 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.862688218 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.862692518 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.882131531 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.882141411 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.882164111 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.882168711 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.882195211 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:42.882199791 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204062745 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204076435 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204079355 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204081695 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204084325 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204088195 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204150125 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204159545 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204162145 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204170725 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204177415 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:44.204183685 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.821579338 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.821592718 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.821595838 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.821598288 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.821600658 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.821603037 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.823426267 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.823436297 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.823470107 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.823475217 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.823479457 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:45.823483247 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.237432139 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.237444649 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.237447819 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.237450349 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.237452689 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.237455259 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.257029863 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.257039183 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.257041923 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.257067692 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.257072792 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:47.257088592 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# W0928 12:11:48.948000 128931736133632 torch/_dynamo/convert_frame.py:762] [0/8] torch._dynamo hit config.cache_size_limit (8)
# W0928 12:11:48.948000 128931736133632 torch/_dynamo/convert_frame.py:762] [0/8]    function: 'train_step' (/tmp/ipykernel_14471/1436842229.py:1)
# W0928 12:11:48.948000 128931736133632 torch/_dynamo/convert_frame.py:762] [0/8]    last reason: len(L['replay_buffer']) == 69
# W0928 12:11:48.948000 128931736133632 torch/_dynamo/convert_frame.py:762] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0928 12:11:48.948000 128931736133632 torch/_dynamo/convert_frame.py:762] [0/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/torch.compiler_troubleshooting.html.
# [W928 12:11:48.900964629 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:48.900978269 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:48.900989699 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:48.900992559 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:48.900995729 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# [W928 12:11:48.901032939 PyInterpreter.cpp:256] Warning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (function decref)
# | Step: 2   / 800  || Average Episode Length 9.30   || lr: 9.999965e-03 || dt: 6.28 s |
# | Step: 3   / 800  || Average Episode Length 9.60   || lr: 9.999861e-03 || dt: 0.01 s |
# | Step: 4   / 800  || Average Episode Length 9.90   || lr: 9.999687e-03 || dt: 0.01 s |
# | Step: 5   / 800  || Average Episode Length 9.60   || lr: 9.999443e-03 || dt: 0.01 s |
# | Step: 6   / 800  || Average Episode Length 9.70   || lr: 9.999130e-03 || dt: 0.01 s |
# | Step: 7   / 800  || Average Episode Length 10.70  || lr: 9.998748e-03 || dt: 0.01 s |
# | Step: 8   / 800  || Average Episode Length 9.40   || lr: 9.998296e-03 || dt: 0.01 s |
# | Step: 9   / 800  || Average Episode Length 10.40  || lr: 9.997774e-03 || dt: 0.01 s |
# | Step: 10  / 800  || Average Episode Length 10.60  || lr: 9.997183e-03 || dt: 0.01 s |
# | Step: 11  / 800  || Average Episode Length 9.70   || lr: 9.996522e-03 || dt: 0.01 s |
# | Step: 12  / 800  || Average Episode Length 9.60   || lr: 9.995792e-03 || dt: 0.01 s |
# | Step: 13  / 800  || Average Episode Length 10.30  || lr: 9.994992e-03 || dt: 0.01 s |
# | Step: 14  / 800  || Average Episode Length 10.20  || lr: 9.994123e-03 || dt: 0.01 s |
# | Step: 15  / 800  || Average Episode Length 9.50   || lr: 9.993184e-03 || dt: 0.01 s |
# | Step: 16  / 800  || Average Episode Length 10.90  || lr: 9.992176e-03 || dt: 0.01 s |
# | Step: 17  / 800  || Average Episode Length 9.90   || lr: 9.991098e-03 || dt: 0.01 s |
# | Step: 18  / 800  || Average Episode Length 10.00  || lr: 9.989951e-03 || dt: 0.01 s |
# | Step: 19  / 800  || Average Episode Length 9.60   || lr: 9.988734e-03 || dt: 0.01 s |
# | Step: 20  / 800  || Average Episode Length 10.10  || lr: 9.987449e-03 || dt: 0.01 s |
# | Step: 21  / 800  || Average Episode Length 10.40  || lr: 9.986093e-03 || dt: 0.01 s |
# | Step: 22  / 800  || Average Episode Length 11.60  || lr: 9.984669e-03 || dt: 0.01 s |
# | Step: 23  / 800  || Average Episode Length 12.30  || lr: 9.983175e-03 || dt: 0.01 s |
# | Step: 24  / 800  || Average Episode Length 19.60  || lr: 9.981611e-03 || dt: 0.01 s |
# | Step: 25  / 800  || Average Episode Length 28.90  || lr: 9.979979e-03 || dt: 0.01 s |
# | Step: 26  / 800  || Average Episode Length 22.10  || lr: 9.978277e-03 || dt: 0.01 s |
# | Step: 27  / 800  || Average Episode Length 11.70  || lr: 9.976506e-03 || dt: 0.01 s |
# | Step: 28  / 800  || Average Episode Length 10.40  || lr: 9.974666e-03 || dt: 0.01 s |
# | Step: 29  / 800  || Average Episode Length 10.10  || lr: 9.972756e-03 || dt: 0.01 s |
# | Step: 30  / 800  || Average Episode Length 12.00  || lr: 9.970778e-03 || dt: 0.01 s |
# | Step: 31  / 800  || Average Episode Length 37.20  || lr: 9.968730e-03 || dt: 0.02 s |
# | Step: 32  / 800  || Average Episode Length 10.00  || lr: 9.966613e-03 || dt: 0.01 s |
# | Step: 33  / 800  || Average Episode Length 12.10  || lr: 9.964427e-03 || dt: 0.01 s |
# | Step: 34  / 800  || Average Episode Length 40.70  || lr: 9.962173e-03 || dt: 0.01 s |
# | Step: 35  / 800  || Average Episode Length 30.70  || lr: 9.959849e-03 || dt: 0.01 s |
# | Step: 36  / 800  || Average Episode Length 22.70  || lr: 9.957456e-03 || dt: 0.01 s |
# | Step: 37  / 800  || Average Episode Length 44.80  || lr: 9.954994e-03 || dt: 0.02 s |
# | Step: 38  / 800  || Average Episode Length 19.30  || lr: 9.952464e-03 || dt: 0.01 s |
# | Step: 39  / 800  || Average Episode Length 14.70  || lr: 9.949864e-03 || dt: 0.01 s |
# | Step: 40  / 800  || Average Episode Length 27.10  || lr: 9.947196e-03 || dt: 0.01 s |
# | Step: 41  / 800  || Average Episode Length 15.50  || lr: 9.944459e-03 || dt: 0.01 s |
# | Step: 42  / 800  || Average Episode Length 54.80  || lr: 9.941653e-03 || dt: 0.02 s |
# | Step: 43  / 800  || Average Episode Length 29.50  || lr: 9.938779e-03 || dt: 0.01 s |
# | Step: 44  / 800  || Average Episode Length 61.50  || lr: 9.935836e-03 || dt: 0.02 s |
# | Step: 45  / 800  || Average Episode Length 23.30  || lr: 9.932825e-03 || dt: 0.01 s |
# | Step: 46  / 800  || Average Episode Length 19.60  || lr: 9.929744e-03 || dt: 0.01 s |
# | Step: 47  / 800  || Average Episode Length 22.50  || lr: 9.926596e-03 || dt: 0.01 s |
# | Step: 48  / 800  || Average Episode Length 55.60  || lr: 9.923379e-03 || dt: 0.02 s |
# | Step: 49  / 800  || Average Episode Length 34.50  || lr: 9.920094e-03 || dt: 0.01 s |
# | Step: 50  / 800  || Average Episode Length 52.50  || lr: 9.916740e-03 || dt: 0.02 s |
# | Step: 51  / 800  || Average Episode Length 80.20  || lr: 9.913318e-03 || dt: 0.02 s |
# | Step: 52  / 800  || Average Episode Length 39.90  || lr: 9.909828e-03 || dt: 0.01 s |
# | Step: 53  / 800  || Average Episode Length 20.40  || lr: 9.906269e-03 || dt: 0.01 s |
# | Step: 54  / 800  || Average Episode Length 56.00  || lr: 9.902643e-03 || dt: 0.02 s |
# | Step: 55  / 800  || Average Episode Length 67.30  || lr: 9.898948e-03 || dt: 0.02 s |
# | Step: 56  / 800  || Average Episode Length 23.20  || lr: 9.895186e-03 || dt: 0.01 s |
# | Step: 57  / 800  || Average Episode Length 72.70  || lr: 9.891355e-03 || dt: 0.02 s |
# | Step: 58  / 800  || Average Episode Length 23.60  || lr: 9.887457e-03 || dt: 0.01 s |
# | Step: 59  / 800  || Average Episode Length 65.20  || lr: 9.883490e-03 || dt: 0.02 s |
# | Step: 60  / 800  || Average Episode Length 85.40  || lr: 9.879456e-03 || dt: 0.03 s |
# | Step: 61  / 800  || Average Episode Length 31.10  || lr: 9.875355e-03 || dt: 0.01 s |
# | Step: 62  / 800  || Average Episode Length 65.00  || lr: 9.871185e-03 || dt: 0.02 s |
# | Step: 63  / 800  || Average Episode Length 46.60  || lr: 9.866948e-03 || dt: 0.02 s |
# | Step: 64  / 800  || Average Episode Length 20.50  || lr: 9.862644e-03 || dt: 0.01 s |
# | Step: 65  / 800  || Average Episode Length 47.10  || lr: 9.858272e-03 || dt: 0.02 s |
# | Step: 66  / 800  || Average Episode Length 74.00  || lr: 9.853833e-03 || dt: 0.02 s |
# | Step: 67  / 800  || Average Episode Length 25.10  || lr: 9.849326e-03 || dt: 0.01 s |
# | Step: 68  / 800  || Average Episode Length 23.30  || lr: 9.844752e-03 || dt: 0.01 s |
# | Step: 69  / 800  || Average Episode Length 50.60  || lr: 9.840111e-03 || dt: 0.02 s |
# | Step: 70  / 800  || Average Episode Length 26.30  || lr: 9.835403e-03 || dt: 0.01 s |
# | Step: 71  / 800  || Average Episode Length 23.40  || lr: 9.830628e-03 || dt: 0.01 s |
# | Step: 72  / 800  || Average Episode Length 29.80  || lr: 9.825786e-03 || dt: 0.01 s |
# | Step: 73  / 800  || Average Episode Length 25.10  || lr: 9.820877e-03 || dt: 0.01 s |
# | Step: 74  / 800  || Average Episode Length 23.70  || lr: 9.815901e-03 || dt: 0.01 s |
# | Step: 75  / 800  || Average Episode Length 27.50  || lr: 9.810859e-03 || dt: 0.01 s |
# | Step: 76  / 800  || Average Episode Length 73.30  || lr: 9.805750e-03 || dt: 0.02 s |
# | Step: 77  / 800  || Average Episode Length 16.80  || lr: 9.800574e-03 || dt: 0.01 s |
# | Step: 78  / 800  || Average Episode Length 24.70  || lr: 9.795332e-03 || dt: 0.01 s |
# | Step: 79  / 800  || Average Episode Length 60.30  || lr: 9.790023e-03 || dt: 0.02 s |
# | Step: 80  / 800  || Average Episode Length 122.70 || lr: 9.784648e-03 || dt: 0.04 s |
# | Step: 81  / 800  || Average Episode Length 26.10  || lr: 9.779207e-03 || dt: 0.01 s |
# | Step: 82  / 800  || Average Episode Length 30.60  || lr: 9.773700e-03 || dt: 0.01 s |
# | Step: 83  / 800  || Average Episode Length 37.80  || lr: 9.768127e-03 || dt: 0.01 s |
# | Step: 84  / 800  || Average Episode Length 18.90  || lr: 9.762487e-03 || dt: 0.01 s |
# | Step: 85  / 800  || Average Episode Length 67.70  || lr: 9.756782e-03 || dt: 0.02 s |
# | Step: 86  / 800  || Average Episode Length 69.70  || lr: 9.751011e-03 || dt: 0.02 s |
# | Step: 87  / 800  || Average Episode Length 51.30  || lr: 9.745174e-03 || dt: 0.02 s |
# | Step: 88  / 800  || Average Episode Length 38.90  || lr: 9.739272e-03 || dt: 0.01 s |
# | Step: 89  / 800  || Average Episode Length 56.00  || lr: 9.733304e-03 || dt: 0.02 s |
# | Step: 90  / 800  || Average Episode Length 28.00  || lr: 9.727270e-03 || dt: 0.01 s |
# | Step: 91  / 800  || Average Episode Length 27.10  || lr: 9.721172e-03 || dt: 0.01 s |
# | Step: 92  / 800  || Average Episode Length 44.00  || lr: 9.715008e-03 || dt: 0.02 s |
# | Step: 93  / 800  || Average Episode Length 68.80  || lr: 9.708778e-03 || dt: 0.02 s |
# | Step: 94  / 800  || Average Episode Length 95.80  || lr: 9.702484e-03 || dt: 0.03 s |
# | Step: 95  / 800  || Average Episode Length 39.50  || lr: 9.696125e-03 || dt: 0.01 s |
# | Step: 96  / 800  || Average Episode Length 35.00  || lr: 9.689701e-03 || dt: 0.01 s |
# | Step: 97  / 800  || Average Episode Length 82.10  || lr: 9.683212e-03 || dt: 0.03 s |
# | Step: 98  / 800  || Average Episode Length 64.60  || lr: 9.676659e-03 || dt: 0.02 s |
# | Step: 99  / 800  || Average Episode Length 134.80 || lr: 9.670040e-03 || dt: 0.04 s |
# | Step: 100 / 800  || Average Episode Length 32.10  || lr: 9.663358e-03 || dt: 0.01 s |
# | Step: 101 / 800  || Average Episode Length 161.00 || lr: 9.656611e-03 || dt: 0.05 s |
# | Step: 102 / 800  || Average Episode Length 82.60  || lr: 9.649800e-03 || dt: 0.03 s |
# | Step: 103 / 800  || Average Episode Length 61.20  || lr: 9.642924e-03 || dt: 0.02 s |
# | Step: 104 / 800  || Average Episode Length 65.30  || lr: 9.635985e-03 || dt: 0.02 s |
# | Step: 105 / 800  || Average Episode Length 107.80 || lr: 9.628982e-03 || dt: 0.03 s |
# | Step: 106 / 800  || Average Episode Length 43.50  || lr: 9.621915e-03 || dt: 0.02 s |
# | Step: 107 / 800  || Average Episode Length 31.70  || lr: 9.614784e-03 || dt: 0.01 s |
# | Step: 108 / 800  || Average Episode Length 44.80  || lr: 9.607589e-03 || dt: 0.02 s |
# | Step: 109 / 800  || Average Episode Length 84.60  || lr: 9.600331e-03 || dt: 0.03 s |
# | Step: 110 / 800  || Average Episode Length 100.50 || lr: 9.593010e-03 || dt: 0.03 s |
# | Step: 111 / 800  || Average Episode Length 131.70 || lr: 9.585625e-03 || dt: 0.04 s |
# | Step: 112 / 800  || Average Episode Length 125.00 || lr: 9.578177e-03 || dt: 0.04 s |
# | Step: 113 / 800  || Average Episode Length 40.80  || lr: 9.570666e-03 || dt: 0.02 s |
# | Step: 114 / 800  || Average Episode Length 160.30 || lr: 9.563093e-03 || dt: 0.05 s |
# | Step: 115 / 800  || Average Episode Length 43.90  || lr: 9.555456e-03 || dt: 0.02 s |
# | Step: 116 / 800  || Average Episode Length 74.90  || lr: 9.547757e-03 || dt: 0.02 s |
# | Step: 117 / 800  || Average Episode Length 32.70  || lr: 9.539995e-03 || dt: 0.01 s |
# | Step: 118 / 800  || Average Episode Length 62.40  || lr: 9.532170e-03 || dt: 0.02 s |
# | Step: 119 / 800  || Average Episode Length 95.80  || lr: 9.524284e-03 || dt: 0.03 s |
# | Step: 120 / 800  || Average Episode Length 173.80 || lr: 9.516335e-03 || dt: 0.05 s |
# | Step: 121 / 800  || Average Episode Length 34.90  || lr: 9.508324e-03 || dt: 0.01 s |
# | Step: 122 / 800  || Average Episode Length 94.60  || lr: 9.500251e-03 || dt: 0.03 s |
# | Step: 123 / 800  || Average Episode Length 197.70 || lr: 9.492116e-03 || dt: 0.06 s |
# | Step: 124 / 800  || Average Episode Length 119.30 || lr: 9.483919e-03 || dt: 0.04 s |
# | Step: 125 / 800  || Average Episode Length 139.20 || lr: 9.475661e-03 || dt: 0.04 s |
# | Step: 126 / 800  || Average Episode Length 143.40 || lr: 9.467342e-03 || dt: 0.04 s |
# | Step: 127 / 800  || Average Episode Length 50.90  || lr: 9.458961e-03 || dt: 0.02 s |
# | Step: 128 / 800  || Average Episode Length 52.50  || lr: 9.450519e-03 || dt: 0.02 s |
# | Step: 129 / 800  || Average Episode Length 128.20 || lr: 9.442015e-03 || dt: 0.04 s |
# | Step: 130 / 800  || Average Episode Length 59.60  || lr: 9.433451e-03 || dt: 0.02 s |
# | Step: 131 / 800  || Average Episode Length 175.00 || lr: 9.424826e-03 || dt: 0.05 s |
# | Step: 132 / 800  || Average Episode Length 70.20  || lr: 9.416141e-03 || dt: 0.02 s |
# | Step: 133 / 800  || Average Episode Length 165.90 || lr: 9.407395e-03 || dt: 0.05 s |
# | Step: 134 / 800  || Average Episode Length 134.10 || lr: 9.398588e-03 || dt: 0.04 s |
# | Step: 135 / 800  || Average Episode Length 77.00  || lr: 9.389721e-03 || dt: 0.03 s |
# | Step: 136 / 800  || Average Episode Length 131.90 || lr: 9.380794e-03 || dt: 0.04 s |
# | Step: 137 / 800  || Average Episode Length 51.10  || lr: 9.371807e-03 || dt: 0.02 s |
# | Step: 138 / 800  || Average Episode Length 171.20 || lr: 9.362760e-03 || dt: 0.05 s |
# | Step: 139 / 800  || Average Episode Length 178.60 || lr: 9.353654e-03 || dt: 0.05 s |
# | Step: 140 / 800  || Average Episode Length 219.10 || lr: 9.344488e-03 || dt: 0.06 s |
# | Step: 141 / 800  || Average Episode Length 359.40 || lr: 9.335262e-03 || dt: 0.10 s |
# | Step: 142 / 800  || Average Episode Length 344.40 || lr: 9.325977e-03 || dt: 0.09 s |
# | Step: 143 / 800  || Average Episode Length 176.20 || lr: 9.316633e-03 || dt: 0.05 s |
# | Step: 144 / 800  || Average Episode Length 422.70 || lr: 9.307230e-03 || dt: 0.11 s |
# | Step: 145 / 800  || Average Episode Length 265.50 || lr: 9.297768e-03 || dt: 0.07 s |
# | Step: 146 / 800  || Average Episode Length 394.70 || lr: 9.288248e-03 || dt: 0.11 s |
# | Step: 147 / 800  || Average Episode Length 393.80 || lr: 9.278668e-03 || dt: 0.11 s |
# | Step: 148 / 800  || Average Episode Length 250.20 || lr: 9.269031e-03 || dt: 0.07 s |
# | Step: 149 / 800  || Average Episode Length 333.20 || lr: 9.259335e-03 || dt: 0.09 s |
# | Step: 150 / 800  || Average Episode Length 183.10 || lr: 9.249581e-03 || dt: 0.05 s |
# | Step: 151 / 800  || Average Episode Length 158.70 || lr: 9.239769e-03 || dt: 0.05 s |
# | Step: 152 / 800  || Average Episode Length 184.90 || lr: 9.229899e-03 || dt: 0.05 s |
# | Step: 153 / 800  || Average Episode Length 212.30 || lr: 9.219972e-03 || dt: 0.06 s |
# | Step: 154 / 800  || Average Episode Length 151.40 || lr: 9.209987e-03 || dt: 0.04 s |
# | Step: 155 / 800  || Average Episode Length 122.90 || lr: 9.199945e-03 || dt: 0.04 s |
# | Step: 156 / 800  || Average Episode Length 114.30 || lr: 9.189845e-03 || dt: 0.03 s |
# | Step: 157 / 800  || Average Episode Length 90.10  || lr: 9.179689e-03 || dt: 0.03 s |
# | Step: 158 / 800  || Average Episode Length 42.60  || lr: 9.169475e-03 || dt: 0.02 s |
# | Step: 159 / 800  || Average Episode Length 197.00 || lr: 9.159205e-03 || dt: 0.05 s |
# | Step: 160 / 800  || Average Episode Length 151.30 || lr: 9.148878e-03 || dt: 0.04 s |
# | Step: 161 / 800  || Average Episode Length 177.90 || lr: 9.138495e-03 || dt: 0.05 s |
# | Step: 162 / 800  || Average Episode Length 199.20 || lr: 9.128056e-03 || dt: 0.06 s |
# | Step: 163 / 800  || Average Episode Length 143.60 || lr: 9.117561e-03 || dt: 0.04 s |
# | Step: 164 / 800  || Average Episode Length 274.70 || lr: 9.107009e-03 || dt: 0.08 s |
# | Step: 165 / 800  || Average Episode Length 226.40 || lr: 9.096402e-03 || dt: 0.06 s |
# | Step: 166 / 800  || Average Episode Length 195.00 || lr: 9.085739e-03 || dt: 0.06 s |
# | Step: 167 / 800  || Average Episode Length 376.20 || lr: 9.075021e-03 || dt: 0.10 s |
# | Step: 168 / 800  || Average Episode Length 201.10 || lr: 9.064248e-03 || dt: 0.06 s |
# | Step: 169 / 800  || Average Episode Length 311.20 || lr: 9.053419e-03 || dt: 0.08 s |
# | Step: 170 / 800  || Average Episode Length 193.80 || lr: 9.042535e-03 || dt: 0.06 s |
# | Step: 171 / 800  || Average Episode Length 387.00 || lr: 9.031597e-03 || dt: 0.11 s |
# | Step: 172 / 800  || Average Episode Length 209.30 || lr: 9.020604e-03 || dt: 0.06 s |
# | Step: 173 / 800  || Average Episode Length 209.00 || lr: 9.009557e-03 || dt: 0.06 s |
# | Step: 174 / 800  || Average Episode Length 392.50 || lr: 8.998456e-03 || dt: 0.11 s |
# | Step: 175 / 800  || Average Episode Length 278.70 || lr: 8.987300e-03 || dt: 0.08 s |
# /home/vvy/Desktop/repos/Reinforcement-Learning/.venv/lib/python3.11/site-packages/torch/nn/functional.py:1593: UserWarning: Deallocating Tensor that still has live PyObject references.  This probably happened because you took out a weak reference to Tensor and didn't call _fix_weakref() after dereferencing it.  Subsequent accesses to this tensor via the PyObject will now fail. (Triggered internally at ../torch/csrc/PyInterpreter.cpp:256.)
#   result = torch._C._nn.elu(input, alpha)
# | Step: 176 / 800  || Average Episode Length 309.50 || lr: 8.976090e-03 || dt: 0.39 s |
# | Step: 177 / 800  || Average Episode Length 212.60 || lr: 8.964827e-03 || dt: 0.06 s |
# | Step: 178 / 800  || Average Episode Length 249.30 || lr: 8.953510e-03 || dt: 0.07 s |
# | Step: 179 / 800  || Average Episode Length 398.40 || lr: 8.942140e-03 || dt: 0.11 s |
# | Step: 180 / 800  || Average Episode Length 287.00 || lr: 8.930717e-03 || dt: 0.08 s |
# | Step: 181 / 800  || Average Episode Length 457.20 || lr: 8.919240e-03 || dt: 0.13 s |
# | Step: 182 / 800  || Average Episode Length 368.40 || lr: 8.907711e-03 || dt: 0.11 s |
# | Step: 183 / 800  || Average Episode Length 379.10 || lr: 8.896129e-03 || dt: 0.11 s |
# | Step: 184 / 800  || Average Episode Length 217.10 || lr: 8.884494e-03 || dt: 0.07 s |
# | Step: 185 / 800  || Average Episode Length 200.40 || lr: 8.872807e-03 || dt: 0.06 s |
# | Step: 186 / 800  || Average Episode Length 206.90 || lr: 8.861068e-03 || dt: 0.06 s |
# | Step: 187 / 800  || Average Episode Length 234.10 || lr: 8.849277e-03 || dt: 0.07 s |
# | Step: 188 / 800  || Average Episode Length 257.80 || lr: 8.837434e-03 || dt: 0.08 s |
# | Step: 189 / 800  || Average Episode Length 215.20 || lr: 8.825540e-03 || dt: 0.07 s |
# | Step: 190 / 800  || Average Episode Length 350.20 || lr: 8.813594e-03 || dt: 0.10 s |
# | Step: 191 / 800  || Average Episode Length 316.00 || lr: 8.801597e-03 || dt: 0.09 s |
# | Step: 192 / 800  || Average Episode Length 411.60 || lr: 8.789549e-03 || dt: 0.11 s |
# | Step: 193 / 800  || Average Episode Length 221.40 || lr: 8.777450e-03 || dt: 0.07 s |
# | Step: 194 / 800  || Average Episode Length 398.10 || lr: 8.765301e-03 || dt: 0.11 s |
# | Step: 195 / 800  || Average Episode Length 339.50 || lr: 8.753101e-03 || dt: 0.10 s |
# | Step: 196 / 800  || Average Episode Length 363.80 || lr: 8.740851e-03 || dt: 0.10 s |
# | Step: 197 / 800  || Average Episode Length 389.70 || lr: 8.728550e-03 || dt: 0.11 s |
# | Step: 198 / 800  || Average Episode Length 363.30 || lr: 8.716200e-03 || dt: 0.11 s |
# | Step: 199 / 800  || Average Episode Length 353.20 || lr: 8.703800e-03 || dt: 0.10 s |
# | Step: 200 / 800  || Average Episode Length 333.20 || lr: 8.691350e-03 || dt: 0.10 s |
# ...
# | Step: 620 / 800  || Average Episode Length 290.10 || lr: 2.080760e-03 || dt: 0.13 s |
# | Step: 621 / 800  || Average Episode Length 305.60 || lr: 2.069283e-03 || dt: 0.14 s |
# | Step: 622 / 800  || Average Episode Length 304.70 || lr: 2.057860e-03 || dt: 0.13 s |
# | Step: 623 / 800  || Average Episode Length 253.00 || lr: 2.046490e-03 || dt: 0.13 s |
# | Step: 624 / 800  || Average Episode Length 324.80 || lr: 2.035173e-03 || dt: 0.14 s |
# | Step: 625 / 800  || Average Episode Length 319.20 || lr: 2.023910e-03 || dt: 0.15 s |
# | Step: 626 / 800  || Average Episode Length 305.00 || lr: 2.012700e-03 || dt: 0.14 s |
# | Step: 627 / 800  || Average Episode Length 341.70 || lr: 2.001544e-03 || dt: 0.15 s |
# | Step: 628 / 800  || Average Episode Length 345.30 || lr: 1.990443e-03 || dt: 0.15 s |
# | Step: 629 / 800  || Average Episode Length 355.40 || lr: 1.979396e-03 || dt: 0.16 s |
# | Step: 630 / 800  || Average Episode Length 289.90 || lr: 1.968403e-03 || dt: 0.14 s |
# | Step: 631 / 800  || Average Episode Length 331.60 || lr: 1.957465e-03 || dt: 0.15 s |
# | Step: 632 / 800  || Average Episode Length 356.80 || lr: 1.946581e-03 || dt: 0.16 s |
# | Step: 633 / 800  || Average Episode Length 310.70 || lr: 1.935752e-03 || dt: 0.14 s |
# | Step: 634 / 800  || Average Episode Length 319.30 || lr: 1.924979e-03 || dt: 0.14 s |
# | Step: 635 / 800  || Average Episode Length 327.40 || lr: 1.914261e-03 || dt: 0.14 s |
# | Step: 636 / 800  || Average Episode Length 312.20 || lr: 1.903598e-03 || dt: 0.14 s |
# | Step: 637 / 800  || Average Episode Length 347.60 || lr: 1.892991e-03 || dt: 0.15 s |
# | Step: 638 / 800  || Average Episode Length 319.90 || lr: 1.882439e-03 || dt: 0.14 s |
# | Step: 639 / 800  || Average Episode Length 338.40 || lr: 1.871944e-03 || dt: 0.15 s |
# | Step: 640 / 800  || Average Episode Length 319.50 || lr: 1.861505e-03 || dt: 0.14 s |
# | Step: 641 / 800  || Average Episode Length 399.80 || lr: 1.851122e-03 || dt: 0.17 s |
# | Step: 642 / 800  || Average Episode Length 372.70 || lr: 1.840795e-03 || dt: 0.16 s |
# | Step: 643 / 800  || Average Episode Length 354.40 || lr: 1.830525e-03 || dt: 0.15 s |
# | Step: 644 / 800  || Average Episode Length 314.70 || lr: 1.820311e-03 || dt: 0.15 s |
# | Step: 645 / 800  || Average Episode Length 319.00 || lr: 1.810155e-03 || dt: 0.15 s |
# | Step: 646 / 800  || Average Episode Length 346.50 || lr: 1.800055e-03 || dt: 0.15 s |
# | Step: 647 / 800  || Average Episode Length 333.40 || lr: 1.790013e-03 || dt: 0.15 s |
# | Step: 648 / 800  || Average Episode Length 333.30 || lr: 1.780028e-03 || dt: 0.15 s |
# | Step: 649 / 800  || Average Episode Length 382.80 || lr: 1.770101e-03 || dt: 0.16 s |
# | Step: 650 / 800  || Average Episode Length 311.60 || lr: 1.760231e-03 || dt: 0.14 s |
# | Step: 651 / 800  || Average Episode Length 332.10 || lr: 1.750419e-03 || dt: 0.56 s |
# | Step: 652 / 800  || Average Episode Length 282.80 || lr: 1.740665e-03 || dt: 0.14 s |
# | Step: 653 / 800  || Average Episode Length 320.60 || lr: 1.730969e-03 || dt: 0.15 s |
# | Step: 654 / 800  || Average Episode Length 323.30 || lr: 1.721332e-03 || dt: 0.15 s |
# | Step: 655 / 800  || Average Episode Length 341.10 || lr: 1.711752e-03 || dt: 0.16 s |
# | Step: 656 / 800  || Average Episode Length 327.20 || lr: 1.702232e-03 || dt: 0.17 s |
# | Step: 657 / 800  || Average Episode Length 328.30 || lr: 1.692770e-03 || dt: 0.16 s |
# | Step: 658 / 800  || Average Episode Length 320.50 || lr: 1.683367e-03 || dt: 0.16 s |
# | Step: 659 / 800  || Average Episode Length 304.80 || lr: 1.674023e-03 || dt: 0.14 s |
# | Step: 660 / 800  || Average Episode Length 358.30 || lr: 1.664738e-03 || dt: 0.16 s |
# | Step: 661 / 800  || Average Episode Length 279.10 || lr: 1.655512e-03 || dt: 0.14 s |
# | Step: 662 / 800  || Average Episode Length 351.50 || lr: 1.646346e-03 || dt: 0.16 s |
# | Step: 663 / 800  || Average Episode Length 320.30 || lr: 1.637240e-03 || dt: 0.17 s |
# | Step: 664 / 800  || Average Episode Length 317.50 || lr: 1.628193e-03 || dt: 0.15 s |
# | Step: 665 / 800  || Average Episode Length 321.30 || lr: 1.619206e-03 || dt: 0.15 s |
# | Step: 666 / 800  || Average Episode Length 310.00 || lr: 1.610279e-03 || dt: 0.15 s |
# | Step: 667 / 800  || Average Episode Length 266.90 || lr: 1.601412e-03 || dt: 0.13 s |
# | Step: 668 / 800  || Average Episode Length 289.90 || lr: 1.592605e-03 || dt: 0.14 s |
# | Step: 669 / 800  || Average Episode Length 372.40 || lr: 1.583859e-03 || dt: 0.16 s |
# | Step: 670 / 800  || Average Episode Length 283.80 || lr: 1.575174e-03 || dt: 0.14 s |
# | Step: 671 / 800  || Average Episode Length 270.20 || lr: 1.566549e-03 || dt: 0.14 s |
# | Step: 672 / 800  || Average Episode Length 317.10 || lr: 1.557985e-03 || dt: 0.16 s |
# | Step: 673 / 800  || Average Episode Length 314.70 || lr: 1.549481e-03 || dt: 0.15 s |
# | Step: 674 / 800  || Average Episode Length 377.80 || lr: 1.541039e-03 || dt: 0.17 s |
# | Step: 675 / 800  || Average Episode Length 279.50 || lr: 1.532658e-03 || dt: 0.14 s |
# | Step: 676 / 800  || Average Episode Length 305.10 || lr: 1.524339e-03 || dt: 0.14 s |
# | Step: 677 / 800  || Average Episode Length 321.30 || lr: 1.516081e-03 || dt: 0.15 s |
# | Step: 678 / 800  || Average Episode Length 323.70 || lr: 1.507884e-03 || dt: 0.15 s |
# | Step: 679 / 800  || Average Episode Length 281.50 || lr: 1.499749e-03 || dt: 0.14 s |
# | Step: 680 / 800  || Average Episode Length 338.90 || lr: 1.491676e-03 || dt: 0.15 s |
# | Step: 681 / 800  || Average Episode Length 356.30 || lr: 1.483665e-03 || dt: 0.16 s |
# | Step: 682 / 800  || Average Episode Length 324.00 || lr: 1.475716e-03 || dt: 0.15 s |
# | Step: 683 / 800  || Average Episode Length 389.60 || lr: 1.467830e-03 || dt: 0.17 s |
# | Step: 684 / 800  || Average Episode Length 334.50 || lr: 1.460005e-03 || dt: 0.15 s |
# | Step: 685 / 800  || Average Episode Length 328.10 || lr: 1.452243e-03 || dt: 0.16 s |
# | Step: 686 / 800  || Average Episode Length 323.20 || lr: 1.444544e-03 || dt: 0.16 s |
# | Step: 687 / 800  || Average Episode Length 332.70 || lr: 1.436907e-03 || dt: 0.16 s |
# | Step: 688 / 800  || Average Episode Length 345.50 || lr: 1.429334e-03 || dt: 0.16 s |
# | Step: 689 / 800  || Average Episode Length 338.40 || lr: 1.421823e-03 || dt: 0.16 s |
# | Step: 690 / 800  || Average Episode Length 289.80 || lr: 1.414375e-03 || dt: 0.14 s |
# | Step: 691 / 800  || Average Episode Length 409.40 || lr: 1.406990e-03 || dt: 0.17 s |
# | Step: 692 / 800  || Average Episode Length 357.30 || lr: 1.399669e-03 || dt: 0.16 s |
# | Step: 693 / 800  || Average Episode Length 382.40 || lr: 1.392411e-03 || dt: 0.17 s |
# | Step: 694 / 800  || Average Episode Length 320.00 || lr: 1.385216e-03 || dt: 0.17 s |
# | Step: 695 / 800  || Average Episode Length 297.50 || lr: 1.378085e-03 || dt: 0.15 s |
# | Step: 696 / 800  || Average Episode Length 307.10 || lr: 1.371018e-03 || dt: 0.15 s |
# | Step: 697 / 800  || Average Episode Length 324.80 || lr: 1.364015e-03 || dt: 0.16 s |
# | Step: 698 / 800  || Average Episode Length 310.90 || lr: 1.357076e-03 || dt: 0.16 s |
# | Step: 699 / 800  || Average Episode Length 272.30 || lr: 1.350200e-03 || dt: 0.15 s |
# | Step: 700 / 800  || Average Episode Length 289.80 || lr: 1.343389e-03 || dt: 0.14 s |
# | Step: 701 / 800  || Average Episode Length 323.50 || lr: 1.336642e-03 || dt: 0.16 s |
# | Step: 702 / 800  || Average Episode Length 384.80 || lr: 1.329960e-03 || dt: 0.18 s |
# | Step: 703 / 800  || Average Episode Length 296.30 || lr: 1.323341e-03 || dt: 0.16 s |
# | Step: 704 / 800  || Average Episode Length 307.20 || lr: 1.316788e-03 || dt: 0.16 s |
# | Step: 705 / 800  || Average Episode Length 289.30 || lr: 1.310299e-03 || dt: 0.15 s |
# | Step: 706 / 800  || Average Episode Length 337.80 || lr: 1.303875e-03 || dt: 0.19 s |
# | Step: 707 / 800  || Average Episode Length 357.70 || lr: 1.297516e-03 || dt: 0.18 s |
# | Step: 708 / 800  || Average Episode Length 318.70 || lr: 1.291222e-03 || dt: 0.17 s |
# | Step: 709 / 800  || Average Episode Length 279.40 || lr: 1.284992e-03 || dt: 0.15 s |
# | Step: 710 / 800  || Average Episode Length 270.90 || lr: 1.278828e-03 || dt: 0.15 s |
# | Step: 711 / 800  || Average Episode Length 243.50 || lr: 1.272730e-03 || dt: 0.15 s |
# | Step: 712 / 800  || Average Episode Length 340.20 || lr: 1.266696e-03 || dt: 0.17 s |
# | Step: 713 / 800  || Average Episode Length 273.50 || lr: 1.260728e-03 || dt: 0.15 s |
# | Step: 714 / 800  || Average Episode Length 297.90 || lr: 1.254826e-03 || dt: 0.15 s |
# | Step: 715 / 800  || Average Episode Length 331.80 || lr: 1.248989e-03 || dt: 0.18 s |
# | Step: 716 / 800  || Average Episode Length 307.90 || lr: 1.243218e-03 || dt: 0.16 s |
# | Step: 717 / 800  || Average Episode Length 265.70 || lr: 1.237513e-03 || dt: 0.15 s |
# | Step: 718 / 800  || Average Episode Length 303.50 || lr: 1.231873e-03 || dt: 0.16 s |
# | Step: 719 / 800  || Average Episode Length 303.10 || lr: 1.226300e-03 || dt: 0.16 s |
# | Step: 720 / 800  || Average Episode Length 312.50 || lr: 1.220793e-03 || dt: 0.16 s |
# | Step: 721 / 800  || Average Episode Length 335.30 || lr: 1.215352e-03 || dt: 0.16 s |
# | Step: 722 / 800  || Average Episode Length 287.10 || lr: 1.209977e-03 || dt: 0.15 s |
# | Step: 723 / 800  || Average Episode Length 294.70 || lr: 1.204668e-03 || dt: 0.16 s |
# | Step: 724 / 800  || Average Episode Length 297.60 || lr: 1.199426e-03 || dt: 0.15 s |
# | Step: 725 / 800  || Average Episode Length 305.40 || lr: 1.194250e-03 || dt: 0.16 s |
# | Step: 726 / 800  || Average Episode Length 297.50 || lr: 1.189141e-03 || dt: 0.15 s |
# | Step: 727 / 800  || Average Episode Length 304.70 || lr: 1.184099e-03 || dt: 0.16 s |
# | Step: 728 / 800  || Average Episode Length 300.20 || lr: 1.179123e-03 || dt: 0.15 s |
# | Step: 729 / 800  || Average Episode Length 325.50 || lr: 1.174214e-03 || dt: 0.16 s |
# | Step: 730 / 800  || Average Episode Length 344.50 || lr: 1.169372e-03 || dt: 0.16 s |
# | Step: 731 / 800  || Average Episode Length 285.50 || lr: 1.164597e-03 || dt: 0.15 s |
# | Step: 732 / 800  || Average Episode Length 271.30 || lr: 1.159889e-03 || dt: 0.15 s |
# | Step: 733 / 800  || Average Episode Length 313.20 || lr: 1.155248e-03 || dt: 0.16 s |
# | Step: 734 / 800  || Average Episode Length 275.60 || lr: 1.150674e-03 || dt: 0.16 s |
# | Step: 735 / 800  || Average Episode Length 282.10 || lr: 1.146167e-03 || dt: 0.15 s |
# | Step: 736 / 800  || Average Episode Length 277.30 || lr: 1.141728e-03 || dt: 0.15 s |
# | Step: 737 / 800  || Average Episode Length 354.10 || lr: 1.137356e-03 || dt: 0.17 s |
# | Step: 738 / 800  || Average Episode Length 313.70 || lr: 1.133052e-03 || dt: 0.16 s |
# | Step: 739 / 800  || Average Episode Length 306.40 || lr: 1.128815e-03 || dt: 0.16 s |
# | Step: 740 / 800  || Average Episode Length 312.00 || lr: 1.124645e-03 || dt: 0.16 s |
# | Step: 741 / 800  || Average Episode Length 314.50 || lr: 1.120544e-03 || dt: 0.17 s |
# | Step: 742 / 800  || Average Episode Length 328.30 || lr: 1.116510e-03 || dt: 0.16 s |
# | Step: 743 / 800  || Average Episode Length 303.10 || lr: 1.112543e-03 || dt: 0.16 s |
# | Step: 744 / 800  || Average Episode Length 332.00 || lr: 1.108645e-03 || dt: 0.16 s |
# | Step: 745 / 800  || Average Episode Length 285.90 || lr: 1.104814e-03 || dt: 0.16 s |
# | Step: 746 / 800  || Average Episode Length 330.40 || lr: 1.101052e-03 || dt: 0.16 s |
# | Step: 747 / 800  || Average Episode Length 322.80 || lr: 1.097357e-03 || dt: 0.17 s |
# | Step: 748 / 800  || Average Episode Length 326.80 || lr: 1.093731e-03 || dt: 0.17 s |
# | Step: 749 / 800  || Average Episode Length 321.50 || lr: 1.090172e-03 || dt: 0.17 s |
# | Step: 750 / 800  || Average Episode Length 266.20 || lr: 1.086682e-03 || dt: 0.15 s |
# | Step: 751 / 800  || Average Episode Length 317.10 || lr: 1.083260e-03 || dt: 0.16 s |
# | Step: 752 / 800  || Average Episode Length 305.80 || lr: 1.079906e-03 || dt: 0.15 s |
# | Step: 753 / 800  || Average Episode Length 319.00 || lr: 1.076621e-03 || dt: 0.17 s |
# | Step: 754 / 800  || Average Episode Length 327.20 || lr: 1.073404e-03 || dt: 0.16 s |
# | Step: 755 / 800  || Average Episode Length 348.90 || lr: 1.070256e-03 || dt: 0.17 s |
# | Step: 756 / 800  || Average Episode Length 276.30 || lr: 1.067175e-03 || dt: 0.15 s |
# | Step: 757 / 800  || Average Episode Length 337.40 || lr: 1.064164e-03 || dt: 0.17 s |
# | Step: 758 / 800  || Average Episode Length 319.10 || lr: 1.061221e-03 || dt: 0.16 s |
# | Step: 759 / 800  || Average Episode Length 348.20 || lr: 1.058347e-03 || dt: 0.17 s |
# | Step: 760 / 800  || Average Episode Length 322.70 || lr: 1.055541e-03 || dt: 0.16 s |
# | Step: 761 / 800  || Average Episode Length 322.70 || lr: 1.052804e-03 || dt: 0.16 s |
# | Step: 762 / 800  || Average Episode Length 352.80 || lr: 1.050136e-03 || dt: 0.17 s |
# | Step: 763 / 800  || Average Episode Length 299.80 || lr: 1.047536e-03 || dt: 0.16 s |
# | Step: 764 / 800  || Average Episode Length 294.50 || lr: 1.045006e-03 || dt: 0.15 s |
# | Step: 765 / 800  || Average Episode Length 283.10 || lr: 1.042544e-03 || dt: 0.15 s |
# | Step: 766 / 800  || Average Episode Length 338.20 || lr: 1.040151e-03 || dt: 0.17 s |
# | Step: 767 / 800  || Average Episode Length 286.40 || lr: 1.037827e-03 || dt: 0.16 s |
# | Step: 768 / 800  || Average Episode Length 335.00 || lr: 1.035573e-03 || dt: 0.17 s |
# | Step: 769 / 800  || Average Episode Length 282.90 || lr: 1.033387e-03 || dt: 0.16 s |
# | Step: 770 / 800  || Average Episode Length 321.80 || lr: 1.031270e-03 || dt: 0.16 s |
# | Step: 771 / 800  || Average Episode Length 281.40 || lr: 1.029222e-03 || dt: 0.16 s |
# | Step: 772 / 800  || Average Episode Length 315.10 || lr: 1.027244e-03 || dt: 0.16 s |
# | Step: 773 / 800  || Average Episode Length 320.10 || lr: 1.025334e-03 || dt: 0.17 s |
# | Step: 774 / 800  || Average Episode Length 319.50 || lr: 1.023494e-03 || dt: 0.16 s |
# | Step: 775 / 800  || Average Episode Length 326.50 || lr: 1.021723e-03 || dt: 0.17 s |
# | Step: 776 / 800  || Average Episode Length 343.50 || lr: 1.020021e-03 || dt: 0.17 s |
# | Step: 777 / 800  || Average Episode Length 334.70 || lr: 1.018389e-03 || dt: 0.17 s |
# | Step: 778 / 800  || Average Episode Length 344.50 || lr: 1.016825e-03 || dt: 0.16 s |
# | Step: 779 / 800  || Average Episode Length 313.80 || lr: 1.015331e-03 || dt: 0.17 s |
# | Step: 780 / 800  || Average Episode Length 340.30 || lr: 1.013907e-03 || dt: 0.17 s |
# | Step: 781 / 800  || Average Episode Length 314.10 || lr: 1.012551e-03 || dt: 0.17 s |
# | Step: 782 / 800  || Average Episode Length 344.20 || lr: 1.011266e-03 || dt: 0.17 s |
# | Step: 783 / 800  || Average Episode Length 298.00 || lr: 1.010049e-03 || dt: 0.16 s |
# | Step: 784 / 800  || Average Episode Length 298.00 || lr: 1.008902e-03 || dt: 0.16 s |
# | Step: 785 / 800  || Average Episode Length 376.70 || lr: 1.007824e-03 || dt: 0.18 s |
# | Step: 786 / 800  || Average Episode Length 371.30 || lr: 1.006816e-03 || dt: 0.17 s |
# | Step: 787 / 800  || Average Episode Length 280.90 || lr: 1.005877e-03 || dt: 0.16 s |
# | Step: 788 / 800  || Average Episode Length 298.20 || lr: 1.005008e-03 || dt: 0.16 s |
# | Step: 789 / 800  || Average Episode Length 344.30 || lr: 1.004208e-03 || dt: 0.17 s |
# | Step: 790 / 800  || Average Episode Length 351.80 || lr: 1.003478e-03 || dt: 0.17 s |
# | Step: 791 / 800  || Average Episode Length 302.20 || lr: 1.002817e-03 || dt: 0.16 s |
# | Step: 792 / 800  || Average Episode Length 293.00 || lr: 1.002226e-03 || dt: 0.16 s |
# | Step: 793 / 800  || Average Episode Length 311.40 || lr: 1.001704e-03 || dt: 0.17 s |
# | Step: 794 / 800  || Average Episode Length 320.10 || lr: 1.001252e-03 || dt: 0.17 s |
# | Step: 795 / 800  || Average Episode Length 332.60 || lr: 1.000870e-03 || dt: 0.17 s |
# | Step: 796 / 800  || Average Episode Length 379.70 || lr: 1.000557e-03 || dt: 0.18 s |
# | Step: 797 / 800  || Average Episode Length 330.60 || lr: 1.000313e-03 || dt: 0.18 s |
# | Step: 798 / 800  || Average Episode Length 321.80 || lr: 1.000139e-03 || dt: 0.16 s |
# | Step: 799 / 800  || Average Episode Length 266.90 || lr: 1.000035e-03 || dt: 0.16 s |
# | Step: 800 / 800  || Average Episode Length 358.30 || lr: 1.000000e-03 || dt: 0.17 s |

# %%
plt.plot(episode_lens)
plt.xlabel("Iterations")
plt.ylabel("Average Episode Length")
plt.show()

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0), repeat=False)
# Out:
# done at step 400
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0.01), repeat=False)
# Out:
# done at step 371
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
show_one_episode(lambda obs: action_policy(dqn, obs, epsilon=0.01), repeat=False)
# Out:
# done at step 499
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
